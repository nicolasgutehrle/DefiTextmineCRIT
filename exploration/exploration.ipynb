# %% [markdown]
# # Data Exploration

# %%
import pandas as pd

# %%
df_train = pd.read_csv('../data/train_2.csv')
df_test = pd.read_csv('../data/test.csv')
df_sample = pd.read_csv('../data/sample_submission_2.csv')

# %%
df_train.head()
# Out:
#    Id    Token              Label
# 0   0     "01"              aucun
# 1   1  "4.5.3"              aucun
# 2   2      "."              aucun
# 3   3   "Port"  geogFeat geogName
# 4   4     "du"           geogName

# %%
df_train['Label'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Label'>

# %%
for tok, label in zip(df_train['Token'], df_train['Label']):
    print(tok, label)
# Out:
# "01" aucun
# "4.5.3" aucun
# "." aucun
# "Port" geogFeat geogName
# "du" geogName
# "Lavandou" geogName name
# "07" aucun
# "4.5.3" aucun
# "." aucun
# "—" aucun
# "Port" geogFeat geogName
# "du" geogName
# "Lavandou" geogName name
# "," aucun
# "au" aucun
# "NW" aucun
# "(" aucun
# "2020" aucun
# ")" aucun
# "." aucun
# "2103" aucun
# "01" aucun
# "3.7.2" aucun
# "." aucun
# "Port" geogFeat geogName
# "de" geogName
# "Kpémé" geogName name
# "07" aucun
# "Carte" aucun
# "7587" aucun
# "(" aucun
# "INT" aucun
# "2881" aucun
# ")" aucun
# "." aucun
# "13" aucun
# "ENC" aucun
# "FR57587C." aucun
# "01" aucun
# "4.5.5.1" aucun
# "." aucun
# "Généralités" aucun
# "07" aucun
# "Le" aucun
# "port" geogFeat geogName
# "de" geogFeat geogName
# "plaisance" geogFeat geogName
# "de" geogName
# "Cavalaire" geogName name
# "se" aucun
# "trouve" aucun
# "à" aucun
# "l’" aucun
# "extrémité" aucun
# "Ouest" aucun
# "de" aucun
# "la" aucun
# "baie" geogFeat geogName
# "de" geogName
# "Cavalaire" geogName name
# "." aucun
# "01" aucun
# "3.2.3.2" aucun
# "." aucun
# "Grande" geogName name
# "Passe" geogFeat geogName
# "07" aucun
# "La" aucun
# "Grande" geogName name
# "Passe" geogFeat geogName
# "(" aucun
# "9" aucun
# "°" aucun
# "45,90" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "47" aucun
# "°" aucun
# "37,48" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "s’" aucun
# "ouvre" aucun
# "entre" aucun
# "le" aucun
# "récif" geogFeat
# "qui" aucun
# "porte" aucun
# "l’" aucun
# "îlot" geogFeat geogName
# "Pagode" geogName name
# "(" aucun
# "9" aucun
# "°" aucun
# "45,75" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "47" aucun
# "°" aucun
# "36,40" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "à" aucun
# "l’" aucun
# "Ouest" aucun
# "et" aucun
# "le" aucun
# "récif" geogFeat
# "qui" aucun
# "porte" aucun
# "la" aucun
# "Grande" geogName name
# "Île" geogFeat geogName
# "," aucun
# "à" aucun
# "l’" aucun
# "Est" aucun
# "." aucun
# "Les" aucun
# "limites" aucun
# "de" aucun
# "la" aucun
# "passe" aucun
# "sont" aucun
# "mal" aucun
# "définies" aucun
# "car" aucun
# "191" aucun
# "ÎLES" geogFeat
# "ET" aucun
# "DANGERS" geogFeat
# "AU" aucun
# "NORD-OUEST" aucun
# "ET" aucun
# "À" aucun
# "L’" aucun
# "OUEST" aucun
# "DE" aucun
# "MADAGASCAR" geogName name
# "ces" aucun
# "deux" aucun
# "récifs" geogFeat
# "ne" aucun
# "sont" aucun
# "pas" aucun
# "accores" aucun
# "." aucun
# "L’" aucun
# "eau" aucun
# "est" aucun
# "très" aucun
# "claire" aucun
# "et" aucun
# "le" aucun
# "fond" aucun
# "apparaît" aucun
# "aussi" aucun
# "distinctement" aucun
# "par" aucun
# "9" aucun
# "m" aucun
# "de" aucun
# "profondeur" aucun
# "que" aucun
# "par" aucun
# "des" aucun
# "fonds" aucun
# "de" aucun
# "4" aucun
# "m." aucun
# "13" aucun
# "Le" aucun
# "chenal" geogFeat
# "a" aucun
# "une" aucun
# "profondeur" aucun
# "minimale" aucun
# "de" aucun
# "5,0" aucun
# "m" aucun
# "dans" aucun
# "sa" aucun
# "partie" aucun
# "centrale" aucun
# "," aucun
# "de" aucun
# "2,1" aucun
# "m" aucun
# "dans" aucun
# "sa" aucun
# "partie" aucun
# "Est" aucun
# "et" aucun
# "2,7" aucun
# "m" aucun
# "dans" aucun
# "le" aucun
# "Nord" aucun
# "." aucun
# "Sa" aucun
# "largeur" aucun
# "minimale" aucun
# "est" aucun
# "de" aucun
# "0,15" aucun
# "M." aucun
# "19" aucun
# "Dans" aucun
# "la" aucun
# "passe" geogFeat
# "," aucun
# "les" aucun
# "courants" aucun
# "de" aucun
# "marée" aucun
# "sont" aucun
# "forts" aucun
# "et" aucun
# "le" aucun
# "courant" aucun
# "sortant" aucun
# "atteint" aucun
# "4" aucun
# "nœuds" aucun
# "en" aucun
# "vive" aucun
# "-" aucun
# "eau" aucun
# "." aucun
# "25" aucun
# "Pendant" aucun
# "la" aucun
# "période" aucun
# "des" aucun
# "alizés" aucun
# "de" aucun
# "SE" aucun
# "," aucun
# "la" aucun
# "Grande" geogName name
# "Passe" geogFeat geogName
# "est" aucun
# "directement" aucun
# "exposée" aucun
# "à" aucun
# "la" aucun
# "houle" aucun
# "et" aucun
# "au" aucun
# "vent" aucun
# "." aucun
# "La" aucun
# "mer" aucun
# "est" aucun
# "alors" aucun
# "très" aucun
# "mouvementée" aucun
# "à" aucun
# "l’" aucun
# "ouvert" geogFeat
# "de" aucun
# "la" aucun
# "passe" geogFeat
# "." aucun
# "En" aucun
# "arrière" aucun
# "de" aucun
# "la" aucun
# "ligne" geogFeat
# "de" aucun
# "brisants" geogFeat
# "," aucun
# "le" aucun
# "plan" geogFeat
# "d’" geogFeat
# "eau" geogFeat
# "est" aucun
# "calme" aucun
# "." aucun
# "Avec" aucun
# "une" aucun
# "bonne" aucun
# "connaissance" aucun
# "des" aucun
# "lieux" aucun
# "," aucun
# "elle" aucun
# "est" aucun
# "praticable" aucun
# "pour" aucun
# "des" aucun
# "petits" aucun
# "navires" aucun
# "." aucun
# "31" aucun
# "Le" aucun
# "chenal" geogFeat
# "principal" geogFeat
# "est" aucun
# "orienté" aucun
# "vers" aucun
# "le" aucun
# "Nord" aucun
# "," aucun
# "sur" aucun
# "une" aucun
# "distance" aucun
# "d’" aucun
# "environ" aucun
# "1,5" aucun
# "M" aucun
# "," aucun
# "entre" aucun
# "deux" aucun
# "lignes" geogFeat
# "de" aucun
# "récifs" geogFeat
# "découvrants" geogFeat
# "et" aucun
# "accores" aucun
# "." aucun
# "Le" aucun
# "récif" geogFeat
# "du" aucun
# "côté" aucun
# "Est" aucun
# "se" aucun
# "distingue" aucun
# "plus" aucun
# "nettement" aucun
# "." aucun
# "37" aucun
# "À" aucun
# "partir" aucun
# "de" aucun
# "la" aucun
# "partie" aucun
# "médiane" aucun
# "de" aucun
# "la" aucun
# "passe" geogFeat
# "," aucun
# "un" aucun
# "chenal" geogFeat
# "secondaire" geogFeat
# "," aucun
# "orienté" aucun
# "vers" aucun
# "le" aucun
# "NW" aucun
# "(" aucun
# "9" aucun
# "°" aucun
# "45,24" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "47" aucun
# "°" aucun
# "37,26" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "," aucun
# "longe" aucun
# "le" aucun
# "côté" aucun
# "NE" aucun
# "du" aucun
# "récif" geogFeat
# "qui" aucun
# "porte" aucun
# "l’" aucun
# "îlot" geogFeat geogName
# "Pagode" geogName name
# "." aucun
# "01" aucun
# "5.4.9.3" aucun
# "." aucun
# "Données" aucun
# "portuaires" aucun
# "07" aucun
# "Caractéristiques" aucun
# "nautiques" aucun
# "Hydrographie" aucun
# "locale" aucun
# "Port" geogFeat
# "d’" geogFeat
# "échouage" geogFeat
# "sur" aucun
# "fond" aucun
# "de" aucun
# "vase" aucun
# "molle" aucun
# "." aucun
# "Marée" aucun
# "et" aucun
# "courants" aucun
# "Courant" aucun
# "provoqué" aucun
# "par" aucun
# "le" aucun
# "déversement" aucun
# "de" aucun
# "l’" aucun
# "eau" aucun
# "à" aucun
# "travers" aucun
# "les" aucun
# "vannes" geogFeat
# "d’" aucun
# "assèchement" aucun
# "des" aucun
# "marais" aucun
# "au" aucun
# "fond" aucun
# "du" aucun
# "port" geogFeat
# "." aucun
# "Navires" aucun
# "admis" aucun
# "Infrastructures" geogFeat
# "Installations" geogFeat
# "portuaires" geogFeat
# "Navires" aucun
# "de" aucun
# "pêche" aucun
# "côtière" aucun
# "et" aucun
# "ostréicoles" aucun
# "jusqu’" aucun
# "à" aucun
# "25" aucun
# "m" aucun
# "de" aucun
# "longueur" aucun
# "," aucun
# "4" aucun
# "m" aucun
# "de" aucun
# "large" aucun
# "," aucun
# "5" aucun
# "m" aucun
# "de" aucun
# "TE" aucun
# "en" aucun
# "VE" aucun
# "et" aucun
# "3,5" aucun
# "m" aucun
# "de" aucun
# "TE" aucun
# "en" aucun
# "ME" aucun
# "." aucun
# "1" aucun
# "quai" geogFeat
# "de" aucun
# "70" aucun
# "m" aucun
# "le" aucun
# "long" aucun
# "de" aucun
# "la" aucun
# "rive" geogFeat geogName
# "NE" geogName name
# "près" aucun
# "des" aucun
# "vannes" geogFeat
# "." aucun
# "Petits" aucun
# "appontements" geogFeat
# "privés" geogFeat
# "le" aucun
# "long" aucun
# "des" aucun
# "rives" geogFeat
# "de" aucun
# "l’" aucun
# "étier" geogFeat
# "sur" aucun
# "500" aucun
# "m" aucun
# "au" aucun
# "total" aucun
# "." aucun
# "Outillage" aucun
# "2" aucun
# "cales" geogFeat
# "." aucun
# "Réparations" aucun
# "1" aucun
# "platin" geogFeat
# "en" aucun
# "maçonnerie" aucun
# "utilisé" aucun
# "pour" aucun
# "le" aucun
# "carénage" aucun
# "en" aucun
# "avant" aucun
# "des" aucun
# "vannes" geogFeat
# "." aucun
# "3" aucun
# "ateliers" geogFeat
# "de" aucun
# "réparation" aucun
# "mécanique" aucun
# "." aucun
# "Ravitaillement" aucun
# "Poste" geogFeat
# "de" geogFeat
# "carburant" geogFeat
# "." aucun
# "Coopérative" aucun
# "maritime" aucun
# "." aucun
# "Organisation" aucun
# "Administration" aucun
# "Régie" aucun
# "municipale" aucun
# "." aucun
# "Mairie" geogFeat geogName
# "de" geogName
# "Bouin" geogName name
# ";" aucun
# "tél" aucun
# "." aucun
# ":" aucun
# "02.51.49.74.14" aucun
# ";" aucun
# "télécopie" aucun
# ":" aucun
# "02.51.68.60.00" aucun
# ";" aucun
# "mél" aucun
# ":" aucun
# "mairie.de.bouin@wanadoo.fr" aucun
# "." aucun
# "Bureau" geogFeat
# "du" geogFeat
# "port" geogFeat
# "à" aucun
# "l’" geogName name
# "Époids" geogName name
# ":" aucun
# "02.51.68.70.53" aucun
# "." aucun
# "5.4.9.3" aucun
# "." aucun
# "—" aucun
# "Port" geogFeat geogName
# "de" geogName
# "l’" geogName name
# "Époids" geogName name
# "(" aucun
# "46" aucun
# "°" aucun
# "56,49" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "2" aucun
# "°" aucun
# "04,66" aucun
# "'" aucun
# "W" aucun
# ")" aucun
# "." aucun
# "extrait" aucun
# "le" aucun
# ":" aucun
# "2021" aucun
# "-" aucun
# "10" aucun
# "-" aucun
# "12" aucun
# "—" aucun
# "généré" aucun
# "le" aucun
# ":" aucun
# "2021" aucun
# "-" aucun
# "10" aucun
# "-" aucun
# "13" aucun
# "–" aucun
# "page" aucun
# "343" aucun
# "/" aucun
# "0" aucun
# "343" aucun
# "DE" aucun
# "LA" aucun
# "POINTE" geogFeat geogName
# "DU" geogName
# "CROISIC" geogName name
# "À" aucun
# "L’" aucun
# "ÎLE" geogFeat geogName
# "DE" geogName
# "NOIRMOUTIER" geogName name
# "01" aucun
# "5.4.4" aucun
# "." aucun
# "Pornic" geogName name
# "et" aucun
# "La" geogName name
# "Noëveillard" geogName name
# "07" aucun
# "13" aucun
# "5.4.4.A." aucun
# "—" aucun
# "Pornic" geogName name
# "(" aucun
# "2018" aucun
# ")" aucun
# "." aucun
# "5.4.4.B." aucun
# "—" aucun
# "La" geogName name
# "Noëveillard" geogName name
# "(" aucun
# "2018" aucun
# ")" aucun
# "." aucun
# "01" aucun
# "5.4.9" aucun
# "." aucun
# "Port" geogFeat geogName
# "de" geogName
# "l’" geogName name
# "Époids" geogName name
# "07" aucun
# "5.4.9" aucun
# "." aucun
# "—" aucun
# "Port" geogFeat geogName
# "du" geogName
# "Bec" geogName name
# "(" aucun
# "2018" aucun
# ")" aucun
# "." aucun
# "342" aucun
# "extrait" aucun
# "le" aucun
# ":" aucun
# "2021" aucun
# "-" aucun
# "10" aucun
# "-" aucun
# "12" aucun
# "—" aucun
# "généré" aucun
# "le" aucun
# ":" aucun
# "2021" aucun
# "-" aucun
# "10" aucun
# "-" aucun
# "13" aucun
# "–" aucun
# "page" aucun
# "342" aucun
# "/" aucun
# "0" aucun
# "BAIE" geogFeat geogName
# "DE" geogName
# "BOURGNEUF" geogName name
# "01" aucun
# "6.2.1.6" aucun
# "." aucun
# "Accès" aucun
# "07" aucun
# "Les" aucun
# "signaux" geogFeat
# "lumineux" geogFeat
# "internationaux" aucun
# "d’" aucun
# "entrée" aucun
# "et" aucun
# "de" aucun
# "sortie" aucun
# "sont" aucun
# "montrés" aucun
# "de" aucun
# "jour" aucun
# "comme" aucun
# "de" aucun
# "nuit" aucun
# "à" aucun
# "la" aucun
# "tour" geogFeat
# "des" geogFeat
# "signaux" geogFeat
# "(" aucun
# "43" aucun
# "°" aucun
# "31,68" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "1" aucun
# "°" aucun
# "31,29" aucun
# "'" aucun
# "W" aucun
# ")" aucun
# "," aucun
# "sur" aucun
# "le" aucun
# "côté" aucun
# "Sud" aucun
# "de" aucun
# "l’" aucun
# "entrée" geogFeat
# "de" aucun
# "l’" aucun
# "Adour" geogName name
# "." aucun
# "En" aucun
# "cas" aucun
# "de" aucun
# "discordance" aucun
# "entre" aucun
# "un" aucun
# "signal" geogFeat
# "portuaire" geogFeat
# "et" aucun
# "un" aucun
# "ordre" aucun
# "de" aucun
# "Bayonne" aucun
# "-" aucun
# "port" aucun
# "," aucun
# "c’" aucun
# "est" aucun
# "l’" aucun
# "ordre" aucun
# "de" aucun
# "Bayonne" aucun
# "-" aucun
# "port" aucun
# "qui" aucun
# "est" aucun
# "à" aucun
# "prendre" aucun
# "en" aucun
# "considération" aucun
# "." aucun
# "13" aucun
# "L’" aucun
# "entrée" geogFeat
# "dans" aucun
# "l’" aucun
# "Adour" geogName name
# "est" aucun
# "canalisée" aucun
# "entre" aucun
# "deux" aucun
# "jetées" geogFeat
# "parallèles" aucun
# "," aucun
# "portant" aucun
# "un" aucun
# "feu" geogFeat
# "à" aucun
# "leur" aucun
# "extrémité" aucun
# "," aucun
# "débordées" aucun
# "par" aucun
# "des" aucun
# "enrochements" geogFeat
# "jusqu’" aucun
# "à" aucun
# "20" aucun
# "m" aucun
# "en" aucun
# "rivière" geogFeat
# "." aucun
# "La" aucun
# "passe" geogFeat
# "," aucun
# "ouverte" aucun
# "à" aucun
# "l’" aucun
# "WNW" aucun
# "," aucun
# "est" aucun
# "large" aucun
# "de" aucun
# "60" aucun
# "m" aucun
# "entre" aucun
# "les" aucun
# "isobathes" aucun
# "de" aucun
# "10" aucun
# "m." aucun
# "Les" aucun
# "jetées" geogFeat
# "sont" aucun
# "prolongées" aucun
# "en" aucun
# "amont" aucun
# "par" aucun
# "des" aucun
# "brise" geogFeat
# "-" geogFeat
# "lames" geogFeat
# "qui" aucun
# "portent" aucun
# "un" aucun
# "balisage" geogFeat
# "latéral" geogFeat
# "lumineux" geogFeat
# "." aucun
# "19" aucun
# "Pour" aucun
# "franchir" aucun
# "la" aucun
# "passe" geogFeat
# "on" aucun
# "suit" aucun
# "l’" aucun
# "alignement" geogFeat
# "(" aucun
# "dit" aucun
# "alignement" geogFeat geogName
# "du" geogName
# "Boucau" geogName name
# ")" aucun
# "à" aucun
# "090" aucun
# "°" aucun
# "de" aucun
# "deux" aucun
# "feux" geogFeat
# "portés" aucun
# "par" aucun
# "deux" aucun
# "pylônes" geogFeat
# "métalliques" aucun
# "blancs" aucun
# "à" aucun
# "sommet" geogFeat
# "rouge" aucun
# "(" aucun
# "6" aucun
# "et" aucun
# "12" aucun
# "m" aucun
# ")" aucun
# "." aucun
# "Le" aucun
# "pylône" geogFeat
# "postérieur" geogFeat
# "porte" aucun
# "un" aucun
# "panneau" geogFeat
# "rouge" aucun
# "avec" aucun
# "bande" aucun
# "blanche" aucun
# "et" aucun
# "le" aucun
# "pylône" geogFeat
# "antérieur" geogFeat
# "un" aucun
# "panneau" geogFeat
# "blanc" aucun
# "avec" aucun
# "bande" aucun
# "rouge" aucun
# "." aucun
# "Il" aucun
# "convient" aucun
# "de" aucun
# "suivre" aucun
# "ensuite" aucun
# "l’" aucun
# "alignement" geogFeat
# "à" aucun
# "111,6" aucun
# "°" aucun
# "de" aucun
# "deux" aucun
# "feux" geogFeat
# "allumés" aucun
# "jour" aucun
# "et" aucun
# "nuit" aucun
# "." aucun
# "Le" aucun
# "feu" geogFeat
# "antérieur" geogFeat
# "est" aucun
# "porté" aucun
# "par" aucun
# "un" aucun
# "mâtereau" geogFeat
# "(" aucun
# "4" aucun
# "m" aucun
# ")" aucun
# "équipé" aucun
# "d’" aucun
# "un" aucun
# "cadre" geogFeat
# "ajouré" aucun
# "avec" aucun
# "une" aucun
# "bande" aucun
# "centrale" aucun
# "verte" aucun
# "et" aucun
# "deux" aucun
# "bandes" aucun
# "latérales" aucun
# "blanches" aucun
# "," aucun
# "le" aucun
# "feu" geogFeat
# "postérieur" geogFeat
# "par" aucun
# "la" aucun
# "tour" geogFeat
# "carrée" aucun
# "blanche" aucun
# "(" aucun
# "9" aucun
# "m" aucun
# ")" aucun
# "du" aucun
# "bâtiment" geogFeat
# "de" geogFeat
# "la" geogFeat
# "capitainerie" geogFeat
# "." aucun
# "2134" aucun
# "25" aucun
# "De" aucun
# "l’" aucun
# "extrémité" aucun
# "Est" aucun
# "des" aucun
# "jetées" geogFeat
# "(" aucun
# "au" aucun
# "Nord" aucun
# "de" aucun
# "la" aucun
# "tour" geogFeat
# "des" geogFeat
# "signaux" geogFeat
# ")" aucun
# "jusqu’" aucun
# "au" aucun
# "premier" aucun
# "coude" aucun
# "de" aucun
# "la" aucun
# "rivière" geogFeat
# "," aucun
# "aucun" aucun
# "alignement" geogFeat
# "ne" aucun
# "matérialise" aucun
# "l’" aucun
# "axe" geogFeat
# "du" aucun
# "chenal" geogFeat
# "." aucun
# "Sur" aucun
# "la" aucun
# "rive" geogFeat geogName
# "gauche" geogName name
# "," aucun
# "deux" aucun
# "blocs" geogFeat
# "de" aucun
# "ciment" aucun
# "," aucun
# "vestiges" geogFeat
# "d’" aucun
# "un" aucun
# "ancien" aucun
# "appontement" geogFeat
# "," aucun
# "débordent" aucun
# "la" aucun
# "digue" geogFeat geogName
# "Est" geogName name
# "du" aucun
# "port" geogFeat geogName
# "de" geogFeat geogName
# "plaisance" geogFeat geogName
# "d’" geogName
# "Anglet" geogName name
# "," aucun
# "200" aucun
# "m" aucun
# "en" aucun
# "aval" aucun
# "d’" aucun
# "une" aucun
# "digue" geogFeat
# "submersible" geogFeat
# "marquée" aucun
# "par" aucun
# "un" aucun
# "feu" geogFeat
# "et" aucun
# "par" aucun
# "la" aucun
# "balise" geogFeat geogName
# "latérale" geogFeat geogName
# "tribord" geogFeat geogName
# "«" geogName
# "9" geogName name
# "»" geogName
# "." aucun
# "À" aucun
# "50" aucun
# "m" aucun
# "en" aucun
# "amont" aucun
# "de" aucun
# "cette" aucun
# "balise" geogFeat
# "se" aucun
# "trouve" aucun
# "un" aucun
# "ponton" geogFeat
# "réservé" aucun
# "aux" aucun
# "remorqueurs" aucun
# "et" aucun
# "aux" aucun
# "pilotines" aucun
# "du" aucun
# "port" geogFeat
# "." aucun
# "31" aucun
# "Dans" aucun
# "le" aucun
# "premier" aucun
# "coude" aucun
# "," aucun
# "l’" aucun
# "axe" geogFeat
# "du" aucun
# "chenal" geogFeat
# "est" aucun
# "matérialisé" aucun
# "," aucun
# "pour" aucun
# "les" aucun
# "navires" aucun
# "faisant" aucun
# "route" aucun
# "vers" aucun
# "l’" aucun
# "amont" aucun
# "," aucun
# "par" aucun
# "l’" aucun
# "alignement" geogFeat
# "lumineux" geogFeat
# "à" aucun
# "139,9" aucun
# "°" aucun
# "des" aucun
# "feux" geogFeat geogName
# "de" geogName
# "Saint-Gobain" geogName name
# "(" aucun
# "43" aucun
# "°" aucun
# "31,05" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "1" aucun
# "°" aucun
# "29,30" aucun
# "'" aucun
# "W" aucun
# ")" aucun
# "constitué" aucun
# "de" aucun
# "deux" aucun
# "panneaux" geogFeat
# "rouge" aucun
# "et" aucun
# "blanc" aucun
# "." aucun
# "Pour" aucun
# "les" aucun
# "navires" aucun
# "faisant" aucun
# "route" aucun
# "vers" aucun
# "l’" aucun
# "aval" aucun
# "," aucun
# "par" aucun
# "l’" aucun
# "alignement" geogFeat
# "lumineux" geogFeat
# "à" aucun
# "322,4" aucun
# "°" aucun
# "des" aucun
# "feux" geogFeat geogName
# "des" geogName
# "Forges" geogName name
# "(" aucun
# "43" aucun
# "°" aucun
# "31,68" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "1" aucun
# "°" aucun
# "29,98" aucun
# "'" aucun
# "W" aucun
# ")" aucun
# "." aucun
# "La" aucun
# "fin" aucun
# "du" aucun
# "chenalage" aucun
# "vers" aucun
# "Bayonne" geogName name
# "est" aucun
# "facilitée" aucun
# "," aucun
# "de" aucun
# "nuit" aucun
# "," aucun
# "par" aucun
# "le" aucun
# "secteur" geogFeat
# "blanc" aucun
# "du" aucun
# "feu" geogFeat
# "de" geogFeat
# "guidage" geogFeat
# "(" aucun
# "43" aucun
# "°" aucun
# "30,06" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "1" aucun
# "°" aucun
# "29,53" aucun
# "'" aucun
# "W" aucun
# ")" aucun
# "du" aucun
# "pont" geogFeat geogName
# "de" geogName
# "l’" geogName
# "Aveugle" geogName name
# "situé" aucun
# "à" aucun
# "0,4" aucun
# "M" aucun
# "en" aucun
# "amont" aucun
# "de" aucun
# "l’" aucun
# "ancienne" geogName name
# "base" geogFeat geogName
# "navale" geogFeat geogName
# "." aucun
# "Le" aucun
# "chenal" geogFeat
# "est" aucun
# "marqué" aucun
# "par" aucun
# "des" aucun
# "bouées" geogFeat
# "et" aucun
# "balises" geogFeat
# "latérales" geogFeat
# "dont" aucun
# "certaines" aucun
# "sont" aucun
# "lumineuses" aucun
# "." aucun
# "2134" aucun
# "37" aucun
# "La" aucun
# "profondeur" aucun
# "minimale" aucun
# "du" aucun
# "chenal" geogFeat
# "est" aucun
# "de" aucun
# "7,5" aucun
# "m" aucun
# "," aucun
# "entre" aucun
# "l’" aucun
# "embouchure" geogFeat
# "et" aucun
# "l’" aucun
# "ancienne" geogName name
# "base" geogFeat geogName
# "navale" geogFeat geogName
# "." aucun
# "Quelques" aucun
# "épaves" geogFeat
# "gisent" aucun
# "en" aucun
# "abord" aucun
# "du" aucun
# "chenal" geogFeat
# "." aucun
# "Seules" aucun
# "celles" aucun
# "qui" aucun
# "sont" aucun
# "dangereuses" aucun
# "pour" aucun
# "la" aucun
# "navigation" aucun
# "sont" aucun
# "balisées" aucun
# "." aucun
# "43" aucun
# "Une" aucun
# "zone" geogFeat
# "d’" geogFeat
# "évitage" geogFeat
# "de" aucun
# "450" aucun
# "m" aucun
# "sur" aucun
# "360" aucun
# "m" aucun
# "," aucun
# "draguée" aucun
# "à" aucun
# "7" aucun
# "m" aucun
# "," aucun
# "est" aucun
# "située" aucun
# "en" aucun
# "amont" aucun
# "de" aucun
# "la" aucun
# "bouée" geogFeat geogName
# "«" geogName
# "2" geogName name
# "»" geogName
# "." aucun
# "49" aucun
# "Les" aucun
# "navires" aucun
# "doivent" aucun
# "naviguer" aucun
# "à" aucun
# "vitesse" aucun
# "réduite" aucun
# "aux" aucun
# "abords" aucun
# "du" aucun
# "port" geogFeat geogName
# "de" geogFeat geogName
# "plaisance" geogFeat geogName
# "d’" geogName
# "Anglet" geogName name
# "." aucun
# "55" aucun
# "Un" aucun
# "siphon" geogFeat
# "constitué" aucun
# "de" aucun
# "deux" aucun
# "canalisations" geogFeat
# "sous-marines" geogFeat
# "est" aucun
# "posé" aucun
# "dans" aucun
# "l’" aucun
# "Adour" geogName name
# "," aucun
# "à" aucun
# "la" aucun
# "hauteur" aucun
# "du" aucun
# "pont" geogFeat geogName
# "de" geogName
# "l’" geogName
# "Aveugle" geogName name
# "." aucun
# "La" aucun
# "cote" aucun
# "supérieure" aucun
# "du" aucun
# "siphon" geogFeat
# "est" aucun
# "de" aucun
# "11" aucun
# "m" aucun
# "au" aucun
# "-" aucun
# "dessous" aucun
# "du" aucun
# "zéro" aucun
# "des" aucun
# "cartes" aucun
# "et" aucun
# "il" aucun
# "est" aucun
# "recouvert" aucun
# "de" aucun
# "3" aucun
# "m" aucun
# "de" aucun
# "sable" aucun
# "et" aucun
# "vase" aucun
# "." aucun
# "61" aucun
# "Le" aucun
# "pont" geogFeat geogName
# "Henri" geogName name
# "Grenet" geogName name
# "(" aucun
# "43" aucun
# "°" aucun
# "29,88" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "1" aucun
# "°" aucun
# "28,95" aucun
# "'" aucun
# "W" aucun
# ")" aucun
# "," aucun
# "situé" aucun
# "en" aucun
# "amont" aucun
# "du" aucun
# "quai" geogFeat geogName
# "Edmond" geogName name
# "Foy" geogName name
# "," aucun
# "constitue" aucun
# "la" aucun
# "limite" aucun
# "de" aucun
# "la" aucun
# "navigation" aucun
# "maritime" aucun
# "." aucun
# "De" aucun
# "nombreuses" aucun
# "embarcations" aucun
# "pratiquent" aucun
# "la" aucun
# "pêche" aucun
# "dans" aucun
# "le" aucun
# "chenal" geogFeat
# "." aucun
# "01" aucun
# "2.3.3.4" aucun
# "." aucun
# "Pilotage" aucun
# "07" aucun
# "Les" aucun
# "limites" aucun
# "de" aucun
# "la" aucun
# "zone" geogFeat
# "de" geogFeat
# "pilotage" geogFeat
# "figurent" aucun
# "sur" aucun
# "la" aucun
# "carte" aucun
# "." aucun
# "Pour" aucun
# "de" aucun
# "plus" aucun
# "amples" aucun
# "informations" aucun
# "," aucun
# "voir" aucun
# "l’" aucun
# "arrêté" aucun
# "cité" aucun
# "dans" aucun
# "le" aucun
# "paragraphe" aucun
# "1.7.6.3" aucun
# "." aucun
# "13" aucun
# "Pour" aucun
# "le" aucun
# "port" geogFeat geogName
# "de" geogName
# "Miquelon" geogName name
# "," aucun
# "la" aucun
# "prise" aucun
# "du" aucun
# "pilote" aucun
# "s’" aucun
# "effectue" aucun
# "soit" aucun
# "à" aucun
# "quai" geogFeat
# "au" aucun
# "port" geogFeat geogName
# "de" geogName
# "Saint-Pierre" geogName name
# "," aucun
# "soit" aucun
# "à" aucun
# "la" aucun
# "bouée" geogFeat geogName
# "de" geogFeat geogName
# "marque" geogFeat geogName
# "d’" geogFeat geogName
# "eaux" geogFeat geogName
# "saines" geogFeat geogName
# "du" geogName
# "«" geogName
# "Nord-Est" geogName name
# "»" geogName
# "(" aucun
# "voir" aucun
# "§" aucun
# "2.2.2.4" aucun
# "." aucun
# ")" aucun
# "." aucun
# "19" aucun
# "Les" aucun
# "navires" aucun
# "astreints" aucun
# "au" aucun
# "pilotage" aucun
# "qui" aucun
# "quittent" aucun
# "le" aucun
# "port" geogFeat geogName
# "de" geogName
# "Miquelon" geogName name
# "doivent" aucun
# "déposer" aucun
# "le" aucun
# "pilote" aucun
# "à" aucun
# "quai" geogFeat
# "au" aucun
# "port" geogFeat geogName
# "de" geogName
# "Saint-Pierre" geogName name
# "," aucun
# "si" aucun
# "c’" aucun
# "était" aucun
# "leur" aucun
# "destination" aucun
# "," aucun
# "ou" aucun
# "à" aucun
# "la" aucun
# "marque" geogFeat geogName
# "d’" geogFeat geogName
# "eaux" geogFeat geogName
# "saines" geogFeat geogName
# "«" geogName
# "Nord-Est" geogName name
# "»" geogName
# "dans" aucun
# "les" aucun
# "autres" aucun
# "cas" aucun
# "." aucun
# "25" aucun
# "Si" aucun
# "les" aucun
# "conditions" aucun
# "météorologiques" aucun
# "le" aucun
# "permettent" aucun
# "," aucun
# "l’" aucun
# "embarquement" aucun
# "et" aucun
# "/" aucun
# "ou" aucun
# "le" aucun
# "débarquement" aucun
# "du" aucun
# "pilote" aucun
# "pourra" aucun
# "s’" aucun
# "ef" aucun
# "fectuer" aucun
# "à" aucun
# "la" aucun
# "bouée" geogFeat geogName
# "cardinale" geogFeat geogName
# "Nord" geogFeat geogName
# "de" geogName
# "«" geogName
# "La" geogName name
# "Chatte" geogName name
# "»" geogName
# "." aucun
# "31" aucun
# "Pour" aucun
# "plus" aucun
# "d’" aucun
# "informations" aucun
# "," aucun
# "se" aucun
# "référer" aucun
# "à" aucun
# "l’" aucun
# "ouvrage" aucun
# "de" aucun
# "Radiosignaux" aucun
# "931" aucun
# "," aucun
# "Radiocommunications" aucun
# "portuaires" aucun
# "(" aucun
# "Océan" geogFeat geogName
# "Atlantique" geogName name
# ")" aucun
# "." aucun
# "01" aucun
# "6.1.1.3" aucun
# "." aucun
# "Marée" aucun
# "07" aucun
# "GUYANE" geogName name
# "." aucun
# "—" aucun
# "La" aucun
# "Pointe" geogFeat geogName
# "Française" geogName name
# "et" aucun
# "Saint-Laurent-du-Maroni" geogName name
# "(" aucun
# "§" aucun
# "6.2.9.1" aucun
# "." aucun
# ")" aucun
# "sont" aucun
# "des" aucun
# "ports" geogFeat
# "secondaires" geogFeat
# "de" aucun
# "l’" aucun
# "Annuaire" aucun
# "des" aucun
# "marées" aucun
# "," aucun
# "tome" aucun
# "2" aucun
# ":" aucun
# "Ports" geogFeat
# "d’" aucun
# "outre-mer" aucun
# "." aucun
# "La" aucun
# "marée" aucun
# "est" aucun
# "de" aucun
# "type" aucun
# "semi-diurne" aucun
# "." aucun
# "À" aucun
# "l’" aucun
# "embouchure" geogFeat
# "," aucun
# "le" aucun
# "marnage" aucun
# "moyen" aucun
# "est" aucun
# "de" aucun
# "2,6" aucun
# "m" aucun
# "en" aucun
# "vive" aucun
# "-" aucun
# "eau" aucun
# "," aucun
# "et" aucun
# "de" aucun
# "1,3" aucun
# "m" aucun
# "en" aucun
# "morte" aucun
# "-" aucun
# "eau" aucun
# "." aucun
# "À" aucun
# "Saint-Laurent" geogName name
# "," aucun
# "ces" aucun
# "valeurs" aucun
# "sont" aucun
# "respectivement" aucun
# "de" aucun
# "2" aucun
# "m" aucun
# "et" aucun
# "de" aucun
# "0,9" aucun
# "m." aucun
# "13" aucun
# "ÎLES" geogFeat geogName
# "DU" geogName
# "SALUT" geogName name
# "." aucun
# "—" aucun
# "Les" aucun
# "îles" geogFeat geogName
# "du" geogName
# "Salut" geogName name
# "(" aucun
# "§" aucun
# "6.2.6.1" aucun
# "." aucun
# ")" aucun
# "," aucun
# "en" aucun
# "Guyane" geogName name
# "," aucun
# "sont" aucun
# "un" aucun
# "port" geogFeat
# "principal" geogFeat
# "de" aucun
# "l’" aucun
# "Annuaire" aucun
# "des" aucun
# "marées" aucun
# "," aucun
# "tome" aucun
# "2" aucun
# ":" aucun
# "Ports" geogFeat
# "d’" aucun
# "outre-mer" aucun
# "." aucun
# "Le" aucun
# "marnage" aucun
# "moyen" aucun
# "est" aucun
# "de" aucun
# "2,1" aucun
# "m" aucun
# "en" aucun
# "vive" aucun
# "-" aucun
# "eau" aucun
# "et" aucun
# "de" aucun
# "1,1" aucun
# "m" aucun
# "en" aucun
# "morte" aucun
# "-" aucun
# "eau" aucun
# "." aucun
# "Le" aucun
# "niveau" aucun
# "moyen" aucun
# "est" aucun
# "à" aucun
# "2,04" aucun
# "m." aucun
# "La" aucun
# "hauteur" aucun
# "de" aucun
# "la" aucun
# "basse" aucun
# "mer" aucun
# "moyenne" aucun
# "de" aucun
# "vive" aucun
# "-" aucun
# "eau" aucun
# "est" aucun
# "de" aucun
# "1" aucun
# "m." aucun
# "19" aucun
# "CÔTES" geogFeat geogName
# "DU" geogName
# "SURINAM" geogName name
# "." aucun
# "—" aucun
# "La" aucun
# "marée" aucun
# "est" aucun
# "de" aucun
# "type" aucun
# "semi-diurne" aucun
# "." aucun
# "Le" aucun
# "marnage" aucun
# "moyen" aucun
# "de" aucun
# "vive" aucun
# "-" aucun
# "eau" aucun
# "est" aucun
# "d’" aucun
# "environ" aucun
# "2" aucun
# "à" aucun
# "3" aucun
# "m." aucun
# "25" aucun
# "Dans" aucun
# "l’" aucun
# "entrée" geogFeat
# "de" aucun
# "Corentyn" geogName name
# "River" geogFeat geogName
# "," aucun
# "le" aucun
# "marnage" aucun
# "moyen" aucun
# "est" aucun
# "de" aucun
# "3,2" aucun
# "m" aucun
# "en" aucun
# "vive" aucun
# "-" aucun
# "eau" aucun
# "et" aucun
# "de" aucun
# "2,2" aucun
# "m" aucun
# "en" aucun
# "morte" aucun
# "-" aucun
# "eau" aucun
# "." aucun
# "01" aucun
# "3.2.1.3" aucun
# "." aucun
# "Grande" geogName name
# "Passe" geogFeat geogName
# "et" aucun
# "lagon" geogFeat
# "07" aucun
# "La" aucun
# "Grande" geogName name
# "Passe" geogFeat geogName
# "(" aucun
# "9" aucun
# "°" aucun
# "22,20" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "14,48" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "," aucun
# "entre" aucun
# "l’" aucun
# "île" geogFeat geogName
# "Picard" geogName name
# "et" aucun
# "Polymnie" geogName name
# "," aucun
# "est" aucun
# "le" aucun
# "seul" aucun
# "accès" geogFeat
# "du" aucun
# "lagon" geogFeat
# "praticable" aucun
# "par" aucun
# "les" aucun
# "navires" aucun
# "." aucun
# "13" aucun
# "Le" aucun
# "chenal" geogFeat
# "," aucun
# "large" aucun
# "d’" aucun
# "environ" aucun
# "0,1" aucun
# "M" aucun
# "," aucun
# "est" aucun
# "bordé" aucun
# "par" aucun
# "des" aucun
# "récifs" geogFeat
# "découvrants" geogFeat
# "." aucun
# "Les" aucun
# "profondeurs" aucun
# "sont" aucun
# "de" aucun
# "22" aucun
# "m" aucun
# "à" aucun
# "l’" aucun
# "entrée" geogFeat
# "de" aucun
# "la" aucun
# "passe" geogFeat
# "et" aucun
# "de" aucun
# "9,9" aucun
# "m" aucun
# "à" aucun
# "1,5" aucun
# "M" aucun
# "au" aucun
# "SSE" aucun
# "dans" aucun
# "la" aucun
# "passe" geogFeat
# "." aucun
# "Ensuite" aucun
# "," aucun
# "un" aucun
# "récif" geogFeat
# "divise" aucun
# "le" aucun
# "chenal" geogFeat
# "en" aucun
# "deux" aucun
# "branches" geogFeat
# "relativement" aucun
# "profondes" aucun
# "," aucun
# "mais" aucun
# "ayant" aucun
# "chacune" aucun
# "une" aucun
# "largeur" aucun
# "de" aucun
# "moins" aucun
# "de" aucun
# "100" aucun
# "m." aucun
# "La" aucun
# "branche" geogFeat geogName
# "SW" geogName name
# "permet" aucun
# "aux" aucun
# "petits" aucun
# "navires" aucun
# "d’" aucun
# "aller" aucun
# "mouiller" aucun
# "près" aucun
# "de" aucun
# "l’" aucun
# "île" geogFeat geogName
# "Esprit" geogName name
# "(" aucun
# "9" aucun
# "°" aucun
# "25,65" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "15,00" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "située" aucun
# "dans" aucun
# "la" aucun
# "partie" aucun
# "Ouest" aucun
# "du" aucun
# "lagon" geogFeat
# "." aucun
# "19" aucun
# "Le" aucun
# "lagon" geogFeat
# "intérieur" geogFeat
# "," aucun
# "peu" aucun
# "profond" aucun
# "," aucun
# "est" aucun
# "encombré" aucun
# "par" aucun
# "de" aucun
# "nombreuses" aucun
# "têtes" geogFeat
# "de" geogFeat
# "corail" geogFeat
# "dangereuses" aucun
# "." aucun
# "Ses" aucun
# "rivages" geogFeat
# "sont" aucun
# "envahis" aucun
# "par" aucun
# "une" aucun
# "mangrove" geogFeat
# "dense" aucun
# "dont" aucun
# "la" aucun
# "hauteur" aucun
# "dépasse" aucun
# "20" aucun
# "m" aucun
# "par" aucun
# "endroits" aucun
# "." aucun
# "25" aucun
# "MOUILLAGE" aucun
# "DANS" aucun
# "LE" aucun
# "LAGON" geogFeat
# "." aucun
# "—" aucun
# "Dans" aucun
# "le" aucun
# "chenal" geogFeat
# "de" aucun
# "la" aucun
# "Grande" geogName name
# "Passe" geogFeat geogName
# "," aucun
# "on" aucun
# "peut" aucun
# "mouiller" aucun
# "par" aucun
# "profondeur" aucun
# "de" aucun
# "10" aucun
# "m" aucun
# "," aucun
# "à" aucun
# "environ" aucun
# "1,5" aucun
# "M" aucun
# "de" aucun
# "l’" aucun
# "entrée" geogFeat
# "de" aucun
# "la" aucun
# "passe" geogFeat
# "," aucun
# "en" aucun
# "relevant" aucun
# "l’" aucun
# "extrémité" aucun
# "SE" aucun
# "de" aucun
# "l’" aucun
# "Île" geogFeat geogName
# "Picard" geogName name
# "à" aucun
# "257" aucun
# "°" aucun
# "et" aucun
# "0,4" aucun
# "M." aucun
# "La" aucun
# "tenue" aucun
# "de" aucun
# "l’" aucun
# "ancre" aucun
# "sur" aucun
# "le" aucun
# "fond" aucun
# "est" aucun
# "médiocre" aucun
# "." aucun
# "31" aucun
# "Ce" aucun
# "mouillage" geogFeat
# "," aucun
# "porté" aucun
# "sur" aucun
# "la" aucun
# "carte" aucun
# "et" aucun
# "l’" aucun
# "ENC" aucun
# "(" aucun
# "9" aucun
# "°" aucun
# "23,541" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "15,040" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "," aucun
# "est" aucun
# "bien" aucun
# "abrité" aucun
# "." aucun
# "37" aucun
# "Le" aucun
# "navire" aucun
# "se" aucun
# "trouve" aucun
# "à" aucun
# "0,1" aucun
# "M" aucun
# "du" aucun
# "récif" geogFeat
# "de" aucun
# "chaque" aucun
# "côté" aucun
# "du" aucun
# "chenal" geogFeat
# "." aucun
# "Il" aucun
# "est" aucun
# "conseillé" aucun
# "d’" aucun
# "affourcher" aucun
# "à" aucun
# "cause" aucun
# "de" aucun
# "la" aucun
# "force" aucun
# "des" aucun
# "courants" aucun
# "de" aucun
# "marée" aucun
# "qui" aucun
# "peuvent" aucun
# "dépasser" aucun
# "7" aucun
# "nœuds" aucun
# "." aucun
# "188" aucun
# "ÎLES" geogFeat
# "ET" aucun
# "DANGERS" geogFeat
# "AU" aucun
# "NORD-OUEST" aucun
# "DU" aucun
# "CAP" geogFeat geogName
# "D’" geogName
# "AMBRE" geogName name
# "43" aucun
# "Ce" aucun
# "mouillage" geogFeat
# "a" aucun
# "été" aucun
# "utilisé" aucun
# "par" aucun
# "un" aucun
# "navire" aucun
# "long" aucun
# "de" aucun
# "91" aucun
# "m" aucun
# "et" aucun
# "calant" aucun
# "4,3" aucun
# "m." aucun
# "Pendant" aucun
# "son" aucun
# "séjour" aucun
# "," aucun
# "le" aucun
# "navire" aucun
# "avait" aucun
# "utilisé" aucun
# "ses" aucun
# "machines" aucun
# "pour" aucun
# "soulager" aucun
# "ses" aucun
# "lignes" aucun
# "de" aucun
# "mouillage" aucun
# "et" aucun
# "pour" aucun
# "faciliter" aucun
# "son" aucun
# "évitage" aucun
# "lors" aucun
# "de" aucun
# "la" aucun
# "renverse" aucun
# "." aucun
# "49" aucun
# "INSTRUCTIONS" aucun
# "." aucun
# "—" aucun
# "Il" aucun
# "est" aucun
# "recommandé" aucun
# "d’" aucun
# "entrer" aucun
# "dans" aucun
# "la" aucun
# "Grande" geogName name
# "Passe" geogFeat geogName
# "à" aucun
# "partir" aucun
# "d’" aucun
# "environ" aucun
# "+" aucun
# "0045" aucun
# "BM" aucun
# "en" aucun
# "profitant" aucun
# "de" aucun
# "la" aucun
# "fin" aucun
# "du" aucun
# "courant" aucun
# "sortant" aucun
# "." aucun
# "Il" aucun
# "faut" aucun
# "serrer" aucun
# "le" aucun
# "côté" aucun
# "Ouest" aucun
# "de" aucun
# "la" aucun
# "passe" geogFeat
# "car" aucun
# "l’" aucun
# "extrémité" aucun
# "Ouest" aucun
# "de" aucun
# "Polymnie" geogName name
# "est" aucun
# "débordée" aucun
# "," aucun
# "jusqu’" aucun
# "à" aucun
# "0,2" aucun
# "M" aucun
# "au" aucun
# "NW" aucun
# "," aucun
# "par" aucun
# "un" aucun
# "banc" geogFeat
# "couvert" aucun
# "de" aucun
# "moins" aucun
# "de" aucun
# "10" aucun
# "m" aucun
# "d’" aucun
# "eau" aucun
# "." aucun
# "55" aucun
# "Après" aucun
# "avoir" aucun
# "franchi" aucun
# "l’" aucun
# "entrée" geogFeat
# "," aucun
# "il" aucun
# "faut" aucun
# "suivre" aucun
# "l’" aucun
# "axe" geogFeat
# "du" aucun
# "chenal" geogFeat
# "." aucun
# "Les" aucun
# "récifs" geogFeat
# "de" aucun
# "chaque" aucun
# "côté" aucun
# "sont" aucun
# "généralement" aucun
# "accores" aucun
# "." aucun
# "Les" aucun
# "bordures" aucun
# "du" aucun
# "chenal" geogFeat
# "sont" aucun
# "bien" aucun
# "marquées" aucun
# "," aucun
# "même" aucun
# "à" aucun
# "pleine" aucun
# "mer" aucun
# "," aucun
# "car" aucun
# "les" aucun
# "récifs" geogFeat
# "en" aucun
# "abord" aucun
# "portent" aucun
# "de" aucun
# "nombreux" aucun
# "petits" aucun
# "îlots" geogFeat
# "hauts" aucun
# "d’" aucun
# "environ" aucun
# "5" aucun
# "m" aucun
# "," aucun
# "en" aucun
# "forme" aucun
# "de" aucun
# "champignons" aucun
# "." aucun
# "01" aucun
# "3.2.1.5" aucun
# "." aucun
# "De" aucun
# "Grande" geogName name
# "Terre" geogName name
# "à" aucun
# "l’" aucun
# "île" geogFeat geogName
# "Picard" geogName name
# "07" aucun
# "Grande" geogName name
# "Terre" geogName name
# "(" aucun
# "9" aucun
# "°" aucun
# "27,00" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "22,50" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "est" aucun
# "l’" aucun
# "île" geogFeat
# "qui" aucun
# "constitue" aucun
# "les" aucun
# "parties" aucun
# "Sud" aucun
# "et" aucun
# "Est" aucun
# "de" aucun
# "la" aucun
# "couronne" aucun
# "de" aucun
# "l’" aucun
# "atoll" geogFeat
# "." aucun
# "La" aucun
# "partie" aucun
# "Est" aucun
# "," aucun
# "s’" aucun
# "étendant" aucun
# "jusqu’" aucun
# "à" aucun
# "la" aucun
# "pointe" geogFeat geogName
# "Hodoul" geogName name
# "(" aucun
# "9" aucun
# "°" aucun
# "24,06" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "31,39" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "et" aucun
# "la" aucun
# "côte" geogFeat geogName
# "Sud" geogName name
# "de" aucun
# "Grande" geogName name
# "Terre" geogName name
# "sont" aucun
# "très" aucun
# "dénudées" aucun
# "à" aucun
# "cause" aucun
# "des" aucun
# "projections" aucun
# "de" aucun
# "sable" aucun
# "et" aucun
# "d’" aucun
# "embruns" aucun
# "auxquelles" aucun
# "elles" aucun
# "sont" aucun
# "soumises" aucun
# "pendant" aucun
# "presque" aucun
# "toute" aucun
# "l’" aucun
# "année" aucun
# "." aucun
# "La" aucun
# "côte" geogFeat geogName
# "Sud" geogName name
# "est" aucun
# "bordée" aucun
# "par" aucun
# "une" aucun
# "crête" geogFeat
# "(" aucun
# "9" aucun
# "°" aucun
# "26,982" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "23,536" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "de" aucun
# "sable" aucun
# "et" aucun
# "de" aucun
# "gravier" aucun
# "de" aucun
# "15" aucun
# "m" aucun
# "édifiée" aucun
# "par" aucun
# "les" aucun
# "vagues" aucun
# "." aucun
# "13" aucun
# "L’" aucun
# "île" geogFeat geogName
# "Michel" geogName name
# "(" aucun
# "9" aucun
# "°" aucun
# "24,65" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "26,68" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "est" aucun
# "située" aucun
# "à" aucun
# "l’" aucun
# "Est" aucun
# "de" aucun
# "Grande" geogName name
# "Terre" geogName name
# "," aucun
# "côté" aucun
# "lagon" geogFeat
# "." aucun
# "19" aucun
# "Les" aucun
# "West" geogName name
# "Channels" geogFeat geogName
# "(" aucun
# "9" aucun
# "°" aucun
# "24,69" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "12,43" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "," aucun
# "entre" aucun
# "Grande" geogName name
# "Terre" geogName name
# "et" aucun
# "l’" aucun
# "île" geogFeat geogName
# "Picard" geogName name
# "," aucun
# "sont" aucun
# "des" aucun
# "chenaux" geogFeat
# "étroits" aucun
# "qui" aucun
# "assèchent" aucun
# "à" aucun
# "la" aucun
# "basse" aucun
# "mer" aucun
# "passant" aucun
# "à" aucun
# "travers" aucun
# "différents" aucun
# "îlots" geogFeat
# ":" aucun
# "–" aucun
# "Au" aucun
# "nord" aucun
# ":" aucun
# "îlot" geogFeat geogName
# "Parc" geogName name
# "," aucun
# "îlot" geogFeat geogName
# "Emile" geogName name
# "et" aucun
# "îlot" geogFeat geogName
# "Yangue" geogName name
# ";" aucun
# "–" aucun
# "Au" aucun
# "Sud" aucun
# ":" aucun
# "îlot" geogFeat geogName
# "Dubois" geogName name
# "," aucun
# "île" geogFeat geogName
# "Magnan" geogName name
# "et" aucun
# "île" geogFeat geogName
# "Lanier" geogName name
# "." aucun
# "25" aucun
# "Les" aucun
# "îles" geogFeat geogName
# "Chaland" geogName name
# "(" aucun
# "9" aucun
# "°" aucun
# "25,13" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "13,60" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "," aucun
# "l’" aucun
# "île" geogFeat geogName
# "Esprit" geogName name
# "(" aucun
# "9" aucun
# "°" aucun
# "25,65" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "15,00" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "et" aucun
# "l’" aucun
# "île" geogFeat geogName
# "Moustiques" geogName name
# "(" aucun
# "9" aucun
# "°" aucun
# "26,29" aucun
# "'" aucun
# "S" aucun
# "—" aucun
# "46" aucun
# "°" aucun
# "14,23" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "sont" aucun
# "situées" aucun
# "à" aucun
# "l’" aucun
# "Ouest" aucun
# "de" aucun
# "Grande" geogName name
# "Terre" geogName name
# "du" aucun
# "côté" aucun
# "lagon" geogFeat
# "." aucun
# "31" aucun
# "MOUILLAGE" aucun
# "." aucun
# "—" aucun
# "On" aucun
# "peut" aucun
# "mouiller" aucun
# "sur" aucun
# "le" aucun
# "banc" geogFeat
# "qui" aucun
# "déborde" aucun
# "à" aucun
# "l’" aucun
# "Est" aucun
# "de" aucun
# "la" aucun
# "Pointe" geogFeat geogName
# "Hodoul" geogName name
# "." aucun
# "Il" aucun
# "est" aucun
# "conseillé" aucun
# "de" aucun
# "mouiller" aucun
# "par" aucun
# "profondeur" aucun
# "de" aucun
# "plus" aucun
# "de" aucun
# "18" aucun
# "m" aucun
# "," aucun
# "à" aucun
# "environ" aucun
# "0,6" aucun
# "M" aucun
# "du" aucun
# "rivage" geogFeat
# "," aucun
# "car" aucun
# "le" aucun
# "fond" aucun
# "est" aucun
# "irrégulier" aucun
# "." aucun
# "37" aucun
# "Cette" aucun
# "zone" geogFeat
# "de" geogFeat
# "mouillage" geogFeat
# "est" aucun
# "relativement" aucun
# "bien" aucun
# "abritée" aucun
# "pendant" aucun
# "la" aucun
# "mousson" aucun
# "de" aucun
# "NW" aucun
# "." aucun
# "Mais" aucun
# "la" aucun
# "mer" aucun
# "se" aucun
# "creuse" aucun
# "rapidement" aucun
# "dès" aucun
# "que" aucun
# "le" aucun
# "vent" aucun
# "tourne" aucun
# "au" aucun
# "SE" aucun
# "." aucun
# "01" aucun
# "3.7.2.7" aucun
# "." aucun
# "Ravitaillement" aucun
# "." aucun
# "Réparations" aucun
# "07" aucun
# "Il" aucun
# "n’" aucun
# "est" aucun
# "pas" aucun
# "possible" aucun
# "de" aucun
# "se" aucun
# "ravitailler" aucun
# "en" aucun
# "eau" aucun
# "ou" aucun
# "en" aucun
# "combustible" aucun
# ";" aucun
# "en" aucun
# "cas" aucun
# "de" aucun
# "nécessité" aucun
# "," aucun
# "les" aucun
# "navires" aucun
# "doivent" aucun
# "se" aucun
# "rendre" aucun
# "à" aucun
# "Lomé" geogName name
# "." aucun
# "À" aucun
# "Kpémé" geogName name
# "," aucun
# "on" aucun
# "peut" aucun
# "se" aucun
# "procurer" aucun
# "de" aucun
# "faibles" aucun
# "quantités" aucun
# "de" aucun
# "vivres" aucun
# "frais" aucun
# ";" aucun
# "ils" aucun
# "sont" aucun
# "chers" aucun
# "et" aucun
# "de" aucun
# "qualité" aucun
# "moyenne" aucun
# "." aucun
# "13" aucun
# "Les" aucun
# "petites" aucun
# "réparations" aucun
# "urgentes" aucun
# "doivent" aucun
# "se" aucun
# "traiter" aucun
# "avec" aucun
# "les" aucun
# "ateliers" geogFeat geogName
# "de" geogName
# "Lomé" geogName name
# "." aucun
# "01" aucun
# "2.2.1.1" aucun
# "." aucun
# "Dimensions" aucun
# "07" aucun
# "La" aucun
# "longueur" aucun
# "de" aucun
# "la" aucun
# "Manche" geogName name
# "est" aucun
# "d’" aucun
# "environ" aucun
# "280" aucun
# "M" aucun
# "entre" aucun
# "le" aucun
# "Pas" geogFeat geogName
# "de" geogName
# "Calais" geogName name
# "," aucun
# "sur" aucun
# "la" aucun
# "ligne" geogFeat
# "Dover" geogName name
# "–" aucun
# "cap" geogFeat geogName
# "Gris" geogName name
# "-" geogName name
# "Nez" geogName name
# "," aucun
# "et" aucun
# "la" aucun
# "ligne" geogFeat
# "Land’" geogName name
# "s" geogName name
# "End" geogName name
# "–" aucun
# "Île" geogFeat geogName
# "Vierge" geogName name
# "." aucun
# "Sa" aucun
# "largeur" aucun
# "utile" aucun
# "est" aucun
# "de" aucun
# "18" aucun
# "M" aucun
# "seulement" aucun
# "dans" aucun
# "le" aucun
# "Pas-de-Calais" geogName name
# "," aucun
# "sur" aucun
# "la" aucun
# "ligne" geogFeat
# "Dover" geogName name
# "–" aucun
# "cap" geogFeat geogName
# "Gris" geogName name
# "-" geogName name
# "Nez" geogName name
# "." aucun
# "Elle" aucun
# "est" aucun
# "de" aucun
# "48" aucun
# "M" aucun
# "en" aucun
# "son" aucun
# "milieu" aucun
# "," aucun
# "sur" aucun
# "la" aucun
# "ligne" geogFeat
# "Portland" geogName name
# "–" aucun
# "Les" geogName name
# "Casquets" geogName name
# "et" aucun
# "de" aucun
# "95" aucun
# "M" aucun
# "entre" aucun
# "Land’" geogName name
# "s" geogName name
# "End" geogName name
# "et" aucun
# "l’" aucun
# "Île" geogFeat geogName
# "Vierge" geogName name
# "." aucun
# "01" aucun
# "4.6.3" aucun
# "." aucun
# "De" aucun
# "Ras" geogFeat geogName
# "Magroua" geogName name
# "à" aucun
# "Ténès" geogName name
# "01" aucun
# "8.3.2.4" aucun
# "." aucun
# "Pilotage" aucun
# "07" aucun
# "Le" aucun
# "pilotage" aucun
# "," aucun
# "assuré" aucun
# "jour" aucun
# "et" aucun
# "nuit" aucun
# "," aucun
# "est" aucun
# "obligatoire" aucun
# "pour" aucun
# "tous" aucun
# "les" aucun
# "navires" aucun
# "et" aucun
# "pour" aucun
# "tout" aucun
# "mouvement" aucun
# "dans" aucun
# "la" aucun
# "zone" geogFeat
# "portée" aucun
# "sur" aucun
# "la" aucun
# "carte" aucun
# "," aucun
# "exception" aucun
# "faite" aucun
# ":" aucun
# "–" aucun
# "des" aucun
# "navires" aucun
# "de" aucun
# "guerre" aucun
# "djiboutiens" aucun
# ";" aucun
# "–" aucun
# "des" aucun
# "navires" aucun
# "d’" aucun
# "État" aucun
# "étrangers" aucun
# "affectés" aucun
# "à" aucun
# "des" aucun
# "services" aucun
# "non" aucun
# "commerciaux" aucun
# "dans" aucun
# "les" aucun
# "cas" aucun
# "où" aucun
# "ces" aucun
# "services" aucun
# "sont" aucun
# "prévus" aucun
# "par" aucun
# "des" aucun
# "accords" aucun
# "bilatéraux" aucun
# "en" aucun
# "vigueur" aucun
# ";" aucun
# "–" aucun
# "des" aucun
# "navires" aucun
# "de" aucun
# "moins" aucun
# "de" aucun
# "40" aucun
# "m" aucun
# "de" aucun
# "longueur" aucun
# "hors" aucun
# "tout" aucun
# "." aucun
# "13" aucun
# "Les" aucun
# "navires" aucun
# "doivent" aucun
# "contacter" aucun
# "Djibouti" geogName name
# "Port" geogFeat
# "Control" aucun
# "," aucun
# "2" aucun
# "h" aucun
# "avant" aucun
# "dʼarriver" aucun
# "à" aucun
# "la" aucun
# "position" geogFeat
# "dʼembarquement" geogFeat
# "du" geogFeat
# "pilote" geogFeat
# "." aucun
# "Les" aucun
# "navires" aucun
# "doivent" aucun
# "également" aucun
# "assurer" aucun
# "une" aucun
# "veille" aucun
# "permanente" aucun
# "sur" aucun
# "VHF" aucun
# "à" aucun
# "partir" aucun
# "du" aucun
# "moment" aucun
# "où" aucun
# "ils" aucun
# "relèvent" aucun
# "le" aucun
# "phare" geogFeat geogName
# "de" geogName
# "l’" geogName
# "Île" geogFeat geogName
# "Maskali" geogName name
# "par" aucun
# "le" aucun
# "travers" aucun
# "et" aucun
# "pendant" aucun
# "leur" aucun
# "séjour" aucun
# "au" aucun
# "port" geogFeat
# "." aucun
# "Voir" aucun
# "l’" aucun
# "ouvrage" aucun
# "de" aucun
# "Radiosignaux" aucun
# "932" aucun
# "," aucun
# "radiocommunications" aucun
# "portuaires" aucun
# "(" aucun
# "Mer" geogFeat geogName
# "Méditerranée" geogName name
# "-" aucun
# "Océans" geogFeat geogName
# "Indien" geogName name
# "," geogName
# "Pacifique" geogName name
# "et" geogName
# "Austral" geogName name
# ")" aucun
# "." aucun
# "2044" aucun
# "19" aucun
# "Le" aucun
# "pilote" aucun
# "embarque" aucun
# "aux" aucun
# "positions" aucun
# "suivantes" aucun
# ":" aucun
# "–" aucun
# "pour" aucun
# "le" aucun
# "port" geogFeat
# ":" aucun
# "à" aucun
# "0,47" aucun
# "M" aucun
# "à" aucun
# "l’" aucun
# "Est" aucun
# "de" aucun
# "la" aucun
# "bouée" geogFeat geogName
# "«" geogName
# "1" geogName name
# "»" geogName
# "à" aucun
# "la" aucun
# "position" aucun
# "11" aucun
# "°" aucun
# "38,34" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "43" aucun
# "°" aucun
# "07,77" aucun
# "'" aucun
# "E" aucun
# ";" aucun
# "–" aucun
# "pour" aucun
# "les" aucun
# "Terminaux" geogFeat
# "de" aucun
# "Doraleh" geogName name
# "oil" geogFeat geogName
# "terminal" geogFeat geogName
# "(" aucun
# "DOT" aucun
# ")" aucun
# "," aucun
# "Doraleh" geogName name
# "container" geogFeat geogName
# "terminal" geogFeat geogName
# "(" aucun
# "DCT" aucun
# ")" aucun
# "et" aucun
# "Doraleh" geogName name
# "multipurpose" geogName name
# "(" aucun
# "DMP" aucun
# ")" aucun
# "," aucun
# "dans" aucun
# "l’" aucun
# "Ouest" aucun
# "du" aucun
# "Banc" geogFeat geogName
# "El" geogName
# "Hadj" geogName name
# "à" aucun
# "la" aucun
# "position" aucun
# "11" aucun
# "°" aucun
# "38,5" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "43" aucun
# "°" aucun
# "03,2" aucun
# "'" aucun
# "E." aucun
# "2044" aucun
# "01" aucun
# "4.6.4.7" aucun
# "." aucun
# "Données" aucun
# "portuaires" aucun
# "de" aucun
# "Ténès" geogName name
# "07" aucun
# "Caractéristiques" aucun
# "nautiques" aucun
# "Météorologie" aucun
# "locale" aucun
# "Rade" geogFeat
# "exposée" aucun
# "aux" aucun
# "vents" aucun
# "du" aucun
# "quadrant" aucun
# "NW" aucun
# "." aucun
# "Par" aucun
# "mauvais" aucun
# "temps" aucun
# "," aucun
# "entrée" aucun
# "au" aucun
# "port" geogFeat
# "difficile" aucun
# "pour" aucun
# "les" aucun
# "grands" aucun
# "navires" aucun
# "et" aucun
# "mer" aucun
# "brisant" aucun
# "loin" aucun
# "du" aucun
# "rivage" geogFeat
# "." aucun
# "Par" aucun
# "vent" aucun
# "d’" aucun
# "Est" aucun
# "," aucun
# "violentes" aucun
# "rafales" aucun
# "descendant" aucun
# "des" aucun
# "hauteurs" aucun
# "dominant" aucun
# "le" aucun
# "port" geogFeat
# "." aucun
# "Installations" geogFeat
# "portuaires" geogFeat
# "Navires" aucun
# "admis" aucun
# "L" aucun
# ":" aucun
# "136" aucun
# "m." aucun
# "T" aucun
# ":" aucun
# "7,3" aucun
# "m." aucun
# "D" aucun
# ":" aucun
# "8" aucun
# "000" aucun
# "t." aucun
# "37" aucun
# "navires" aucun
# "par" aucun
# "an" aucun
# "." aucun
# "182" aucun
# "000" aucun
# "tonnes" aucun
# "par" aucun
# "an" aucun
# "." aucun
# "Entrée" aucun
# "délicate" aucun
# "aux" aucun
# "grands" aucun
# "navires" aucun
# "." aucun
# "Remorquage" aucun
# "1" aucun
# "remorqueur" aucun
# "." aucun
# "Obligatoire" aucun
# "pour" aucun
# "les" aucun
# "navires" aucun
# "de" aucun
# "jauge" aucun
# "brute" aucun
# "supérieure" aucun
# "à" aucun
# "500" aucun
# "tonneaux" aucun
# "." aucun
# "Infrastructures" geogFeat
# "Jetée" geogFeat geogName
# "Ouest" geogName name
# ":" aucun
# "Long" aucun
# "." aucun
# "400" aucun
# "m." aucun
# "Prof" aucun
# "." aucun
# "de" aucun
# "5" aucun
# "(" aucun
# "au" aucun
# "Sud" aucun
# ")" aucun
# "à" aucun
# "7,2" aucun
# "m" aucun
# "(" aucun
# "au" aucun
# "Nord" aucun
# ")" aucun
# "." aucun
# "Poste" geogFeat
# "roulier" geogFeat
# "au" aucun
# "NW" aucun
# "du" aucun
# "môle" geogFeat
# "." aucun
# "Quai" geogFeat geogName
# "Sud" geogName name
# ":" aucun
# "nouveau" geogName name
# "môle" geogFeat geogName
# "en" aucun
# "service" aucun
# "en" aucun
# "2013" aucun
# "." aucun
# "Long" aucun
# "." aucun
# "200" aucun
# "m." aucun
# "Poste" geogFeat
# "roulier" geogFeat
# "T" aucun
# ":" aucun
# "6" aucun
# "m." aucun
# "Quai" geogFeat geogName
# "Long" geogName name
# "." aucun
# "200" aucun
# "m." aucun
# "Port" geogFeat
# "de" geogFeat
# "pêche" geogFeat
# "au" aucun
# "NE" aucun
# "du" aucun
# "bassin" geogFeat
# "portuaire" geogFeat
# "." aucun
# "Outillage" aucun
# "2" aucun
# "tours" geogFeat
# "de" geogFeat
# "chargement" geogFeat
# "de" geogFeat
# "céréales" geogFeat
# "." aucun
# "Ravitaillement" aucun
# "Eau" aucun
# "aux" aucun
# "postes" geogFeat
# "du" aucun
# "Môle" geogFeat geogName
# "Commercial" geogName name
# "." aucun
# "Pas" aucun
# "de" aucun
# "carburants" aucun
# "." aucun
# "Vivres" aucun
# "frais" aucun
# "." aucun
# "Organisation" aucun
# "Communications" aucun
# "Liaison" aucun
# "ferroviaire" aucun
# "." aucun
# "Aéroport" geogFeat
# "le" aucun
# "plus" aucun
# "proche" aucun
# "," aucun
# "Alger" geogName name
# "à" aucun
# "environ" aucun
# "250" aucun
# "km" aucun
# "." aucun
# "Ville" geogFeat
# "35" aucun
# "000" aucun
# "habitants" aucun
# "." aucun
# "Hôpital" geogFeat
# "." aucun
# "4.6.4.7" aucun
# "." aucun
# "—" aucun
# "Données" aucun
# "portuaires" aucun
# "du" aucun
# "port" geogFeat geogName
# "de" geogName
# "Ténès" geogName name
# "(" aucun
# "35" aucun
# "°" aucun
# "31,8" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "0" aucun
# "°" aucun
# "18,8" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "." aucun
# "extrait" aucun
# "le" aucun
# ":" aucun
# "2021" aucun
# "-" aucun
# "10" aucun
# "-" aucun
# "12" aucun
# "—" aucun
# "généré" aucun
# "le" aucun
# ":" aucun
# "2021" aucun
# "-" aucun
# "10" aucun
# "-" aucun
# "13" aucun
# "–" aucun
# "page" aucun
# "183" aucun
# "/" aucun
# "0" aucun
# "183" aucun
# "DE" aucun
# "LA" aucun
# "FRONTIÈRE" geogFeat geogName
# "DU" geogName
# "MAROC" geogName name
# "À" aucun
# "ALGER" geogName name
# "01" aucun
# "3.3.3.1" aucun
# "." aucun
# "Généralités" aucun
# "07" aucun
# "Le" aucun
# "port" geogFeat geogName
# "de" geogFeat geogName
# "plaisance" geogFeat geogName
# "de" geogName
# "Cavallo" geogName name
# "est" aucun
# "situé" aucun
# "dans" aucun
# "l’" aucun
# "anse" geogFeat geogName
# "Marine" geogName name
# "du" aucun
# "village" geogFeat
# "," aucun
# "la" aucun
# "plus" aucun
# "Sud" aucun
# "de" aucun
# "l’" aucun
# "île" geogFeat
# "et" aucun
# "la" aucun
# "moins" aucun
# "exposée" aucun
# "aux" aucun
# "houles" aucun
# "." aucun
# "Il" aucun
# "est" aucun
# "établi" aucun
# "à" aucun
# "l’" aucun
# "abri" aucun
# "d’" aucun
# "une" aucun
# "jetée" geogFeat
# "en" aucun
# "enrochements" aucun
# "coudée" aucun
# "vers" aucun
# "le" aucun
# "SW" aucun
# "." aucun
# "01" aucun
# "6.1.2" aucun
# "." aucun
# "Météorologie" aucun
# "07" aucun
# "Dans" aucun
# "cette" aucun
# "région" geogFeat
# "," aucun
# "les" aucun
# "vents" aucun
# "dominants" aucun
# "soufflent" aucun
# "du" aucun
# "NE" aucun
# "au" aucun
# "printemps" aucun
# "," aucun
# "et" aucun
# "de" aucun
# "l’" aucun
# "Est" aucun
# "en" aucun
# "automne" aucun
# "." aucun
# "Ils" aucun
# "dépassent" aucun
# "rarement" aucun
# "le" aucun
# "degré" aucun
# "5" aucun
# "de" aucun
# "l’" aucun
# "échelle" aucun
# "Beaufort" aucun
# "." aucun
# "Leur" aucun
# "vitesse" aucun
# "moyenne" aucun
# "se" aucun
# "situe" aucun
# "entre" aucun
# "6" aucun
# "et" aucun
# "10" aucun
# "nœuds" aucun
# "." aucun
# "Pendant" aucun
# "la" aucun
# "journée" aucun
# "," aucun
# "le" aucun
# "vent" aucun
# "atteint" aucun
# "sa" aucun
# "force" aucun
# "maximale" aucun
# "vers" aucun
# "14" aucun
# "h" aucun
# "00" aucun
# "." aucun
# "La" aucun
# "force" aucun
# "moyenne" aucun
# "du" aucun
# "vent" aucun
# "augmente" aucun
# "depuis" aucun
# "le" aucun
# "milieu" aucun
# "de" aucun
# "l’" aucun
# "été" aucun
# "jusqu’" aucun
# "à" aucun
# "la" aucun
# "fin" aucun
# "de" aucun
# "l’" aucun
# "hiver" aucun
# "," aucun
# "puis" aucun
# "elle" aucun
# "décroît" aucun
# "depuis" aucun
# "le" aucun
# "début" aucun
# "du" aucun
# "printemps" aucun
# "jusqu’" aucun
# "au" aucun
# "début" aucun
# "de" aucun
# "l’" aucun
# "été" aucun
# "." aucun
# "13" aucun
# "Les" aucun
# "variations" aucun
# "saisonnières" aucun
# "de" aucun
# "la" aucun
# "température" aucun
# "sont" aucun
# "faibles" aucun
# "," aucun
# "d’" aucun
# "environ" aucun
# "2" aucun
# "ou" aucun
# "3" aucun
# "°" aucun
# "C" aucun
# "au" aucun
# "cours" aucun
# "de" aucun
# "l’" aucun
# "année" aucun
# "." aucun
# "19" aucun
# "Les" aucun
# "dates" aucun
# "et" aucun
# "les" aucun
# "débuts" aucun
# "de" aucun
# "la" aucun
# "saison" aucun
# "des" aucun
# "pluies" aucun
# "sont" aucun
# "variables" aucun
# "d’" aucun
# "une" aucun
# "région" geogFeat
# "à" aucun
# "l’" aucun
# "autre" aucun
# "." aucun
# "Elles" aucun
# "sont" aucun
# "précisées" aucun
# "dans" aucun
# "le" aucun
# "texte" aucun
# "." aucun
# "25" aucun
# "Dans" aucun
# "l’" aucun
# "Atlantique" geogName name
# "Nord" geogName name
# "," aucun
# "les" aucun
# "perturbations" aucun
# "cycloniques" aucun
# ...
# "large" aucun
# "," aucun
# "4" aucun
# "m" aucun
# "de" aucun
# "TE" aucun
# "en" aucun
# "VE" aucun
# "et" aucun
# "2" aucun
# "m" aucun
# "de" aucun
# "TE" aucun
# "en" aucun
# "ME" aucun
# "." aucun
# "500" aucun
# "m" aucun
# "de" aucun
# "quais" geogFeat
# "bordés" aucun
# "d’" aucun
# "appontements" geogFeat
# "privés" geogFeat
# "sur" aucun
# "les" aucun
# "2" aucun
# "rives" geogFeat
# "de" aucun
# "l’" aucun
# "étier" geogFeat
# "jusqu’" aucun
# "au" aucun
# "vannes" geogFeat
# "du" aucun
# "déversoir" geogFeat
# "." aucun
# "Administration" aucun
# "Régie" aucun
# "municipale" aucun
# "." aucun
# "Mairie" geogFeat geogName
# "de" geogName
# "Bouin" geogName name
# ";" aucun
# "tél" aucun
# "." aucun
# ":" aucun
# "02.51.49.74.14" aucun
# ";" aucun
# "télécopie" aucun
# ":" aucun
# "02.51.68.60.00" aucun
# ";" aucun
# "mél" aucun
# ":" aucun
# "mairie.de.bouin@wanadoo.fr" aucun
# "5.4.8.4" aucun
# "." aucun
# "—" aucun
# "Port" geogFeat geogName
# "des" geogName
# "Champs" geogName name
# "(" aucun
# "46" aucun
# "°" aucun
# "58,12" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "2" aucun
# "°" aucun
# "02,71" aucun
# "'" aucun
# "W" aucun
# ")" aucun
# "." aucun
# "Organisation" aucun
# "01" aucun
# "6.1.2.1" aucun
# "." aucun
# "Climat" aucun
# "en" aucun
# "Guyane" geogName name
# "07" aucun
# "Le" aucun
# "climat" aucun
# "de" aucun
# "la" aucun
# "Guyane" geogName name
# "est" aucun
# "équatorial" aucun
# "humide" aucun
# "," aucun
# "avec" aucun
# "alternance" aucun
# "de" aucun
# "saisons" aucun
# "sèches" aucun
# "et" aucun
# "de" aucun
# "saisons" aucun
# "humides" aucun
# ":" aucun
# "la" aucun
# "petite" aucun
# "saison" aucun
# "des" aucun
# "pluies" aucun
# "de" aucun
# "la" aucun
# "mi-décembre" aucun
# "à" aucun
# "février" aucun
# ";" aucun
# "la" aucun
# "petite" aucun
# "saison" aucun
# "sèche" aucun
# "en" aucun
# "mars" aucun
# ";" aucun
# "la" aucun
# "grande" aucun
# "saison" aucun
# "des" aucun
# "pluies" aucun
# "de" aucun
# "la" aucun
# "fin" aucun
# "-" aucun
# "mars" aucun
# "à" aucun
# "juin" aucun
# ";" aucun
# "et" aucun
# "la" aucun
# "grande" aucun
# "saison" aucun
# "sèche" aucun
# "de" aucun
# "juillet" aucun
# "à" aucun
# "la" aucun
# "mi-décembre" aucun
# "." aucun
# "Cette" aucun
# "alternance" aucun
# "est" aucun
# "réglée" aucun
# "par" aucun
# "les" aucun
# "déplacements" aucun
# "de" aucun
# "zone" geogFeat
# "intertropicale" geogFeat
# "de" geogFeat
# "convergence" geogFeat
# "(" aucun
# "ZITC" geogFeat
# ")" aucun
# "." aucun
# "La" aucun
# "pluviométrie" aucun
# "annuelle" aucun
# "moyenne" aucun
# "est" aucun
# "d’" aucun
# "environ" aucun
# "3" aucun
# "000" aucun
# "mm" aucun
# "." aucun
# "13" aucun
# "La" aucun
# "température" aucun
# "moyenne" aucun
# "est" aucun
# "de" aucun
# "26" aucun
# "°" aucun
# "C" aucun
# "," aucun
# "avec" aucun
# "un" aucun
# "minimum" aucun
# "de" aucun
# "18" aucun
# "°" aucun
# "C" aucun
# "et" aucun
# "un" aucun
# "maximum" aucun
# "de" aucun
# "36" aucun
# "°" aucun
# "C" aucun
# "pendant" aucun
# "la" aucun
# "grande" aucun
# "saison" aucun
# "sèche" aucun
# "." aucun
# "L’" aucun
# "humidité" aucun
# "relative" aucun
# "moyenne" aucun
# "est" aucun
# "proche" aucun
# "de" aucun
# "85" aucun
# "%" aucun
# ";" aucun
# "elle" aucun
# "culmine" aucun
# "à" aucun
# "95" aucun
# "%" aucun
# "pendant" aucun
# "la" aucun
# "grande" aucun
# "saison" aucun
# "des" aucun
# "pluies" aucun
# "." aucun
# "19" aucun
# "Les" aucun
# "vents" aucun
# "sont" aucun
# "modérés" aucun
# "." aucun
# "L’" aucun
# "alizé" aucun
# "de" aucun
# "Nord-Est" aucun
# "souffle" aucun
# "pendant" aucun
# "la" aucun
# "moitié" aucun
# "de" aucun
# "l’" aucun
# "année" aucun
# "." aucun
# "La" aucun
# "vitesse" aucun
# "maximale" aucun
# "enre" aucun
# "gistrée" aucun
# "par" aucun
# "le" aucun
# "Centre" geogFeat
# "Spatial" aucun
# "Guyanais" aucun
# "depuis" aucun
# "sa" aucun
# "création" aucun
# "a" aucun
# "été" aucun
# "de" aucun
# "46" aucun
# "nœuds" aucun
# "." aucun
# "01" aucun
# "2.1.4.1" aucun
# "." aucun
# "Protection" aucun
# "des" aucun
# "écosystèmes" aucun
# "sous-marins" aucun
# "07" aucun
# "Les" aucun
# "fonds" aucun
# "marins" aucun
# "bordant" aucun
# "les" aucun
# "côtes" geogFeat
# "décrites" aucun
# "dans" aucun
# "ce" aucun
# "chapitre" aucun
# "peuvent" aucun
# "abriter" aucun
# "," aucun
# "jusqu’" aucun
# "à" aucun
# "une" aucun
# "profondeur" aucun
# "d’" aucun
# "environ" aucun
# "120" aucun
# "m" aucun
# "," aucun
# "des" aucun
# "écosystèmes" aucun
# "appelés" aucun
# "biocénoses" aucun
# "composés" aucun
# "d’" aucun
# "espèces" aucun
# "protégées" aucun
# "(" aucun
# "posidonies" aucun
# "," aucun
# "cymodocées" aucun
# "et" aucun
# "coralligènes" aucun
# ")" aucun
# "." aucun
# "13" aucun
# "Il" aucun
# "importe" aucun
# "de" aucun
# "ne" aucun
# "pas" aucun
# "mouiller" aucun
# "dans" aucun
# "les" aucun
# "zones" geogFeat
# "occupées" aucun
# "par" aucun
# "ces" aucun
# "espèces" aucun
# "protégées" aucun
# "(" aucun
# "voir" aucun
# "§" aucun
# "1.5.2" aucun
# "." aucun
# ")" aucun
# "." aucun
# "01" aucun
# "2.1.1" aucun
# "." aucun
# "Environnement" aucun
# "07" aucun
# "Entre" aucun
# "la" aucun
# "frontière" geogFeat geogName
# "espagnole" geogName name
# "immédiatement" aucun
# "au" aucun
# "Sud" aucun
# "du" aucun
# "cap" geogFeat geogName
# "Cerbère" geogName name
# "(" aucun
# "42" aucun
# "°" aucun
# "26,37" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "3" aucun
# "°" aucun
# "10,60" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "[" aucun
# "phare" geogFeat
# "]" aucun
# "et" aucun
# "le" aucun
# "cap" geogFeat geogName
# "d’" geogName
# "Agde" geogName name
# "(" aucun
# "43" aucun
# "°" aucun
# "16,50" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "3" aucun
# "°" aucun
# "30,84" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "," aucun
# "la" aucun
# "côte" geogFeat
# "présente" aucun
# "des" aucun
# "aspects" aucun
# "très" aucun
# "différents" aucun
# ":" aucun
# "–" aucun
# "dans" aucun
# "sa" aucun
# "partie" aucun
# "Sud" aucun
# "," aucun
# "jusqu’" aucun
# "à" aucun
# "Argelès-sur-Mer" geogName name
# "," aucun
# "le" aucun
# "littoral" geogFeat
# "rocheux" aucun
# "et" aucun
# "découpé" aucun
# "est" aucun
# "dominé" aucun
# "par" aucun
# "le" aucun
# "massif" geogFeat geogName
# "des" geogName
# "Pyrénées" geogName name
# "orientales" geogName name
# "," aucun
# "montagnes" geogFeat
# "élevées" aucun
# "," aucun
# "irrégulières" aucun
# "et" aucun
# "de" aucun
# "couleur" aucun
# "sombre" aucun
# "(" aucun
# "pic" geogFeat geogName
# "du" geogName
# "Canigou" geogName name
# "," aucun
# "2" aucun
# "785" aucun
# "m" aucun
# ")" aucun
# ";" aucun
# "–" aucun
# "puis" aucun
# "la" aucun
# "côte" geogFeat
# "s’" aucun
# "abaisse" aucun
# "brusquement" aucun
# "jusqu’" aucun
# "à" aucun
# "la" aucun
# "falaise" geogFeat geogName
# "de" geogName
# "Leucate" geogName name
# "." aucun
# "Elle" aucun
# "est" aucun
# "orientée" aucun
# "Sud-Nord" aucun
# "," aucun
# "rectiligne" aucun
# "," aucun
# "plate" aucun
# "et" aucun
# "sablonneuse" aucun
# "," aucun
# "bordée" aucun
# "d’" aucun
# "étangs" geogFeat
# "communiquant" aucun
# "généralement" aucun
# "avec" aucun
# "la" aucun
# "mer" aucun
# "par" aucun
# "des" aucun
# "canaux" geogFeat
# "appelés" aucun
# "«" aucun
# "graus" geogFeat
# "»" aucun
# ";" aucun
# "–" aucun
# "au-delà" aucun
# "du" aucun
# "cap" geogFeat geogName
# "Leucate" geogName name
# "," aucun
# "la" aucun
# "côte" geogFeat
# "basse" aucun
# "et" aucun
# "sablonneuse" aucun
# "décrit" aucun
# "une" aucun
# "courbe" aucun
# "très" aucun
# "peu" aucun
# "concave" aucun
# "jusqu’" aucun
# "au" aucun
# "mont" geogFeat geogName
# "d’" geogName
# "Agde" geogName name
# "." aucun
# "La" aucun
# "montagne" geogFeat geogName
# "de" geogName
# "la" geogName
# "Clape" geogName name
# "atteint" aucun
# "presque" aucun
# "la" aucun
# "mer" aucun
# "à" aucun
# "proximité" aucun
# "de" aucun
# "Narbonne" geogName name
# "-" geogName name
# "Plage" geogName name
# "." aucun
# "13" aucun
# "L’" aucun
# "isobathe" aucun
# "de" aucun
# "20" aucun
# "m" aucun
# "est" aucun
# "sensiblement" aucun
# "parallèle" aucun
# "à" aucun
# "la" aucun
# "côte" geogFeat
# "entre" aucun
# "le" aucun
# "Nord" aucun
# "du" aucun
# "cap" geogFeat geogName
# "Béar" geogName name
# "et" aucun
# "le" aucun
# "cap" geogFeat geogName
# "d’" geogName
# "Agde" geogName name
# "." aucun
# "Elle" aucun
# "s’" aucun
# "approche" aucun
# "de" aucun
# "0,5" aucun
# "à" aucun
# "1" aucun
# "M" aucun
# "du" aucun
# "rivage" geogFeat
# "entre" aucun
# "le" aucun
# "Nord" aucun
# "du" aucun
# "cap" geogFeat geogName
# "Béar" geogName name
# "et" aucun
# "le" aucun
# "cap" geogFeat geogName
# "Leucate" geogName name
# "puis" aucun
# "de" aucun
# "1" aucun
# "à" aucun
# "3" aucun
# "M" aucun
# "jusqu’" aucun
# "au" aucun
# "cap" geogFeat geogName
# "d’" geogName
# "Agde" geogName name
# "." aucun
# "19" aucun
# "L’" aucun
# "isobathe" aucun
# "de" aucun
# "50" aucun
# "m" aucun
# "est" aucun
# "sensiblement" aucun
# "parallèle" aucun
# "à" aucun
# "la" aucun
# "côte" geogFeat
# "entre" aucun
# "le" aucun
# "Nord" aucun
# "du" aucun
# "cap" geogFeat geogName
# "Béar" geogName name
# "et" aucun
# "le" aucun
# "cap" geogFeat geogName
# "Leucate" geogName name
# "à" aucun
# "environ" aucun
# "5" aucun
# "M" aucun
# "du" aucun
# "rivage" geogFeat
# "." aucun
# "Au" aucun
# "-" aucun
# "delà" aucun
# "du" aucun
# "cap" geogFeat geogName
# "Leucate" geogName name
# "," aucun
# "elle" aucun
# "s’" aucun
# "éloigne" aucun
# "régulièrement" aucun
# "de" aucun
# "la" aucun
# "côte" geogFeat
# "jusqu’" aucun
# "à" aucun
# "10" aucun
# "M" aucun
# "pour" aucun
# "revenir" aucun
# "à" aucun
# "6" aucun
# "M" aucun
# "au" aucun
# "large" aucun
# "du" aucun
# "cap" geogFeat geogName
# "d’" geogName
# "Agde" geogName name
# "." aucun
# "25" aucun
# "Les" aucun
# "profondeurs" aucun
# "décroissent" aucun
# "régulièrement" aucun
# "entre" aucun
# "l’" aucun
# "isobathe" aucun
# "de" aucun
# "50" aucun
# "m" aucun
# "et" aucun
# "le" aucun
# "littoral" geogFeat
# "." aucun
# "31" aucun
# "L’" aucun
# "isobathe" aucun
# "de" aucun
# "100" aucun
# "m" aucun
# "traverse" aucun
# "le" aucun
# "golfe" geogFeat geogName
# "du" geogName
# "Lion" geogName name
# "en" aucun
# "suivant" aucun
# "approximativement" aucun
# "la" aucun
# "ligne" geogFeat
# "joignant" aucun
# "le" aucun
# "cap" geogFeat geogName
# "Cerbère" geogName name
# "au" aucun
# "cap" geogFeat geogName
# "Couronne" geogName name
# "(" aucun
# "43" aucun
# "°" aucun
# "19,54" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "5" aucun
# "°" aucun
# "03,19" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "[" aucun
# "phare]." geogFeat
# "01" aucun
# "8.3.5" aucun
# "." aucun
# "Entre" aucun
# "Saylac" geogName name
# "et" aucun
# "Berbera" geogName name
# "07" aucun
# "De" aucun
# "Saylac" geogName name
# "à" aucun
# "Shaʻab" geogFeat geogName
# "Galangaret" geogName name
# "," aucun
# "à" aucun
# "30" aucun
# "M" aucun
# "au" aucun
# "SE" aucun
# "de" aucun
# "Saylac" geogName name
# "," aucun
# "trois" aucun
# "récifs" geogFeat
# "sont" aucun
# "portés" aucun
# "sur" aucun
# "la" aucun
# "carte" aucun
# "à" aucun
# "proximité" aucun
# "de" aucun
# "la" aucun
# "côte" geogFeat
# ";" aucun
# "Shaʻab" geogFeat geogName
# "Shaykh" geogName name
# "Yakab" geogName name
# "et" aucun
# "Shaʻab" geogFeat geogName
# "Galangaret" geogName name
# "(" aucun
# "10" aucun
# "°" aucun
# "57" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "43" aucun
# "°" aucun
# "45" aucun
# "'" aucun
# "E" aucun
# ")" aucun
# "sont" aucun
# "couverts" aucun
# "de" aucun
# "moins" aucun
# "de" aucun
# "2" aucun
# "m" aucun
# "d’" aucun
# "eau" aucun
# "," aucun
# "Shaʻab" geogFeat geogName
# "Salbal" geogName name
# "," aucun
# "entre" aucun
# "les" aucun
# "deux" aucun
# "précédents" aucun
# "," aucun
# "découvre" aucun
# "dans" aucun
# "sa" aucun
# "partie" aucun
# "Sud" aucun
# "." aucun
# "13" aucun
# "Entre" aucun
# "Shaʻab" geogFeat geogName
# "Galangaret" geogName name
# "et" aucun
# "Berbera" geogName name
# "," aucun
# "à" aucun
# "80" aucun
# "M" aucun
# "au" aucun
# "SSE" aucun
# "," aucun
# "la" aucun
# "côte" geogFeat
# "n’" aucun
# "a" aucun
# "été" aucun
# "qu’" aucun
# "imparfaitement" aucun
# "reconnue" aucun
# "." aucun
# "Aucun" aucun
# "danger" geogFeat
# "n’" aucun
# "est" aucun
# "connu" aucun
# "dans" aucun
# "cette" aucun
# "zone" geogFeat
# "et" aucun
# "la" aucun
# "côte" geogFeat
# "est" aucun
# "en" aucun
# "général" aucun
# "accore" aucun
# "," aucun
# "mais" aucun
# "la" aucun
# "plus" aucun
# "grande" aucun
# "prudence" aucun
# "s’" aucun
# "impose" aucun
# "." aucun
# "19" aucun
# "Les" aucun
# "petits" aucun
# "navires" aucun
# "connaissant" aucun
# "la" aucun
# "zone" geogFeat
# "mouillent" aucun
# "par" aucun
# "profondeur" aucun
# "de" aucun
# "11" aucun
# "m" aucun
# "," aucun
# "à" aucun
# "0,8" aucun
# "M" aucun
# "de" aucun
# "la" aucun
# "côte" geogFeat
# "devant" aucun
# "Dagarita" geogName name
# "," aucun
# "par" aucun
# "profondeur" aucun
# "de" aucun
# "11" aucun
# "m" aucun
# "," aucun
# "à" aucun
# "environ" aucun
# "0,8" aucun
# "M" aucun
# "de" aucun
# "la" aucun
# "côte" geogFeat
# "devant" aucun
# "Saba" geogName name
# "Wanak" geogName name
# "et" aucun
# "par" aucun
# "profondeurs" aucun
# "de" aucun
# "11" aucun
# "à" aucun
# "13" aucun
# "m" aucun
# "devant" aucun
# "Bulhar" aucun
# "à" aucun
# "environ" aucun
# "0,5" aucun
# "M" aucun
# "de" aucun
# "l’" aucun
# "ancienne" geogName name
# "Résidence" geogFeat geogName
# "et" aucun
# "en" aucun
# "la" aucun
# "relevant" aucun
# "entre" aucun
# "135" aucun
# "°" aucun
# "et" aucun
# "155" aucun
# "°" aucun
# "." aucun
# "Ce" aucun
# "mouillage" geogFeat
# "devant" aucun
# "Bulhar" geogName name
# "n’" aucun
# "est" aucun
# "pas" aucun
# "sûr" aucun
# "pendant" aucun
# "la" aucun
# "plus" aucun
# "grande" aucun
# "partie" aucun
# "de" aucun
# "la" aucun
# "mousson" aucun
# "de" aucun
# "SW" aucun
# "." aucun
# "280" aucun
# "extrait" aucun
# "le" aucun
# ":" aucun
# "2021" aucun
# "-" aucun
# "09" aucun
# "-" aucun
# "13" aucun
# "—" aucun
# "généré" aucun
# "le" aucun
# ":" aucun
# "2021" aucun
# "-" aucun
# "10" aucun
# "-" aucun
# "06" aucun
# "–" aucun
# "page" aucun
# "280" aucun
# "/" aucun
# "0" aucun
# "01" aucun
# "4.6.2" aucun
# "." aucun
# "Entre" aucun
# "Ras" geogFeat geogName
# "Ouillis" geogName name
# "et" aucun
# "Ras" geogFeat geogName
# "Magroua" geogName name
# "01" aucun
# "6.1.4.2" aucun
# "." aucun
# "Réserve" geogFeat
# "naturelle" geogFeat
# "07" aucun
# "Le" geogName name
# "Grand" geogName name
# "Connétable" geogName name
# "," aucun
# "Le" geogName name
# "Petit" geogName name
# "Connétable" geogName name
# "et" aucun
# "leurs" aucun
# "abords" aucun
# "," aucun
# "au" aucun
# "large" aucun
# "de" aucun
# "l’" aucun
# "embouchure" geogFeat
# "du" aucun
# "fleuve" geogFeat geogName
# "Approuague" geogName name
# "(" aucun
# "§" aucun
# "6.2.2.2" aucun
# "." aucun
# ")" aucun
# "," aucun
# "sont" aucun
# "des" aucun
# "îlots" geogFeat
# "qui" aucun
# "ont" aucun
# "été" aucun
# "classés" aucun
# "réserve" geogFeat
# "naturelle" geogFeat
# "par" aucun
# "décret" aucun
# "ministériel" aucun
# "du" aucun
# "8" aucun
# "décembre" aucun
# "1992" aucun
# "." aucun
# "Cette" aucun
# "zone" geogFeat
# "circulaire" aucun
# "de" aucun
# "2,7" aucun
# "M" aucun
# "de" aucun
# "rayon" aucun
# "est" aucun
# "centrée" aucun
# "sur" aucun
# "le" aucun
# "sommet" geogFeat
# "du" aucun
# "Grand" geogName name
# "Connétable" geogName name
# "(" aucun
# "4" aucun
# "°" aucun
# "49,5" aucun
# "'" aucun
# "N" aucun
# "—" aucun
# "51" aucun
# "°" aucun
# "56,0" aucun
# "'" aucun
# "W" aucun
# ")" aucun
# "." aucun
# "13" aucun
# "À" aucun
# "l’" aucun
# "intérieur" aucun
# "de" aucun
# "cette" aucun
# "réserve" geogFeat
# "," aucun
# "il" aucun
# "est" aucun
# "interdit" aucun
# "de" aucun
# "débarquer" aucun
# "," aucun
# "de" aucun
# "pêcher" aucun
# "," aucun
# "de" aucun
# "chasser" aucun
# "et" aucun
# "de" aucun
# "mouiller" aucun
# "." aucun
# "357" aucun
# "DE" aucun
# "CABO" geogFeat geogName
# "ORANGE" geogName name
# "JUSQU’" aucun
# "À" aucun
# "PUNTA" geogFeat geogName
# "BOMBEADOR" geogName name
# "GUYANE" geogName name
# "–" aucun
# "SURINAME" geogName name
# "–" aucun
# "GUYANA" geogName name
# "–" aucun
# "VENEZUELA" geogName name
# "EST" geogName name
# "01" aucun
# "2.1.4.10" aucun
# "." aucun
# "Zone" geogFeat geogName
# "de" geogFeat geogName
# "cantonnement" geogFeat geogName
# "de" geogFeat geogName
# "pêche" geogFeat geogName
# "du" geogName
# "Roc" geogFeat geogName
# "du" geogName
# "Brescou" geogName name
# "07" aucun
# "Au" aucun
# "droit" aucun
# "de" aucun
# "la" aucun
# "commune" geogFeat geogName
# "du" geogName
# "Cap" geogFeat geogName
# "d’" geogName
# "Agde" geogName name
# "," aucun
# "se" aucun
# "trouve" aucun
# "au" aucun
# "Roc" geogFeat geogName
# "du" geogName
# "Brescou" geogName name
# "une" aucun
# "zone" geogFeat
# "de" geogFeat
# "cantonnement" geogFeat
# "de" geogFeat
# "pêche" geogFeat
# "dans" aucun
# "laquelle" aucun
# "sont" aucun
# "interdits" aucun
# "toute" aucun
# "activité" aucun
# "de" aucun
# "pêche" aucun
# "," aucun
# "le" aucun
# "mouillage" aucun
# "des" aucun
# "navires" aucun
# "," aucun
# "la" aucun
# "plongée" aucun
# "sous-marine" aucun
# "(" aucun
# "en" aucun
# "scaphandre" aucun
# "autonome" aucun
# "ou" aucun
# "en" aucun
# "apnée" aucun
# ")" aucun
# "ainsi" aucun
# "que" aucun
# "le" aucun
# "dragage" aucun
# "(" aucun
# "arrêté" aucun
# "du" aucun
# "27" aucun
# "décembre" aucun
# "2019" aucun
# "[" aucun
# "JORF" aucun
# "du" aucun
# "8" aucun
# "janvier" aucun
# "2020" aucun
# "]" aucun
# "," aucun
# "du" aucun
# "ministère" aucun
# "de" aucun
# "l'" aucun
# "agriculture" aucun
# "et" aucun
# "de" aucun
# "l'" aucun
# "alimentation" aucun
# "et" aucun
# "arrêté" aucun
# "007/2020" aucun
# "du" aucun
# "31" aucun
# "janvier" aucun
# "2020" aucun
# "du" aucun
# "préfet" aucun
# "maritime" aucun
# "de" aucun
# "la" aucun
# "Méditerranée" geogName name
# ")" aucun
# "." aucun
# "Cette" aucun
# "zone" geogFeat
# "est" aucun
# "portée" aucun
# "sur" aucun
# "les" aucun
# "cartes" aucun
# "." aucun

# %%
set(df_train[df_train['Label'] == 'geogName name']['Token'])
# Out:
# {'-',
#  '0',
#  '1',
#  '10',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '12',
#  '13',
#  '15',
#  '18',
#  '2',
#  '3',
#  '30',
#  '31',
#  '32',
#  '36',
#  '37',
#  '39',
#  '4',
#  '40',
#  '41,42',
#  '43',
#  '44',
#  '45',
#  '5',
#  '51',
#  '52',
#  '6',
#  '62',
#  '63',
#  '64',
#  '7',
#  '8',
#  '81',
#  '82',
#  '83',
#  '9',
#  '91',
#  '92',
#  'A',
#  'A63',
#  'A64',
#  'ABY',
#  'ADEN',
#  'ADOUR',
#  'AFRICAINE',
#  'AGDE',
#  'ALBÈRES',
#  'ALGER',
#  'ALLÉES',
#  'AMANZA',
#  'AMBOULI',
#  'AMBRE',
#  'ANGLET',
#  'ARABIE',
#  'Abbé',
#  'Abderrahmane',
#  'Abeille',
#  'Accore',
#  'Adour',
#  'Afrique',
#  'Agde',
#  'Agoué',
#  'Agwé',
#  'Aigle',
#  'Air',
#  'Aldabra',
#  'Alderney',
#  'Alger',
#  'Allière',
#  'Allées',
#  'Alouettes',
#  'Amadou',
#  'Ambassades',
#  'Ambouli',
#  'Ambre',
#  'Amérique',
#  'An',
#  'Anglaise',
#  'Anglet',
#  'Angleterre',
#  'Anglo-Normandes',
#  'Anse',
#  'Antarès',
#  'Antifer',
#  'Anécho',
#  'Aného',
#  'Aoua',
#  'Approuague',
#  'Aquitaine',
#  'Ar',
#  'Arab',
#  'Argelès-sur-Mer',
#  'Armand',
#  'Assane',
#  'Assomption',
#  'Astove',
#  'At',
#  'Atlantique',
#  'Aurigny',
#  'Austral',
#  'Avel',
#  'Aveugle',
#  'Avrékété',
#  'Ayabelé',
#  'B',
#  'BA',
#  'BANYULS-SUR-MER',
#  'BERBERA',
#  'BLANCPIGNON',
#  'BOMBEADOR',
#  'BONIFACIO',
#  'BOUCAU',
#  'BOURGNEUF',
#  'Bages',
#  'Baleares',
#  'Banc',
#  'Banyuls',
#  'Banyuls-sur-Mer',
#  'Barcelone',
#  'Bargny',
#  'Barre-de-Monts',
#  'Basque',
#  'Bassurelle',
#  'Bayonne',
#  'Beachy',
#  'Beauvoir-sur-Mer',
#  'Bec',
#  'Bel',
#  'Belle',
#  'Belliveau',
#  'Berbera',
#  'Bernard',
#  'Bernerie',
#  'Bernerie-en-Retz',
#  'Bgar',
#  'Biarritz',
#  'Bilbao',
#  'Bir',
#  'Blanc',
#  'Blanc-Nez',
#  'Blanchard',
#  'Blancpignon',
#  'Bleu',
#  'Bon-Porté',
#  'Bormes',
#  'Bormes-les-Mimosas',
#  'Boucau',
#  'Bouin',
#  'Bourgneuf',
#  'Bourgneuf-en-Retz',
#  'Bras',
#  'Brescou',
#  'Brest',
#  'Bretagne',
#  'Briand',
#  'Briande',
#  'Brise',
#  'Brochets',
#  'Bulhar',
#  'BÉNAT',
#  'BÉNIN',
#  'Béar',
#  'Bénat',
#  'Bénin',
#  'Bœufs',
#  'C',
#  'C.',
#  'C10',
#  'C19',
#  'CAMARAT',
#  'COTONOU',
#  'CROISIC',
#  'Caen',
#  'Caillou',
#  'Calais',
#  'Calvaire',
#  'Camarat',
#  'Camp',
#  'Canadel',
#  'Canadel-',
#  'Canadells',
#  'Canigou',
#  'Cap',
#  'Capbreton',
#  'Cape',
#  'Carnot',
#  'Cartaya',
#  'Casquets',
#  'Cassin',
#  'Castel',
#  'Catherine',
#  'Cavalaire',
#  'Cavalière',
#  'Cavallo',
#  'Cayenne',
#  'Ceebaad',
#  'Centre',
#  'Cerbère',
#  'Chaland',
#  'Champs',
#  'Chapeau',
#  'Chats',
#  'Chatte',
#  'Chaussée',
#  'Château',
#  'Cimetière',
#  'Clape',
#  'Colbart',
#  'Collet',
#  'Collioure',
#  'Colombi',
#  'Commercial',
#  'Connétable',
#  'Corentyn',
#  'Cosmoledo',
#  'Cotentin',
#  'Cotonou',
#  'Coupé',
#  'Couronne',
#  'Creach',
#  'Creus',
#  'Cristau',
#  'Croix',
#  'Créac’',
#  'Cuisse',
#  'Curieuse',
#  'CÔTE',
#  'D',
#  'DE',
#  'DES',
#  'DJIBOUTI',
#  'Dagarita',
#  'Dakar',
#  'Dalwakteak',
#  'Dankali',
#  'Dattier',
#  'Delure',
#  'Din',
#  'Direction',
#  'Djibouti',
#  'Djondji',
#  'Doraleh',
#  'Douane',
#  'Douvres',
#  'Dover',
#  'Dubois',
#  'Dune',
#  'Dungeness',
#  'Dunkerque',
#  'E.',
#  'EN',
#  'ESPAGNOLE',
#  'EST',
#  'Eckmühl',
#  'Edmond',
#  'El',
#  'Emile',
#  'End',
#  'Espagne',
#  'Esprit',
#  'Est',
#  'Europe',
#  'Européen',
#  'FENO',
#  'Fain',
#  'Falleron',
#  'Fann',
#  'Fedj',
#  'Femme',
#  'Filfil',
#  'Foreland',
#  'Forges',
#  'Forgues',
#  'Fourmigue',
#  'Foy',
#  'France',
#  'Française',
#  'Frigate',
#  'Fromagette',
#  'Fromentine',
#  'Fromveur',
#  'G.',
#  'GHANA',
#  'GIENS',
#  'GORÉE',
#  'GOURMALON',
#  'GRANDE',
#  'GUYANA',
#  'GUYANE',
#  'Galangaret',
#  'Gascogne',
#  'Gaston',
#  'Gavetti',
#  'Georgetown',
#  'Ghiuncu',
#  'Gibraltar',
#  'Gionnet',
#  'Godomey',
#  'Gommès',
#  'Gorée',
#  'Gourmalon',
#  'Gouron',
#  'Gouvernement',
#  'Grand',
#  'Grand-Popo',
#  'Grande',
#  'Grands',
#  'Grau',
#  'Grecu',
#  'Grenet',
#  'Gris',
#  'Grise',
#  'Gros',
#  'Gruissan',
#  'Guaira',
#  'Guernesey',
#  'Gueule',
#  'Guissi',
#  'Gumarlah',
#  'Guyana',
#  'Guyane',
#  'HYÈRES',
#  'Hadj',
#  'Hague',
#  'Hann',
#  'Hastings',
#  'Haute-Perche',
#  'Havre',
#  'Hayyâbleï',
#  'Hendaye',
#  'Henri',
#  'Hodoul',
#  'Houareau',
#  'Hyères',
#  'HÉRON',
#  'Héron',
#  'IVI',
#  'Ibérique',
#  'Indien',
#  'Iroise',
#  'Italie',
#  'Ivi',
#  'Jean',
#  'Jova',
#  'Jument',
#  'Kalah',
#  'Kaolack',
#  'Kerouars',
#  'Kpémé',
#  'Kramis',
#  'Kébir',
#  'L',
#  'LA',
#  'LAVEZZI',
#  'LOMÉ',
#  'La',
#  'Lame',
#  'Lames',
#  'Lampaul',
#  'Land’',
#  'Langlade',
#  'Langlage',
#  'Lanier',
#  'Lardier',
#  'Large',
#  'Lavandou',
#  'Lavezzi',
#  'Layet',
#  'Le',
#  'Lequéré',
#  'Leray',
#  'Leroy',
#  'Les',
#  'Leucate',
#  'Levant',
#  'Libération',
#  'Lion',
#  'Llose',
#  'Loire',
#  'Lomé',
#  'Long',
#  'Lougne',
#  'Louippe',
#  'Loyada',
#  'Léon',
#  'L’',
#  'MADAGASCAR',
#  'MARINES',
#  'MAROC',
#  'MIQUELON',
#  'MOUCHA',
#  'Macaque',
#  'Mad',
#  'Madeleines',
#  'Madeloc',
#  'Magnan',
#  'Magroua',
#  'Magrowa',
#  'Mahé',
#  'Malabar',
#  'Mali',
#  'Mamelles',
#  'Manche',
#  'Mandéla',
#  'Manuel',
#  'Marabout',
#  'Marcel',
#  'Marine',
#  'Marines',
#  'Marins',
#  'Maskali',
#  'Mauresque',
#  'Maurice',
#  'Mayou',
#  'Maïsica',
#  'Mbao',
#  'Mbaw',
#  'Men',
#  'Menai',
#  'Mer',
#  'Mermoz',
#  'Merouane',
#  'Michel',
#  'Midi',
#  'Miquelon',
#  'Moidubis',
#  'Molène',
#  'Mono',
#  'Monticule',
#  'Morts',
#  'Moucha',
#  'Moulade',
#  'Moustique',
#  'Moustiques',
#  'Moutiers-en-Retz',
#  'Méditerranée',
#  'Météore',
#  'NE',
#  'NOIRMOUTIER',
#  'NORD',
#  'NOËVEILLARD',
#  'NW',
#  'Nadji',
#  'Namouic',
#  'Nantes',
#  'Narbonne',
#  'Nard',
#  'Ndoye',
#  'Nelson',
#  'Nez',
#  'Nid',
#  'Nive',
#  'Niçois',
#  'Noirmoutier',
#  'Nord',
#  'Nord-Est',
#  'Nord-Ouest',
#  'Notre-Dame',
#  'Noue',
#  'Nouvelle',
#  'Noëveillard',
#  'Nègre',
#  'ORANGE',
#  'OUEST',
#  'OUILLIS',
#  'Ondres',
#  'Orientales',
#  'Orinoco',
#  'Osne',
#  'Ouaramous',
#  'Ouessant',
#  'Ouest',
#  'Ouidah',
#  'Ouillis',
#  'PEYREFITE',
#  'PORNIC',
#  'POSIDONIES',
#  'Pacifique',
#  'Pagode',
#  'Palma',
#  'Palyvestre',
#  'Paramaribo',
#  'Parc',
#  'Paris',
#  'Pas-de-Calais',
#  'Paul',
#  'Pays',
#  'Penmarc’',
#  'Perche',
#  'Percé',
#  'Perduto',
#  'Petit',
#  'Peyrefite',
#  'Phare',
#  'Piana',
#  'Piantarella',
#  'Picard',
#  'Pierre',
#  'Pierre-du-Chenal',
#  'Pignon',
#  'Pilier',
#  'Pillot',
#  'Pingouin',
#  'Plage',
#  'Plaine-sur-Mer',
#  'Plate',
#  'Polymnie',
#  'Polype',
#  'Pont-Neuf',
#  'Pornic',
#  'Porraggia',
#  'Port',
#  'Port-Barcarès',
#  'Port-Vendres',
#  'Port-la-Nouvelle',
#  'Portland',
#  'Portugal',
#  'Préfailles',
#  'Pyrénées',
#  'PÊCHE',
#  'Pêcheurs',
#  'Quairolle',
#  'ROUGE',
#  'Raffineries',
#  'Ratino',
#  'Ravitaillement',
#  'Rayol',
#  'Reef',
#  'Rellinet',
#  'Ris',
#  'Rochers',
#  'Roques',
#  'Rouen',
#  'Rouge',
#  'Roumane',
#  'Royale',
#  'Royan',
#  'Rufisque',
#  'Résolue',
#  'SAINT-BERNARD',
#  'SAINT-PIERRE-ET-MIQUELON',
#  'SALUT',
#  'SANESLI',
#  'SANT’',
#  'SE',
#  'SOMALIE',
#  'SPM',
#  'SUD',
#  'SURINAM',
#  'SURINAME',
#  'SW',
#  'Saacada',
#  'Saba',
#  'Saghir',
#  'Saint',
#  'Saint-',
#  'Saint-Bernard',
#  'Saint-Clair',
#  'Saint-Cyprien-Plage',
#  'Saint-Esprit',
#  'Saint-Gildas',
#  'Saint-Gobain',
#  'Saint-Jean-de-Luz',
#  'Saint-Joseph',
#  'Saint-Laurent',
#  'Saint-Laurent-du-Maroni',
#  'Saint-Louis',
#  'Saint-Loup',
#  'Saint-Nazaire',
#  'Saint-Pierre',
#  'Saint-Thomas',
#  'Sainte',
#  'Sainte-Marie',
#  'Sainte-Marie-la-Mer',
#  'Salbal',
#  'Salines',
#  'Salses',
#  'Salut',
#  'Sand',
#  'Saylac',
#  'Saï',
#  'Scilly',
#  'Scorpion',
#  'Sein',
#  'Serpent',
#  'Serpents',
#  'Serpette',
#  'Seychelles',
#  'Shaykh',
#  'Shell',
#  'Sidi',
#  'Siham',
#  'Siigaale',
#  'Socoa',
#  'Soldats',
#  'Somali',
#  'Somalie',
#  'Souak',
#  'Soug',
#  'South',
#  'Stiff',
#  'Sud',
#  'Sud-Ouest',
#  'Suriname',
#  'SÉMÉ',
#  'Sète',
#  'Séghir',
#  'Sénégal',
#  'TARNOS',
#  'TOGO',
#  'Tables',
#  'Tacoma',
#  'Tadjoura',
#  'Taillat',
#  'Tarnos',
#  'Terre',
#  'The',
#  'Togo',
#  'Toulon',
#  'Toulouse',
#  'Town',
#  'Tramut',
#  'Trésor',
#  'Turuhat',
#  'Turuxaad',
#  'TÉNÈS',
#  'Ténès',
#  'VENEZUELA',
#  'VERGA',
#  'VERT',
#  'Valras',
#  'Valéry',
#  'Var',
#  'Varne',
#  'Veaux',
#  'Vedettes',
#  'Venezuela',
#  'Verdun',
#  'Vergeron',
#  'Vergoyer',
#  'Vert',
#  'Vieille',
#  'Vierge',
#  'Viou',
#  'Volterra',
#  'Wanak',
#  'Warys',
#  'West',
#  'Wight',
#  'Yakab',
#  'Yangue',
#  'Yoff',
#  'Zerfet',
#  'Zeri',
#  'Ziguinchor',
#  'africaine',
#  'ancien',
#  'ancienne',
#  'anciennes',
#  'anglaise',
#  'arachides',
#  'bature',
#  'bleue',
#  'breton',
#  'cap',
#  'continental',
#  'continentale',
#  'dans',
#  'de',
#  'des',
#  'droite',
#  'du',
#  'd’',
#  'el',
#  'en',
#  'espagnole',
#  'européen',
#  'européennes',
#  'française',
#  'françaises',
#  'gauche',
#  'h',
#  'h.',
#  'hodoul',
#  'la',
#  'lantique',
#  'l’',
#  'maritime',
#  'multipurpose',
#  'médian',
#  'normand',
#  'nouveau',
#  'n°',
#  'nº',
#  'orientales',
#  'principal',
#  'pétrolier',
#  'pêche',
#  'renaissance',
#  'réparations',
#  's',
#  'sur',
#  'torpilleurs',
#  '«',
#  '»',
#  'Écluse',
#  'Écuelle',
#  'Édouard',
#  'Édourad',
#  'Époids',
#  'Étoile',
#  'à',
#  '’'}

# %%
df_test
# Out:
#           Id                     Token
# 0          0                        01
# 1          1                   2.1.4.8
# 2          2                         .
# 3          3                 Conduites
# 4          4              sous-marines
# ...      ...                       ...
# 26168  26168                       103
# 26169  26169                         /
# 26170  26170                         0
# 26171  26171                       103
# 26172  26172  SAINT-PIERRE-ET-MIQUELON
#
# [26173 rows x 2 columns]

# %%
df_sample
# Out:
#           Id               Label
# 0          0            geogFeat
# 1          1   geogFeat geogName
# 2          2               aucun
# 3          3               aucun
# 4          4               aucun
# ...      ...                 ...
# 26168  26168               aucun
# 26169  26169               aucun
# 26170  26170               aucun
# 26171  26171               aucun
# 26172  26172               aucun
#
# [26173 rows x 2 columns]

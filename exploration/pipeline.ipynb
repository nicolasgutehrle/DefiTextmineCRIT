# %% [markdown]
# # Pipeline
#
# Pipeline combining the CRF and classifier (KNN, XGBoost) to extract and classify ENE candidates

# %%
import gensim 
import pandas as pd
import numpy as np
import spacy 
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, make_scorer

from gensim.models import KeyedVectors


import scipy

import joblib
import os

import string

import joblib

from typing import List

# %%
class Model:

    def __init__(self, extractor, classifier, embeddings, class_labels):
        self.extractor = extractor
        self.classifier = classifier
        self.embeddings = embeddings
        self.class_labels = class_labels

    def cleanData(self, data:pd.DataFrame) -> None:
        """Simple function to clean Tokens

        :param data: DataFrame containing the data
        :type data: pd.DataFrame
        """
        data['Token'] = data['Token'].str.replace('"', '')


    def getStringShape(self, string:str) -> str:
        """Get the shape of the string as either X for capital letters and x for normal letters

        :param string: String to get the shape of
        :type string: str
        :return: Shape of the string (e.g. Port: Xxxx)
        :rtype: str
        """
        shape = ['X' if x.isupper() else 'x' for x in string]
        return ''.join(shape)
        
    def extractCRFFeatures(self, data:pd.DataFrame):
        """
        Extract features from Token column of the dataframe

        :param data: DataFrame contianing the data
        :type data: pd.DataFrame
        """
        data['lower'] = [x.lower() for x in data['Token']]
        data['isdigit'] = [x.isdigit() for x in data['Token']]
        data['isupper'] = [x.isupper() for x in data['Token']]
        data['ispunct'] = [x in string.punctuation for x in data['Token']]
        data['isstop'] = [x in nlp.Defaults.stop_words for x in data['Token']]
        data['len'] = [len(x) for x in data['Token']]
        data['shape'] = [self.getStringShape(x) for x in data['Token']]
        # data['istitle'] = [x.istitle() for x in data['Token']]


    def prepareDatasetFeatures(self, data:pd.DataFrame, i:int) -> dict:
        """Process the features of a token extracted with extractFeatures and
        prepares them in the format required by sklearn_crfsuite
        Note: this functions takes a lot of time somehow, so it probably needs to be
        refactored.

        :param data: DataFrame containing the token and their features
        :type data: pd.DataFrame
        :param i: index of the token
        :type i: int
        :return: Dictionary where keys are the name of the feature, and values are the features
        :rtype: dict
        """
    #     # word_vector = vectorize(we=we, word=word['Token'])
        ignore_col = ['Id', 'Label']

        data = data[[x for x in data.columns if x not in ignore_col]]
        word_data = data.loc[i]
        feature_dict = word_data.to_dict()

        if i != 0:
            prev_word_data = data.loc[i - 1]
            for k, v in prev_word_data.to_dict().items():
                feature_dict[f"prev_{k}"] = v
        
        if i != len(data) - 1:
            next_word_data = data.loc[i + 1]
            for k, v in next_word_data.to_dict().items():
                feature_dict[f"next_{k}"] = v
                
        return feature_dict

    def binarizeLabels(self, labels:List[str]) -> np.array:
        """Binarizes labels as either "aucun" or "NER"

        :param labels: List of labels to binarize
        :type labels: List[str]
        :return: Binarized list of labels
        :rtype: np.array
        """
        return np.array(['NER' if x != 'aucun' else 'aucun' for x in labels])

    def vectorize(self, word:str) -> np.memmap:
        """Vectorize a word into a word embedding vector

        :param we: Word embedding to use
        :type we: KeyedVectors
        :param word: Word to convert
        :type word: str
        :return: Embeddings corresponding to this word
        :rtype: np.memmap
        """
        try:
            vector = self.embeddings.word_vec(word)
        except:
            try:
                vector = self.embeddings.word_vec(word.lower())
            except:
                vector = np.zeros(300)
        return vector

    def extractCandidates(self, X:pd.DataFrame) -> pd.DataFrame :
        """Use the CRF extractor to extract NER candidate from dataset
        First extract the required features, then predict and update the dataset

        :param X: Dataset to classify
        :type X: pd.DataFrame
        :return: Updated dataset with predictions
        :rtype: pd.DataFrame
        """
        # first clean tokens
        self.cleanData(X)
        # extract required features
        self.extractCRFFeatures(X)
        X_features = np.array([self.prepareDatasetFeatures(data=X, i=i) for i in X.index])
        pred = self.extractor.predict([X_features])
        X['crf_pred'] = pred[0]
        return X

    def classifyCandidates(self, X:pd.DataFrame) -> pd.DataFrame:
        """Use the classifier to label the candidates extracted by the CRF extractor

        :param X: Dataset to classify
        :type X: pd.DataFrame
        :return: Updated dataset with predictions
        :rtype: pd.DataFrame
        """
        

        # selects token labelled "NER" by CRF
        sub_X = X[X['crf_pred'] == 'NER']

        # converts tokens into word embeddings
        X_features = np.array([self.vectorize(word=x) for x in sub_X['Token']])

        # output matrix of prediction for each token labelled NER
        pred = pd.DataFrame(self.classifier.predict(X_features), columns = self.class_labels)

        # joins predictions to original dataset
        pred['Id'] = sub_X['Id'].values
        pred = pred.set_index('Id')
        X = X.join(pred)
        
        # makes sure every label is set to 0 when the CRF classifier (extractor)
        # has labelled "aucun" a token
        for col in self.class_labels:
                X.loc[X['crf_pred'] == 'aucun', col] = 0

        return X
    
    def getPrediction(self, X:pd.DataFrame) -> pd.DataFrame:
        """Reads the output of the classifier and add a 'Label' column
        to the dataset which contains the prediction in the required format
        (ie in one Label and not multiple)

        :param X: Dataset to classify
        :type X: pd.DataFrame
        :return: Updated dataset with predictions
        :rtype: pd.DataFrame
        """

        X.loc[
            (X['geogFeat'] == 1) &
            (X['geogName'] == 0) &
            (X['name'] == 0), 'Label'] = 'geogFeat'

        X.loc[
            (X['geogFeat'] == 0) &
            (X['geogName'] == 1) &
            (X['name'] == 0), 'Label'] = 'geogName'


        X.loc[
            (X['geogFeat'] == 1) &
            (X['geogName'] == 1) &
            (X['name'] == 0), 'Label'] = 'geogFeat geogName'
        

        X.loc[
            (X['geogFeat'] == 0) &
            (X['geogName'] == 1) &
            (X['name'] == 1), 'Label'] = 'geogName name'


        X['Label'].fillna('aucun', inplace=True)
        return X
    #     array(['aucun', 'geogFeat geogName', 'geogName', 'geogName name',
    #    'geogFeat'

    def predict(self, X:pd.DataFrame) -> pd.DataFrame:
        """Main function to apply the pipeline: candidate extraction then classification

        :param X: _description_
        :type X: pd.DataFrame
        :return: _description_
        :rtype: pd.DataFrame
        """
        copy_X = X.copy(deep=True)

        copy_X = self.extractCandidates(copy_X)
        copy_X = self.classifyCandidates(copy_X)
        copy_X = self.getPrediction(copy_X)
        return copy_X

# %% [markdown]
# # Loading models

# %%
knn = joblib.load('../models/knn.joblib')

# %%
xgboost = joblib.load('../models/xgboost.joblib')

# %%
crf = joblib.load('../models/crf.joblib')

# %%
embeddings_path = '../embeddings/conceptnet_fr-19.08-clean_simpler'
we = KeyedVectors.load(embeddings_path, mmap='r')

# %%
df_train = pd.read_csv('../data/train_2.csv')
df_test = pd.read_csv('../data/test.csv')
df_sample = pd.read_csv('../data/sample_submission_2.csv')

# %%
nlp = spacy.load('fr_core_news_lg')

# %%
class_labels = ['geogFeat', 'geogName', 'name']

# %% [markdown]
# # CRF + KNN Pipeline

# %%
knn_pipeline = Model(extractor=crf, classifier=knn, embeddings=we, class_labels = class_labels)

# %%
predictions = knn_pipeline.predict(df_test)
# Out:
# /var/folders/g9/npfr2mks4118dkv7g8ckgccr0000gn/T/ipykernel_6227/2184327442.py:99: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   vector = self.embeddings.word_vec(word)
# /var/folders/g9/npfr2mks4118dkv7g8ckgccr0000gn/T/ipykernel_6227/2184327442.py:102: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   vector = self.embeddings.word_vec(word.lower())

# %%
for tok, label in zip(predictions['Token'], predictions['Label']):
    print(tok, label)
# Out:
# 01 aucun
# 2.1.4.8 aucun
# . aucun
# Conduites aucun
# sous-marines aucun
# 07 aucun
# Arrêtés aucun
# 1974 aucun
# - aucun
# 961 aucun
# ADM aucun
# / aucun
# SA aucun
# du aucun
# 6 aucun
# décembre aucun
# 1974 aucun
# et aucun
# 1998 aucun
# - aucun
# 002 aucun
# du aucun
# 15 aucun
# janvier aucun
# 1998 aucun
# du aucun
# préfet aucun
# maritime aucun
# de aucun
# la aucun
# Méditerranée geogName
# ( aucun
# www.premar-mediterranee.gouv.fr/arretes.html aucun
# ) aucun
# , aucun
# courrier aucun
# des aucun
# Phares geogName
# et geogName
# Balises geogName
# du aucun
# 9 aucun
# septembre aucun
# 1968 aucun
# . aucun
# 2107 aucun
# 08 aucun
# Émissaires aucun
# de aucun
# rejet aucun
# protégés aucun
# par aucun
# des aucun
# zones geogName
# réglementées geogName
# . aucun
# 13 aucun
# Situation aucun
# : aucun
# zones geogName
# portées geogName
# sur aucun
# les aucun
# cartes aucun
# , aucun
# devant aucun
# les aucun
# ports geogName
# de aucun
# : aucun
# – aucun
# Cerbère geogName
# ( aucun
# 42 aucun
# ° aucun
# 26,52 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 10,26 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Banyuls-sur-Mer geogName
# ( aucun
# 42 aucun
# ° aucun
# 29,00 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 08,53 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Port-Vendres geogName
# ( aucun
# 42 aucun
# ° aucun
# 31,41 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 07,22 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Collioure geogName
# ( aucun
# 42 aucun
# ° aucun
# 31,79 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 05,21 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Argelès-sur-Mer geogName
# ( aucun
# 42 aucun
# ° aucun
# 32,80 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 03,45 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Grau geogName
# - geogName
# d’ geogName
# Agde geogName
# ( aucun
# 42 aucun
# ° aucun
# 15,92 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 27,45 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 19 aucun
# Réglementation aucun
# : aucun
# mouillage aucun
# et aucun
# dragage aucun
# interdits aucun
# . aucun
# 01 aucun
# 3.7.1 aucun
# . aucun
# Entre aucun
# le aucun
# port geogName
# de geogName
# Lomé geogName
# et aucun
# le aucun
# port geogName
# de geogName
# Kpémé geogName
# 07 aucun
# Le aucun
# phare geogName
# de geogName
# Baguida geogName
# , aucun
# à aucun
# 2 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# de aucun
# la aucun
# contre-jetée aucun
# du aucun
# Port geogName
# de geogName
# Lomé geogName
# , aucun
# est aucun
# un aucun
# pylône geogName
# peint geogName
# en aucun
# aluminium aucun
# , aucun
# haut aucun
# de aucun
# 34 aucun
# m aucun
# , aucun
# à aucun
# voyant aucun
# trapézoïdal aucun
# noir aucun
# . aucun
# 13 aucun
# Entre aucun
# le aucun
# Port geogName
# de geogName
# Lomé geogName
# et aucun
# le aucun
# village geogName
# de geogName
# Kpémé geogName
# à aucun
# 15 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# la aucun
# côte geogName
# est aucun
# formée aucun
# d’ aucun
# une aucun
# plage geogName
# de aucun
# sable aucun
# rectiligne aucun
# , aucun
# bordée aucun
# de aucun
# cocotiers aucun
# . aucun
# 19 aucun
# Au aucun
# Nord aucun
# de aucun
# Porto geogName
# - geogName
# Segouro geogName
# ( aucun
# Porto geogName
# - geogName
# Seguro geogName
# ) aucun
# [ aucun
# 6 aucun
# ° aucun
# 12 aucun
# ' aucun
# N aucun
# — aucun
# 1 aucun
# ° aucun
# 29 aucun
# ' aucun
# E aucun
# ] aucun
# , aucun
# ( aucun
# vue aucun
# 3.7.1 aucun
# . aucun
# ) aucun
# , aucun
# s’ aucun
# étend aucun
# le aucun
# Lac geogName
# Togo geogName
# , aucun
# vaste aucun
# étendue aucun
# d’ aucun
# eau aucun
# qui aucun
# se aucun
# prolonge aucun
# jusqu’ aucun
# au aucun
# village geogName
# de geogName
# Grand-Popo geogName
# , aucun
# à aucun
# 20 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# par aucun
# une aucun
# lagune geogName
# étroite aucun
# en aucun
# forme aucun
# de aucun
# canal aucun
# . aucun
# 25 aucun
# Le aucun
# village geogName
# de geogName
# Kpémé geogName
# est aucun
# situé aucun
# à aucun
# 2 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# de aucun
# Porto geogName
# - geogName
# Segouro geogName
# . aucun
# 31 aucun
# 3.7.1 aucun
# . aucun
# — aucun
# Vue aucun
# générale aucun
# de aucun
# Porto geogName
# - geogName
# Ségouro geogName
# . aucun
# 01 aucun
# 6.2.1.7 aucun
# . aucun
# Règlementation aucun
# 07 aucun
# VOIE geogName
# D’ geogName
# ACCÈS geogName
# OBLIGATOIRE geogName
# . aucun
# — aucun
# Une aucun
# voie geogName
# d’ geogName
# accès geogName
# est aucun
# obligatoire aucun
# pour aucun
# les aucun
# navires aucun
# dont aucun
# la aucun
# jauge aucun
# brute aucun
# est aucun
# supérieure aucun
# à aucun
# 3 aucun
# 000 aucun
# , aucun
# transportant aucun
# des aucun
# hydrocarbures aucun
# ou aucun
# des aucun
# substances aucun
# dangereuses aucun
# ( aucun
# arrêté aucun
# 2006/069 aucun
# du aucun
# 30 aucun
# août aucun
# 2006 aucun
# [ aucun
# modifié aucun
# ] aucun
# du aucun
# préfet aucun
# maritime aucun
# de aucun
# l’ aucun
# Atlantique geogName
# ) aucun
# . aucun
# 13 aucun
# Le aucun
# chenal geogName
# d’ geogName
# approche geogName
# est aucun
# limité aucun
# : aucun
# – aucun
# au aucun
# Nord aucun
# et aucun
# au aucun
# Sud aucun
# , aucun
# par aucun
# des aucun
# lignes aucun
# orientées aucun
# à aucun
# 328,4 aucun
# ° aucun
# et aucun
# 270 aucun
# ° aucun
# à aucun
# partir aucun
# du aucun
# feu geogName
# de aucun
# la aucun
# digue geogName
# Nord geogName
# ; aucun
# – aucun
# à aucun
# l’ aucun
# Ouest aucun
# , aucun
# le aucun
# chenal geogName
# débute geogName
# à aucun
# 7 aucun
# M aucun
# du aucun
# feu geogName
# de aucun
# la aucun
# digue geogName
# Nord geogName
# , aucun
# et aucun
# se aucun
# prolonge aucun
# , aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# jusqu’ aucun
# à aucun
# 1 aucun
# M aucun
# de aucun
# ce aucun
# même aucun
# feu geogName
# . aucun
# 19 aucun
# La aucun
# zone geogName
# d’ geogName
# attente geogName
# est aucun
# limitée aucun
# : aucun
# – aucun
# au aucun
# Nord aucun
# par aucun
# la aucun
# ligne geogName
# orientée aucun
# à aucun
# 300 aucun
# ° aucun
# à aucun
# partir aucun
# du aucun
# château geogName
# d’ geogName
# eau geogName
# d’ geogName
# Ondres geogName
# ; aucun
# – aucun
# au aucun
# Sud aucun
# par aucun
# la aucun
# ligne geogName
# orientée aucun
# à aucun
# 328,4 aucun
# ° aucun
# à aucun
# partir aucun
# du aucun
# feu geogName
# de aucun
# la aucun
# digue geogName
# Nord geogName
# ; aucun
# – aucun
# à aucun
# l’ aucun
# Est aucun
# et aucun
# à aucun
# l’ aucun
# Ouest aucun
# par aucun
# les aucun
# distances aucun
# de aucun
# 2 aucun
# M aucun
# et aucun
# 4 aucun
# M aucun
# à aucun
# partir aucun
# du aucun
# trait aucun
# de aucun
# côte geogName
# . aucun
# 25 aucun
# À aucun
# partir aucun
# de aucun
# l’ aucun
# extrémité aucun
# Est aucun
# du aucun
# chenal geogName
# d’ geogName
# approche geogName
# , aucun
# les aucun
# navires aucun
# se aucun
# conforment aucun
# aux aucun
# instructions aucun
# du aucun
# pilote aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 281 aucun
# / aucun
# 0 aucun
# 281 aucun
# DE aucun
# L’ aucun
# ADOUR geogName
# À aucun
# LA aucun
# FRONTIÈRE geogName
# ESPAGNOLE geogName
# 31 aucun
# CARACTÉRISTIQUES aucun
# DU aucun
# NAVIRE geogName
# DE geogName
# RÉFÉRENCE geogName
# . aucun
# — aucun
# Les aucun
# caractéristiques aucun
# du aucun
# navire aucun
# de aucun
# référence aucun
# autorisé aucun
# à aucun
# accéder aucun
# au aucun
# port geogName
# sont aucun
# les aucun
# suivantes aucun
# : aucun
# longueur aucun
# 160 aucun
# m aucun
# , aucun
# largeur aucun
# 25 aucun
# m aucun
# , aucun
# tirant aucun
# d’ aucun
# eau aucun
# à aucun
# l’ aucun
# entrée aucun
# 8,70 aucun
# m aucun
# , aucun
# tirant aucun
# d’ aucun
# eau aucun
# à aucun
# la aucun
# sortie aucun
# 9,60 aucun
# m. aucun
# 37 aucun
# L’ aucun
# accès geogName
# d’ aucun
# un aucun
# navire aucun
# présentant aucun
# une aucun
# caractéristique aucun
# supérieure aucun
# à aucun
# celles aucun
# du aucun
# navire aucun
# de aucun
# référence aucun
# peut aucun
# être aucun
# autorisé aucun
# par aucun
# la aucun
# capitainerie geogName
# , geogName
# après aucun
# avis aucun
# du aucun
# pilotage aucun
# . aucun
# Dans aucun
# ce aucun
# cas aucun
# , aucun
# il aucun
# est aucun
# conseillé aucun
# aux aucun
# représentants aucun
# du aucun
# navire aucun
# de aucun
# déposer aucun
# à aucun
# la aucun
# capitainerie geogName
# , aucun
# au aucun
# minimum aucun
# une aucun
# semaine aucun
# avant aucun
# le aucun
# mouvement aucun
# prévu aucun
# , aucun
# la aucun
# demande aucun
# d’ aucun
# escale aucun
# qui aucun
# doit aucun
# comporter aucun
# les aucun
# caractéristiques aucun
# détaillées aucun
# du aucun
# navire aucun
# . aucun
# 43 aucun
# Des aucun
# restrictions aucun
# peuvent aucun
# être aucun
# apportées aucun
# par aucun
# la aucun
# capitainerie geogName
# , aucun
# pour aucun
# des aucun
# raisons aucun
# de aucun
# sécurité aucun
# , aucun
# de aucun
# profondeur aucun
# du aucun
# chenal geogName
# ou aucun
# de aucun
# conditions aucun
# nautiques aucun
# et aucun
# météorologiques aucun
# . aucun
# 49 aucun
# De aucun
# nuit aucun
# , aucun
# seuls aucun
# sont aucun
# autorisés aucun
# à aucun
# faire aucun
# mouvement aucun
# les aucun
# navires aucun
# dont aucun
# les aucun
# dimensions aucun
# n’ aucun
# excèdent aucun
# pas aucun
# 130 aucun
# m aucun
# de aucun
# long aucun
# et aucun
# 7,00 aucun
# m aucun
# de aucun
# tirant aucun
# d’ aucun
# eau aucun
# . aucun
# 55 aucun
# L’ aucun
# entrée geogName
# de aucun
# l’ aucun
# Adour geogName
# peut aucun
# être aucun
# impraticable aucun
# par aucun
# gros aucun
# temps aucun
# en aucun
# mer aucun
# , aucun
# ou aucun
# forte aucun
# crue aucun
# en aucun
# rivière geogName
# , aucun
# particulièrement aucun
# en aucun
# jusant aucun
# . aucun
# Les aucun
# navires aucun
# reçoivent aucun
# alors aucun
# des aucun
# instructions aucun
# de aucun
# la aucun
# capitainerie geogName
# sur geogName
# VHF geogName
# , aucun
# canal aucun
# 12 aucun
# , aucun
# soit aucun
# pour aucun
# quitter aucun
# leur aucun
# mouillage aucun
# , aucun
# soit aucun
# pour aucun
# rester aucun
# en aucun
# attente aucun
# au aucun
# large aucun
# . aucun
# 61 aucun
# PROFONDEURS aucun
# , aucun
# TIRANTS geogName
# D’ geogName
# EAU geogName
# ET geogName
# TIRANTS geogName
# D’ geogName
# AIR geogName
# ADMISSIBLES geogName
# . aucun
# — aucun
# Les aucun
# profondeurs aucun
# à aucun
# l’ aucun
# embouchure geogName
# sont aucun
# variables aucun
# suivant aucun
# les aucun
# saisons aucun
# ; aucun
# elles aucun
# sont aucun
# entretenues aucun
# par aucun
# dragage aucun
# . aucun
# Elles aucun
# ne aucun
# sont aucun
# pratiquement aucun
# pas aucun
# inférieures aucun
# à aucun
# 9,5 aucun
# m aucun
# en aucun
# été aucun
# , aucun
# mais aucun
# peuvent aucun
# être aucun
# réduites aucun
# en aucun
# hiver aucun
# à aucun
# la aucun
# suite aucun
# des aucun
# tempêtes aucun
# d’ aucun
# Ouest aucun
# à aucun
# SW aucun
# . aucun
# 67 aucun
# Le aucun
# tirant aucun
# d’ aucun
# eau aucun
# admissible aucun
# est aucun
# fonction aucun
# du aucun
# coefficient aucun
# de aucun
# la aucun
# marée aucun
# , aucun
# de aucun
# l’ aucun
# état aucun
# de aucun
# la aucun
# mer aucun
# , aucun
# des aucun
# vents aucun
# , aucun
# de aucun
# l’ aucun
# état aucun
# d’ aucun
# ensablement aucun
# à aucun
# l’ aucun
# embouchure geogName
# de aucun
# l’ aucun
# Adour geogName
# , aucun
# ainsi aucun
# que aucun
# de aucun
# la aucun
# hauteur aucun
# d’ aucun
# eau aucun
# au aucun
# poste geogName
# d’ geogName
# amarrage geogName
# souhaité aucun
# . aucun
# Par aucun
# conditions aucun
# idéales aucun
# , aucun
# le aucun
# tirant aucun
# d’ aucun
# eau aucun
# maximal aucun
# admissible aucun
# est aucun
# : aucun
# de aucun
# jour aucun
# 8,70 aucun
# m aucun
# à aucun
# l’ aucun
# entrée geogName
# et aucun
# 9,60 aucun
# m aucun
# à aucun
# la aucun
# sortie aucun
# ; aucun
# de aucun
# nuit aucun
# 7 aucun
# m. aucun
# 73 aucun
# Le aucun
# pont geogName
# Henri geogName
# Grenet geogName
# , aucun
# situé aucun
# à aucun
# 3,1 aucun
# M aucun
# de aucun
# l’ aucun
# embouchure geogName
# de aucun
# l’ aucun
# Adour geogName
# , aucun
# autorise aucun
# un aucun
# tirant aucun
# d’ aucun
# air aucun
# de aucun
# 9,5 aucun
# m aucun
# par aucun
# rapport aucun
# au aucun
# zéro aucun
# des aucun
# cartes aucun
# . aucun
# 01 aucun
# 5.4.10.3 aucun
# . aucun
# Accès aucun
# 07 aucun
# À aucun
# l’ aucun
# angle aucun
# des aucun
# vestiges geogName
# d’ aucun
# une aucun
# ancienne geogName
# digue geogName
# , aucun
# une aucun
# balise geogName
# latérale geogName
# bâbord geogName
# , aucun
# avec aucun
# panneaux aucun
# réfléchissants aucun
# , aucun
# signale aucun
# l’ aucun
# entrée geogName
# du aucun
# port geogName
# . aucun
# 01 aucun
# 2.4.5 aucun
# . aucun
# Chenalage aucun
# 07 aucun
# Les aucun
# voies geogName
# recommandées aucun
# permettant aucun
# l’ aucun
# accès geogName
# à aucun
# Nouméa geogName
# sont aucun
# portées aucun
# sur aucun
# les aucun
# cartes aucun
# ( aucun
# § aucun
# 2.1.1.3 aucun
# . aucun
# ) aucun
# . aucun
# Leurs aucun
# limites aucun
# sont aucun
# précisées aucun
# en aucun
# annexe aucun
# ( aucun
# § aucun
# 7.4 aucun
# . aucun
# ) aucun
# . aucun
# 13 aucun
# Corne aucun
# SE aucun
# : aucun
# – aucun
# du aucun
# canal aucun
# de aucun
# la aucun
# Havannah geogName
# ( aucun
# § aucun
# 2.2.1.1 aucun
# . aucun
# ) aucun
# à aucun
# Nouméa geogName
# ( aucun
# § aucun
# 2.4 aucun
# . aucun
# ) aucun
# par aucun
# le aucun
# canal geogName
# Woodin geogName
# ( aucun
# § aucun
# 2.2.3 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# menant aucun
# à aucun
# la aucun
# passe geogName
# de geogName
# la geogName
# Sarcelle geogName
# ( aucun
# § aucun
# 2.2.1.6 aucun
# . aucun
# ) aucun
# et aucun
# à aucun
# l’ aucun
# île geogName
# des geogName
# Pins geogName
# ( aucun
# § aucun
# 2.2.2 aucun
# . aucun
# ) aucun
# . aucun
# 19 aucun
# Côte geogName
# SW geogName
# : aucun
# – aucun
# de aucun
# la aucun
# passe geogName
# de geogName
# Uatio geogName
# jusqu’ aucun
# au aucun
# mouillage aucun
# de aucun
# l’ aucun
# îlot geogName
# Kouaré geogName
# ( aucun
# § aucun
# 2.2.5 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# de aucun
# la aucun
# passe geogName
# Nord aucun
# des aucun
# passes geogName
# de geogName
# Boulari geogName
# ( aucun
# § aucun
# 2.3.1 aucun
# . aucun
# ) aucun
# à aucun
# la aucun
# Petite geogName
# rade geogName
# ( aucun
# § aucun
# 2.4.6.1 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# reliant aucun
# les aucun
# passes geogName
# de geogName
# Boulari geogName
# au aucun
# canal geogName
# Woodin geogName
# ( aucun
# § aucun
# 2.2.3 aucun
# . aucun
# ) aucun
# ou aucun
# au aucun
# canal aucun
# de aucun
# la aucun
# Havannah geogName
# ( aucun
# § aucun
# 2.2.1.1 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# de aucun
# la aucun
# passe geogName
# de geogName
# Dumbéa geogName
# ( aucun
# § aucun
# 2.3.2.1 aucun
# . aucun
# ) aucun
# et aucun
# celles aucun
# menant aucun
# de aucun
# cette aucun
# passe geogName
# à geogName
# Nouméa geogName
# ; aucun
# – aucun
# de aucun
# la aucun
# passe geogName
# de geogName
# Uitoé geogName
# ( aucun
# § aucun
# 2.5.2.1 aucun
# . aucun
# ) aucun
# à aucun
# Nouméa geogName
# . aucun
# 25 aucun
# Les aucun
# points aucun
# d’ aucun
# embarquement aucun
# des aucun
# pilotes aucun
# sont aucun
# précisés aucun
# au aucun
# § aucun
# 2.4.4 aucun
# . aucun
# 01 aucun
# 4.5.5.4 aucun
# . aucun
# Données aucun
# portuaires aucun
# 07 aucun
# Caractéristiques aucun
# nautiques aucun
# Météorologie aucun
# locale aucun
# Vents aucun
# tourbillonnants aucun
# dans aucun
# la aucun
# baie geogName
# par aucun
# temps aucun
# de aucun
# mistral aucun
# . aucun
# Navires aucun
# admis aucun
# PORT geogName
# PUBLIC geogName
# : aucun
# unités aucun
# de aucun
# plaisance aucun
# de aucun
# 4 aucun
# à aucun
# 30 aucun
# m. aucun
# Installations geogName
# portuaires geogName
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 21 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 205 aucun
# / aucun
# 0 aucun
# 205 aucun
# DE aucun
# LA aucun
# PRESQU’ geogName
# ÎLE geogName
# DE geogName
# GIENS geogName
# AU aucun
# CAP geogName
# CAMARAT geogName
# – aucun
# ÎLES geogName
# D’ geogName
# HYÈRES geogName
# PORT geogName
# PRIVÉ geogName
# : aucun
# unités aucun
# de aucun
# plaisance aucun
# de aucun
# 7 aucun
# à aucun
# 16 aucun
# m. aucun
# Infrastructures geogName
# 1 aucun
# port geogName
# à aucun
# gestion aucun
# privée aucun
# ou aucun
# nouveau aucun
# port geogName
# dans aucun
# la aucun
# partie aucun
# Est aucun
# et aucun
# 1 aucun
# port geogName
# public geogName
# à aucun
# l’ aucun
# Ouest aucun
# . aucun
# 1 aucun
# 251 aucun
# places geogName
# dont aucun
# 100 aucun
# pour aucun
# bateaux aucun
# de aucun
# passage aucun
# sur aucun
# l’ aucun
# ensemble aucun
# des aucun
# deux aucun
# ports geogName
# . aucun
# PORT geogName
# PUBLIC geogName
# : aucun
# 621 aucun
# places geogName
# . aucun
# PORT geogName
# PRIVÉ geogName
# : aucun
# 545 aucun
# places geogName
# . aucun
# Zone geogName
# de geogName
# mouillage geogName
# organisé geogName
# ( aucun
# en aucun
# saison aucun
# ) aucun
# : aucun
# 85 aucun
# places geogName
# supplémentaires geogName
# pour aucun
# bateaux aucun
# de aucun
# 7 aucun
# à aucun
# 16 aucun
# m. aucun
# Outillage aucun
# 1 aucun
# cale geogName
# de geogName
# halage geogName
# + aucun
# 1 aucun
# élévateur aucun
# à aucun
# bateaux aucun
# de aucun
# 35 aucun
# t. aucun
# Ravitaillement aucun
# Eau aucun
# aux aucun
# appontements geogName
# . aucun
# Poste geogName
# de geogName
# carburants geogName
# à aucun
# l’ aucun
# épi geogName
# entre aucun
# les aucun
# deux aucun
# ports geogName
# ( aucun
# longueur aucun
# 20 aucun
# m aucun
# par aucun
# 1,8 aucun
# à aucun
# 3 aucun
# m aucun
# d’ aucun
# eau aucun
# ) aucun
# . aucun
# Administration aucun
# Organisation aucun
# PORT geogName
# PUBLIC geogName
# : aucun
# gestion aucun
# concédée aucun
# à aucun
# la aucun
# commune geogName
# de geogName
# Cavalaire-sur-Mer geogName
# . aucun
# Bureau geogName
# du geogName
# port geogName
# public geogName
# : aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.17.81 aucun
# ; aucun
# télécopie aucun
# : aucun
# 04.64.64.67.06 aucun
# ; aucun
# mél aucun
# : aucun
# port@cavalaire.fr aucun
# . aucun
# Veille aucun
# VHF aucun
# en aucun
# saison aucun
# . aucun
# Site aucun
# web aucun
# : aucun
# www.cavalaire.fr aucun
# . aucun
# PORT geogName
# PRIVÉ geogName
# : aucun
# gestion aucun
# par aucun
# société aucun
# anonyme aucun
# ( aucun
# SACNPPC geogName
# ) aucun
# . aucun
# Bureau geogName
# du geogName
# port geogName
# privé geogName
# : aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.16.01 aucun
# ; aucun
# télécopie aucun
# : aucun
# 04.94.64.36.06 aucun
# ; aucun
# mél aucun
# : aucun
# info@port- aucun
# cavalaire.com aucun
# . aucun
# Veille aucun
# VHF aucun
# en aucun
# saison aucun
# . aucun
# Site aucun
# web aucun
# : aucun
# www.port-cavalaire.com aucun
# . aucun
# Accueil aucun
# des aucun
# navires aucun
# Au aucun
# quai geogName
# d’ geogName
# attente geogName
# , aucun
# devant aucun
# le aucun
# bureau geogName
# du geogName
# port geogName
# public geogName
# . aucun
# Services aucun
# Affaires aucun
# maritimes aucun
# : aucun
# à aucun
# Toulon geogName
# . aucun
# Douanes aucun
# : aucun
# à aucun
# Toulon geogName
# . aucun
# Poste geogName
# de geogName
# secours geogName
# du geogName
# Parc geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.11.54 aucun
# ( aucun
# du aucun
# 1er aucun
# juin aucun
# au aucun
# 30 aucun
# septembre aucun
# ) aucun
# . aucun
# Poste geogName
# de geogName
# secours geogName
# de geogName
# Pardigon geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.43.49 aucun
# ( aucun
# du aucun
# 15 aucun
# juin aucun
# au aucun
# 15 aucun
# septembre aucun
# ) aucun
# . aucun
# Gendarmerie geogName
# : aucun
# Rue geogName
# A. geogName
# Daudet geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.04.17 aucun
# . aucun
# Communications aucun
# Lignes aucun
# d’ aucun
# autocars aucun
# . aucun
# Gare geogName
# SNCF geogName
# à aucun
# Hyères geogName
# et aucun
# Toulon geogName
# . aucun
# Aéroport geogName
# de geogName
# Hyères geogName
# - geogName
# Le geogName
# Palyvestre geogName
# . aucun
# Ville geogName
# Mairie geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.04.26 aucun
# . aucun
# 4.5.5.4 aucun
# . aucun
# — aucun
# Port geogName
# de geogName
# Cavalaire geogName
# ( aucun
# 43 aucun
# ° aucun
# 10,3 aucun
# ' aucun
# N aucun
# — aucun
# 6 aucun
# ° aucun
# 32,2 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 206 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 21 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 206 aucun
# / aucun
# 0 aucun
# DU aucun
# CAP geogName
# BÉNAT geogName
# AU aucun
# CAP geogName
# CAMARAT geogName
# . aucun
# 01 aucun
# 5.4.8.1 aucun
# . aucun
# Généralités aucun
# 07 aucun
# L’ aucun
# étier geogName
# de geogName
# Port geogName
# des geogName
# Champs geogName
# est aucun
# situé aucun
# à aucun
# 1,5 aucun
# M aucun
# au aucun
# Sud aucun
# de aucun
# l’ aucun
# étier geogName
# de geogName
# la geogName
# Louippe geogName
# et aucun
# débouche aucun
# lui aucun
# aussi aucun
# dans aucun
# une aucun
# ouverture aucun
# de aucun
# la aucun
# digue geogName
# du geogName
# littoral geogName
# . aucun
# 01 aucun
# 9.2 aucun
# . aucun
# Du aucun
# cap geogName
# Vert geogName
# à aucun
# la aucun
# pointe geogName
# Rouge geogName
# . aucun
# Baie geogName
# de geogName
# Gorée geogName
# 07 aucun
# La aucun
# presqu’ geogName
# île geogName
# du aucun
# cap geogName
# Vert geogName
# comprend aucun
# deux aucun
# pointes geogName
# saillantes aucun
# orientées aucun
# , aucun
# l’ aucun
# une aucun
# vers aucun
# l’ aucun
# Ouest aucun
# et aucun
# l’ aucun
# autre aucun
# vers aucun
# le aucun
# Sud aucun
# . aucun
# 13 aucun
# Le aucun
# cap geogName
# Vert geogName
# , aucun
# terminé aucun
# par aucun
# la aucun
# pointe geogName
# des geogName
# Almadies geogName
# ( aucun
# 14 aucun
# ° aucun
# 44,47′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 31,95 aucun
# ' aucun
# W aucun
# ) aucun
# est aucun
# le aucun
# point aucun
# le aucun
# plus aucun
# occidental aucun
# de aucun
# la aucun
# côte geogName
# Ouest geogName
# du aucun
# continent geogName
# africain geogName
# . aucun
# Le aucun
# cap geogName
# Manuel geogName
# ( aucun
# 14 aucun
# ° aucun
# 38,77′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 25,98′ aucun
# W aucun
# ) aucun
# , aucun
# orienté aucun
# au aucun
# Sud aucun
# , aucun
# délimite aucun
# la aucun
# partie aucun
# Ouest aucun
# de aucun
# la aucun
# baie geogName
# de geogName
# Gorée geogName
# . aucun
# 19 aucun
# La aucun
# baie geogName
# de geogName
# Gorée geogName
# s’ aucun
# ouvre aucun
# entre aucun
# le aucun
# Cap geogName
# Manuel geogName
# et aucun
# la aucun
# pointe geogName
# Rouge geogName
# ( aucun
# 14 aucun
# ° aucun
# 38,11′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 10,42′ aucun
# W aucun
# ) aucun
# distante aucun
# de aucun
# 15 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# . aucun
# Bien aucun
# qu’ aucun
# ouverte aucun
# aux aucun
# vents aucun
# de aucun
# Sud aucun
# , aucun
# cette aucun
# vaste aucun
# baie geogName
# est aucun
# réputée aucun
# être aucun
# sûre aucun
# . aucun
# L’ aucun
# île geogName
# de geogName
# Gorée geogName
# ( aucun
# 14 aucun
# ° aucun
# 39,98′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 23,89′ aucun
# W aucun
# ) aucun
# se aucun
# trouve aucun
# dans aucun
# l’ aucun
# entrée geogName
# de aucun
# la aucun
# baie geogName
# . aucun
# 25 aucun
# Le aucun
# port geogName
# de geogName
# Dakar geogName
# , aucun
# décrit aucun
# dans aucun
# le aucun
# paragraphe aucun
# 9.2.3 aucun
# . aucun
# , aucun
# est aucun
# établi aucun
# dans aucun
# l’ aucun
# anse geogName
# qui aucun
# s’ aucun
# étend aucun
# entre aucun
# la aucun
# pointe geogName
# de geogName
# Dakar geogName
# ( aucun
# 14 aucun
# ° aucun
# 40,19′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 25,30′ aucun
# W aucun
# ) aucun
# , aucun
# au aucun
# Sud aucun
# et aucun
# la aucun
# pointe geogName
# de geogName
# Bel geogName
# - geogName
# Air geogName
# ( aucun
# 14 aucun
# ° aucun
# 42,08′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 25,03′ aucun
# W aucun
# ) aucun
# , aucun
# au aucun
# Nord aucun
# . aucun
# 31 aucun
# Outre aucun
# la aucun
# ville geogName
# de geogName
# Dakar geogName
# qui aucun
# occupe aucun
# la aucun
# majeure aucun
# partie aucun
# de aucun
# la aucun
# presqu’ geogName
# île geogName
# du aucun
# cap geogName
# Vert geogName
# , aucun
# la aucun
# côte geogName
# Nord geogName
# de aucun
# la aucun
# baie geogName
# de geogName
# Gorée geogName
# est aucun
# urbanisée aucun
# de aucun
# façon aucun
# presque aucun
# continue aucun
# depuis aucun
# la aucun
# pointe geogName
# de geogName
# Bel geogName
# - geogName
# Air geogName
# jusqu’ aucun
# à aucun
# Rufisque geogName
# . aucun
# 01 aucun
# 4.3.4.4 aucun
# . aucun
# Maupihaa aucun
# ( aucun
# Mopelia geogName
# ) aucun
# 07 aucun
# À aucun
# 100 aucun
# M aucun
# à aucun
# l’ aucun
# WSW aucun
# de aucun
# Maupiti geogName
# , aucun
# Maupihaa geogName
# ( aucun
# Mopelia geogName
# ) aucun
# [ aucun
# 16 aucun
# ° aucun
# 48 aucun
# ' aucun
# S aucun
# — aucun
# 153 aucun
# ° aucun
# 58 aucun
# ' aucun
# W aucun
# ] aucun
# est aucun
# un aucun
# atoll geogName
# de aucun
# 4,5 aucun
# M aucun
# de aucun
# diamètre aucun
# , aucun
# avec aucun
# une aucun
# longue aucun
# île geogName
# étroite geogName
# , geogName
# Motu geogName
# Maupihaa geogName
# , aucun
# couverte aucun
# de aucun
# cocotiers aucun
# , aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# un aucun
# motu aucun
# isolé aucun
# au aucun
# NW aucun
# et aucun
# un aucun
# récif- aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 221 aucun
# / aucun
# 0 aucun
# 221 aucun
# ÎLES geogName
# DU aucun
# VENT aucun
# – aucun
# ÎLES geogName
# SOUS-LE-VENT geogName
# – aucun
# ÎLES geogName
# AUSTRALES geogName
# barrière aucun
# juste aucun
# affleurant aucun
# au aucun
# SW aucun
# . aucun
# Sa aucun
# population aucun
# est aucun
# réduite aucun
# à aucun
# 3 aucun
# habitants aucun
# sédentaires aucun
# ( aucun
# 2012 aucun
# ) aucun
# , aucun
# vivant aucun
# de aucun
# la aucun
# pêche aucun
# et aucun
# de aucun
# la aucun
# récolte aucun
# du aucun
# coprah aucun
# . aucun
# Les aucun
# exploitations aucun
# de aucun
# fermes aucun
# perlières aucun
# et aucun
# de aucun
# nacres aucun
# sont aucun
# abandonnées aucun
# . aucun
# 13 aucun
# L’ aucun
# unique aucun
# passe geogName
# Taihaaru geogName
# Vahine geogName
# , aucun
# au aucun
# NW aucun
# de aucun
# l’ aucun
# atoll geogName
# , aucun
# est aucun
# étroite aucun
# ( aucun
# 35 aucun
# m aucun
# ) aucun
# mais aucun
# profonde aucun
# ( aucun
# 12 aucun
# m aucun
# ) aucun
# . aucun
# Son aucun
# balisage geogName
# , aucun
# détruit aucun
# par aucun
# les aucun
# intempéries geogName
# n’ aucun
# a aucun
# pas aucun
# été aucun
# restauré aucun
# ( aucun
# 2014 aucun
# ) aucun
# . aucun
# À aucun
# l’ aucun
# entrée geogName
# du aucun
# lagon geogName
# , aucun
# la aucun
# passe geogName
# se aucun
# divise aucun
# en aucun
# deux aucun
# chenaux geogName
# ; aucun
# celui aucun
# du aucun
# NE aucun
# , aucun
# non aucun
# balisé aucun
# , aucun
# n’ aucun
# est aucun
# praticable aucun
# que aucun
# par aucun
# de aucun
# petites aucun
# embarcations aucun
# ; aucun
# celui aucun
# du aucun
# SW aucun
# franchit aucun
# un aucun
# seuil aucun
# couvert aucun
# de aucun
# 3,7 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Il aucun
# doit aucun
# être aucun
# emprunté aucun
# avec aucun
# précaution aucun
# , aucun
# par aucun
# temps aucun
# clair aucun
# quand aucun
# les aucun
# têtes geogName
# de geogName
# corail geogName
# sont aucun
# bien aucun
# visibles aucun
# , aucun
# de aucun
# préférence aucun
# en aucun
# début aucun
# de aucun
# matinée aucun
# quand aucun
# le aucun
# courant aucun
# est aucun
# le aucun
# plus aucun
# faible aucun
# . aucun
# Le aucun
# courant aucun
# , aucun
# toujours aucun
# sortant aucun
# , aucun
# peut aucun
# atteindre aucun
# 9 aucun
# nœuds aucun
# par aucun
# forte aucun
# houle aucun
# de aucun
# SW aucun
# ( aucun
# ensachage aucun
# ) aucun
# et aucun
# provoque aucun
# des aucun
# tourbillons aucun
# près aucun
# du aucun
# plateau geogName
# de aucun
# corail aucun
# central aucun
# . aucun
# 19 aucun
# Le aucun
# lagon geogName
# est aucun
# très aucun
# vaste aucun
# et aucun
# profond aucun
# avec aucun
# de aucun
# nombreux aucun
# bancs geogName
# de geogName
# corail geogName
# bien aucun
# visibles aucun
# . aucun
# 25 aucun
# MOUILLAGE aucun
# . aucun
# — aucun
# Faire geogName
# route geogName
# à aucun
# 065 aucun
# ° aucun
# , aucun
# en aucun
# relevant aucun
# par aucun
# l’ aucun
# arrière aucun
# à aucun
# 245 aucun
# ° aucun
# l’ aucun
# extrémité aucun
# Sud aucun
# de aucun
# l’ aucun
# îlot geogName
# à aucun
# l’ aucun
# WSW aucun
# du aucun
# Motu geogName
# Manu geogName
# ; aucun
# mouiller aucun
# par aucun
# profondeur aucun
# de aucun
# 16 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# sable aucun
# avec aucun
# de aucun
# nombreuses aucun
# patates aucun
# de aucun
# corail aucun
# , aucun
# en aucun
# relevant aucun
# à aucun
# 312 aucun
# ° aucun
# la aucun
# pointe geogName
# SW geogName
# de aucun
# la aucun
# partie aucun
# Nord aucun
# du aucun
# Motu geogName
# Maupihaa geogName
# , aucun
# et aucun
# à aucun
# 0,3 aucun
# M aucun
# de aucun
# la aucun
# côte geogName
# . aucun
# Ne aucun
# pas aucun
# s’ aucun
# approcher aucun
# à aucun
# moins aucun
# de aucun
# 0,3 aucun
# M aucun
# de aucun
# la aucun
# côte geogName
# car aucun
# les aucun
# profondeurs aucun
# y aucun
# sont aucun
# moindres aucun
# que aucun
# celles aucun
# figurant aucun
# sur aucun
# la aucun
# carte aucun
# . aucun
# 31 aucun
# DÉBARQUEMENT aucun
# . aucun
# — aucun
# Les aucun
# embarcations aucun
# accostent aucun
# sur aucun
# la aucun
# plage geogName
# devant aucun
# les aucun
# rares geogName
# constructions geogName
# entretenues geogName
# . aucun
# 01 aucun
# 2.3 aucun
# . aucun
# Île geogName
# Miquelon geogName
# 01 aucun
# 4.3.4.6 aucun
# . aucun
# Manuae geogName
# ( aucun
# Scilly geogName
# ) aucun
# [ aucun
# Fanua geogName
# Ura geogName
# ] aucun
# 07 aucun
# Manuae geogName
# ( aucun
# Scilly geogName
# ) aucun
# [ aucun
# Fanua geogName
# Ura geogName
# ] aucun
# ( aucun
# 16 aucun
# ° aucun
# 30 aucun
# ' aucun
# S aucun
# — aucun
# 154 aucun
# ° aucun
# 40 aucun
# ' aucun
# W aucun
# ) aucun
# , aucun
# atoll geogName
# de aucun
# 6 aucun
# M aucun
# de aucun
# diamètre aucun
# , aucun
# est aucun
# le aucun
# plus aucun
# Ouest aucun
# des aucun
# Îles geogName
# Sous-le-Vent geogName
# . aucun
# Le aucun
# lagon geogName
# n’ aucun
# est aucun
# accessible aucun
# qu’ aucun
# aux aucun
# embarcations aucun
# par aucun
# une aucun
# échancrure aucun
# dans aucun
# le aucun
# récif geogName
# à aucun
# 0,4 aucun
# M aucun
# à aucun
# l’ aucun
# WSW aucun
# de aucun
# la aucun
# pointe geogName
# Nord geogName
# . aucun
# Une aucun
# autre aucun
# anfractuosité aucun
# dans aucun
# la aucun
# barrière geogName
# permet aucun
# le aucun
# débarquement aucun
# par aucun
# baleinière aucun
# sur aucun
# la aucun
# côte geogName
# Est geogName
# près aucun
# du aucun
# village geogName
# ; aucun
# l’ aucun
# embarcation aucun
# doit aucun
# être aucun
# hissée aucun
# sur aucun
# le aucun
# platier aucun
# . aucun
# Ce aucun
# débarquement aucun
# de aucun
# même aucun
# que aucun
# le aucun
# franchissement aucun
# de aucun
# la aucun
# passe geogName
# ne aucun
# peuvent aucun
# être aucun
# envisagés aucun
# que aucun
# par aucun
# temps aucun
# calme aucun
# . aucun
# 13 aucun
# Des aucun
# îlots geogName
# boisés geogName
# se aucun
# voient aucun
# dans aucun
# la aucun
# partie aucun
# Est aucun
# du aucun
# récif geogName
# dont aucun
# les aucun
# côtes geogName
# Ouest geogName
# et aucun
# Sud aucun
# sont aucun
# à aucun
# fleur aucun
# d’ aucun
# eau aucun
# . aucun
# L’ aucun
# atoll geogName
# présente aucun
# à aucun
# l’ aucun
# Ouest aucun
# un aucun
# banc geogName
# de aucun
# sable aucun
# de aucun
# plus aucun
# de aucun
# 10 aucun
# km aucun
# , aucun
# parfois aucun
# confondu aucun
# avec aucun
# la aucun
# limite aucun
# du aucun
# récif geogName
# . aucun
# 25 aucun
# Cet aucun
# atoll geogName
# est aucun
# inclus aucun
# dans aucun
# la aucun
# réserve geogName
# territoriale geogName
# de geogName
# Scilly geogName
# et aucun
# Bellingshausen aucun
# ; aucun
# il aucun
# est aucun
# soumis aucun
# à aucun
# la aucun
# même aucun
# réglemen aucun
# tation aucun
# que aucun
# l’ aucun
# atoll geogName
# Motu geogName
# One geogName
# ( aucun
# § aucun
# 4.3.4.5 aucun
# . aucun
# ) aucun
# . aucun
# La aucun
# population aucun
# , aucun
# très aucun
# isolée aucun
# , aucun
# est aucun
# limitée aucun
# à aucun
# moins aucun
# de aucun
# 10 aucun
# personnes aucun
# . aucun
# 31 aucun
# Note aucun
# : aucun
# Il aucun
# existe aucun
# également aucun
# une aucun
# île geogName
# du geogName
# nom geogName
# de geogName
# Manuae geogName
# dans aucun
# les aucun
# Southern geogName
# Cook geogName
# Islands geogName
# . aucun
# 222 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 222 aucun
# / aucun
# 0 aucun
# ÎLES geogName
# AUSTRALES geogName
# 01 aucun
# 4.3.3.3 aucun
# . aucun
# Côte geogName
# de geogName
# Tahaa geogName
# 05 aucun
# Sur aucun
# la aucun
# côte geogName
# SW geogName
# de geogName
# Tahaa geogName
# , aucun
# la aucun
# passe geogName
# Paipai geogName
# , aucun
# large aucun
# de aucun
# 200 aucun
# m aucun
# et aucun
# profonde aucun
# , aucun
# est aucun
# bien aucun
# balisée aucun
# . aucun
# Son aucun
# axe geogName
# ( aucun
# 009 aucun
# ° aucun
# ) aucun
# est aucun
# marqué aucun
# par aucun
# l’ aucun
# alignement geogName
# de aucun
# deux aucun
# colonnes geogName
# lumineuses geogName
# à aucun
# bandes aucun
# horizontales aucun
# rouges aucun
# et aucun
# blanches aucun
# , aucun
# implantées aucun
# à aucun
# la aucun
# pointe geogName
# Tepari geogName
# , aucun
# au aucun
# Nord aucun
# de aucun
# la aucun
# passe geogName
# . aucun
# 09 aucun
# 4.3.3.3.A. aucun
# — aucun
# Tahaa geogName
# – aucun
# Passe geogName
# Paipai geogName
# – aucun
# Alignement geogName
# à aucun
# 009 aucun
# ° aucun
# . aucun
# 13 aucun
# La aucun
# passe geogName
# Paipai geogName
# débouche aucun
# sur aucun
# la aucun
# baie geogName
# Hurepiti geogName
# qui aucun
# offre aucun
# un aucun
# excellent aucun
# abri aucun
# par aucun
# tous aucun
# les aucun
# temps aucun
# . aucun
# De aucun
# nombreuses aucun
# bouées geogName
# sont aucun
# mouillées aucun
# dans aucun
# sa aucun
# partie aucun
# NW aucun
# . aucun
# Mouillage aucun
# , aucun
# par aucun
# profondeur aucun
# de aucun
# 25 aucun
# à aucun
# 30 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# sable aucun
# d’ aucun
# excellente aucun
# tenue aucun
# , aucun
# en aucun
# relevant aucun
# la aucun
# pointe geogName
# Tepari geogName
# à aucun
# 280 aucun
# ° aucun
# et aucun
# 0,3 aucun
# M. aucun
# Pour aucun
# se aucun
# rapprocher aucun
# de aucun
# Tiva geogName
# , aucun
# mouillage aucun
# par aucun
# profondeur aucun
# de aucun
# 30 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# de aucun
# bonne aucun
# tenue aucun
# , aucun
# en aucun
# relevant aucun
# à aucun
# 320 aucun
# ° aucun
# et aucun
# 0,6 aucun
# M aucun
# le aucun
# clocher geogName
# , aucun
# à aucun
# l’ aucun
# Ouest aucun
# de aucun
# la aucun
# baie geogName
# . aucun
# Il aucun
# y aucun
# a aucun
# un aucun
# appontement geogName
# devant aucun
# l’ aucun
# église geogName
# et aucun
# un aucun
# autre aucun
# à aucun
# 0,2 aucun
# M aucun
# au aucun
# NW aucun
# de aucun
# la aucun
# pointe geogName
# Tepari geogName
# . aucun
# 17 aucun
# Le aucun
# chenal geogName
# intérieur aucun
# autour aucun
# de aucun
# l’ aucun
# île geogName
# est aucun
# marqué aucun
# par aucun
# un aucun
# balisage geogName
# , aucun
# en aucun
# partie aucun
# lumineux aucun
# . aucun
# Les aucun
# balises geogName
# sont aucun
# pour aucun
# la aucun
# plupart aucun
# implantées aucun
# sur aucun
# le aucun
# récif geogName
# côtier geogName
# de aucun
# l’ aucun
# île geogName
# ; aucun
# il aucun
# ne aucun
# faut aucun
# pas aucun
# les aucun
# serrer aucun
# de aucun
# trop aucun
# près aucun
# , aucun
# car aucun
# elles aucun
# ne aucun
# sont aucun
# pas aucun
# toujours aucun
# au aucun
# bord aucun
# du aucun
# récif geogName
# . aucun
# 21 aucun
# À aucun
# 2,7 aucun
# M aucun
# au aucun
# SE aucun
# de aucun
# la aucun
# passe geogName
# Paipai geogName
# , aucun
# la aucun
# baie geogName
# Apu geogName
# , aucun
# offre aucun
# d’ aucun
# excellents aucun
# mouillages aucun
# pour aucun
# petits aucun
# navires aucun
# notamment aucun
# à aucun
# 0,3 aucun
# M aucun
# dans aucun
# le aucun
# NNE aucun
# de aucun
# l aucun
# ’ aucun
# île geogName
# Toapuhi geogName
# par aucun
# 33 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# 25 aucun
# Les aucun
# grands aucun
# navires aucun
# peuvent aucun
# mouiller aucun
# par aucun
# profondeur aucun
# de aucun
# 43 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# sable aucun
# , aucun
# à aucun
# 0,6 aucun
# M aucun
# au aucun
# Sud aucun
# de aucun
# la aucun
# pointe geogName
# Toamaro geogName
# , aucun
# pointe geogName
# SE geogName
# de aucun
# la aucun
# baie geogName
# Apu geogName
# . aucun
# 29 aucun
# Un aucun
# appontement geogName
# de aucun
# 15 aucun
# m aucun
# de aucun
# long aucun
# et aucun
# 5 aucun
# m aucun
# d’ aucun
# eau aucun
# se aucun
# trouve aucun
# sur aucun
# le aucun
# côté aucun
# Ouest aucun
# de aucun
# la aucun
# pointe geogName
# Toamaro geogName
# ; aucun
# c’ aucun
# est aucun
# tout aucun
# ce aucun
# qui aucun
# reste aucun
# de aucun
# la aucun
# marina geogName
# Iti geogName
# après aucun
# la aucun
# fermeture aucun
# du aucun
# yacht geogName
# club geogName
# « geogName
# Taravana geogName
# » aucun
# en aucun
# 2013 aucun
# . aucun
# 33 aucun
# À aucun
# 1,8 aucun
# M aucun
# plus aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# on aucun
# peut aucun
# mouiller aucun
# devant aucun
# le aucun
# village geogName
# de geogName
# Vaitoare geogName
# , aucun
# par aucun
# profondeur aucun
# de aucun
# 30 aucun
# à aucun
# 40 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# d’ aucun
# excellente aucun
# tenue aucun
# en aucun
# relevant aucun
# à aucun
# 255 aucun
# ° aucun
# la aucun
# pointe geogName
# SE geogName
# de aucun
# l’ aucun
# îlot geogName
# Fatufatu geogName
# et aucun
# à aucun
# 341 aucun
# ° aucun
# la aucun
# pointe geogName
# Sud geogName
# de aucun
# l’ aucun
# appontement geogName
# . aucun
# 37 aucun
# Sur aucun
# la aucun
# côte geogName
# Est geogName
# de aucun
# l’ aucun
# île geogName
# , aucun
# la aucun
# passe geogName
# Toahotu geogName
# , aucun
# bien aucun
# balisée aucun
# , aucun
# large aucun
# de aucun
# 150 aucun
# m aucun
# et aucun
# profonde aucun
# , aucun
# se aucun
# franchit aucun
# sur aucun
# l’ aucun
# alignement geogName
# ( aucun
# 293 aucun
# ° aucun
# ) aucun
# d’ aucun
# une aucun
# échancrure geogName
# remarquable aucun
# , aucun
# légèrement aucun
# au aucun
# Sud aucun
# du aucun
# mont geogName
# Puurauti geogName
# , aucun
# par aucun
# une aucun
# balise geogName
# , aucun
# peu aucun
# visible aucun
# , aucun
# implantée aucun
# au aucun
# pied aucun
# de aucun
# la aucun
# pointe geogName
# Pataaia geogName
# , aucun
# et aucun
# par aucun
# le aucun
# milieu aucun
# du aucun
# passage geogName
# entre aucun
# l’ aucun
# îlot geogName
# Mahaea geogName
# et aucun
# l’ aucun
# îlot geogName
# Toahotu geogName
# ; aucun
# dès aucun
# que aucun
# ce aucun
# dernier aucun
# est aucun
# paré aucun
# , aucun
# venir aucun
# rondement aucun
# par aucun
# la aucun
# gauche aucun
# en aucun
# route geogName
# à aucun
# 255 aucun
# ° aucun
# pour aucun
# laisser aucun
# au aucun
# Nord aucun
# un aucun
# haut-fond geogName
# couvert aucun
# de aucun
# 5,2 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# non aucun
# balisé aucun
# , aucun
# marqué aucun
# par aucun
# une aucun
# décoloration aucun
# de aucun
# l’ aucun
# eau aucun
# , aucun
# parfois aucun
# peu aucun
# visible aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 209 aucun
# / aucun
# 0 aucun
# 209 aucun
# ÎLES geogName
# DU aucun
# VENT aucun
# – aucun
# ÎLES geogName
# SOUS-LE-VENT geogName
# – aucun
# ÎLES geogName
# AUSTRALES geogName
# 41 aucun
# 4.3.3.3.B. aucun
# — aucun
# Tahaa geogName
# – aucun
# Passe geogName
# de geogName
# Toahotu geogName
# – aucun
# Alignement geogName
# à aucun
# 293 aucun
# ° aucun
# . aucun
# 45 aucun
# Un aucun
# chenal geogName
# secondaire geogName
# marqué aucun
# par aucun
# des aucun
# espars geogName
# noir aucun
# et aucun
# blanc aucun
# permet aucun
# aux aucun
# petites aucun
# embarcations aucun
# de aucun
# passer aucun
# sur aucun
# le aucun
# récif geogName
# - aucun
# barrière aucun
# au aucun
# Sud aucun
# de aucun
# la aucun
# passe geogName
# de geogName
# Toahotu geogName
# , aucun
# dans aucun
# la aucun
# partie aucun
# submergée aucun
# de aucun
# 0,5 aucun
# à aucun
# 1,5 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# et aucun
# d’ aucun
# accéder aucun
# au aucun
# mouillage geogName
# d’ geogName
# Uturoa geogName
# en aucun
# longeant aucun
# le aucun
# côté aucun
# Est aucun
# du aucun
# récif geogName
# . aucun
# 49 aucun
# La aucun
# baie geogName
# Haamene geogName
# constitue aucun
# une aucun
# brèche geogName
# profonde aucun
# de aucun
# 2,4 aucun
# M aucun
# à aucun
# l’ aucun
# intérieur aucun
# de aucun
# l’ aucun
# île geogName
# à aucun
# partir aucun
# de aucun
# la aucun
# pointe geogName
# Para geogName
# . aucun
# On aucun
# peut aucun
# mouiller aucun
# dans aucun
# la aucun
# partie aucun
# Est aucun
# de aucun
# la aucun
# baie geogName
# par aucun
# profondeur aucun
# de aucun
# 30 aucun
# à aucun
# 40 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# . aucun
# Appontement aucun
# au aucun
# NE aucun
# de aucun
# la aucun
# baie geogName
# de geogName
# 18 aucun
# m aucun
# de aucun
# long aucun
# par aucun
# 2 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# 53 aucun
# À aucun
# 0,5 aucun
# M aucun
# au aucun
# Nord aucun
# de aucun
# la aucun
# pointe geogName
# Pataaia geogName
# , aucun
# la aucun
# baie geogName
# Faaha geogName
# , aucun
# longue aucun
# de aucun
# 1,1 aucun
# M aucun
# , aucun
# permet aucun
# de aucun
# mouiller aucun
# par aucun
# profondeur aucun
# de aucun
# 32 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# . aucun
# Le aucun
# village geogName
# de geogName
# Faaha geogName
# , aucun
# en aucun
# fond aucun
# de aucun
# baie geogName
# , aucun
# dispose aucun
# d’ aucun
# un aucun
# quai geogName
# . aucun
# 57 aucun
# Le aucun
# chenal geogName
# se aucun
# rétrécit aucun
# ( aucun
# 0,15 aucun
# M aucun
# ) aucun
# à aucun
# la aucun
# pointe geogName
# Matahira geogName
# , aucun
# pointe geogName
# Ouest geogName
# de aucun
# l’ aucun
# île geogName
# , aucun
# puis aucun
# s’ aucun
# élargit aucun
# au aucun
# NE aucun
# de aucun
# l’ aucun
# île geogName
# . aucun
# 61 aucun
# Il aucun
# est aucun
# conseillé aucun
# de aucun
# suivre aucun
# le aucun
# chenal geogName
# en aucun
# serrant aucun
# le aucun
# récif geogName
# côtier geogName
# de geogName
# Tahaa geogName
# , aucun
# plus aucun
# accore aucun
# et aucun
# plus aucun
# visible aucun
# que aucun
# le aucun
# bord aucun
# intérieur aucun
# du aucun
# récif geogName
# - aucun
# barrière aucun
# . aucun
# Le aucun
# seul aucun
# passage aucun
# délicat aucun
# est aucun
# au aucun
# Nord aucun
# de aucun
# la aucun
# baie geogName
# Pahure geogName
# ( aucun
# 16 aucun
# ° aucun
# 35 aucun
# ' aucun
# S aucun
# — aucun
# 151 aucun
# ° aucun
# 29 aucun
# ' aucun
# W aucun
# ) aucun
# , aucun
# où aucun
# le aucun
# chenal geogName
# est aucun
# rétréci aucun
# par aucun
# plusieurs aucun
# dangers geogName
# , aucun
# que aucun
# l’ aucun
# on aucun
# peut aucun
# contourner aucun
# par aucun
# le aucun
# Nord aucun
# en aucun
# arrondissant aucun
# à aucun
# plus aucun
# de aucun
# 0,15 aucun
# M aucun
# le aucun
# récif geogName
# Moora geogName
# , aucun
# balisé aucun
# mais aucun
# débordé aucun
# de aucun
# 0,1 aucun
# M aucun
# par aucun
# un aucun
# haut-fond geogName
# recouvert aucun
# de aucun
# 4,1 aucun
# m aucun
# d’ aucun
# eau aucun
# puis aucun
# en aucun
# passant aucun
# au aucun
# Sud aucun
# du aucun
# récif geogName
# Faremao geogName
# , aucun
# marqué aucun
# par aucun
# une aucun
# balise geogName
# latérale geogName
# tribord geogName
# . aucun
# 65 aucun
# À aucun
# l’ aucun
# embouchure geogName
# de aucun
# la aucun
# rivière geogName
# Iripau geogName
# , aucun
# le aucun
# village geogName
# de geogName
# Patio geogName
# , aucun
# centre aucun
# administratif aucun
# de aucun
# l’ aucun
# île geogName
# , aucun
# offre aucun
# une aucun
# darse aucun
# et aucun
# des aucun
# quais geogName
# par aucun
# 1,5 aucun
# m aucun
# d’ aucun
# eau aucun
# ; aucun
# il aucun
# possède aucun
# une aucun
# infirmerie aucun
# . aucun
# 69 aucun
# Vers aucun
# l’ aucun
# Ouest aucun
# , aucun
# le aucun
# chenal geogName
# mène geogName
# sans aucun
# difficulté aucun
# jusqu’ aucun
# à aucun
# la aucun
# baie geogName
# Tapuamu geogName
# offrant aucun
# dans aucun
# sa aucun
# partie aucun
# Sud aucun
# , aucun
# un aucun
# quai geogName
# , aucun
# orienté aucun
# Est-Ouest aucun
# , aucun
# de aucun
# 74 aucun
# m aucun
# de aucun
# long aucun
# par aucun
# 6 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# avec aucun
# un aucun
# slip geogName
# de aucun
# 14 aucun
# m aucun
# de aucun
# large aucun
# à aucun
# son aucun
# extrémité aucun
# Ouest aucun
# , aucun
# et aucun
# une aucun
# darse aucun
# pour aucun
# bonitiers aucun
# et aucun
# navires aucun
# de aucun
# plaisance aucun
# par aucun
# 1,7 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Alimentation aucun
# en aucun
# eau aucun
# possible aucun
# . aucun
# Il aucun
# est aucun
# interdit aucun
# de aucun
# mouiller aucun
# à aucun
# l’ aucun
# ouvert geogName
# de aucun
# cette aucun
# baie geogName
# sur aucun
# une aucun
# bande geogName
# de aucun
# 0,3 aucun
# M aucun
# , aucun
# axée aucun
# à aucun
# 302 aucun
# ° aucun
# entre aucun
# le aucun
# quai geogName
# et aucun
# l’ aucun
# îlot geogName
# Tautau geogName
# ( aucun
# canalisation aucun
# eau aucun
# et aucun
# gaz aucun
# ) aucun
# . aucun
# 210 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 210 aucun
# / aucun
# 0 aucun
# ÎLES geogName
# SOUS-LE-VENT geogName
# 73 aucun
# 4.3.3.3.C. aucun
# — aucun
# Tahaa geogName
# – aucun
# Quai geogName
# de geogName
# la aucun
# baie geogName
# de geogName
# Tapuamu geogName
# . aucun
# 77 aucun
# Le aucun
# village geogName
# de geogName
# Tiva geogName
# , aucun
# à aucun
# 1,5 aucun
# M aucun
# au aucun
# Sud aucun
# de aucun
# Tapuamu geogName
# , aucun
# possède aucun
# un aucun
# appontement geogName
# de geogName
# 9 aucun
# m aucun
# de aucun
# long aucun
# par aucun
# 2,7 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# accessible aucun
# aux aucun
# petits aucun
# caboteurs aucun
# . aucun
# 81 aucun
# L’ aucun
# accès geogName
# à aucun
# Uturoa geogName
# par aucun
# la aucun
# passe geogName
# Toahotu geogName
# est aucun
# moins aucun
# facile aucun
# que aucun
# par aucun
# celle aucun
# de aucun
# Paipai geogName
# ou aucun
# par aucun
# celles aucun
# de aucun
# Teavapiti geogName
# ( aucun
# § aucun
# 4.3.3.5 aucun
# . aucun
# ) aucun
# ou aucun
# de aucun
# Rautoanui geogName
# ( aucun
# § aucun
# 4.3.3.4 aucun
# . aucun
# ) aucun
# . aucun
# 01 aucun
# 5.4.8.3 aucun
# . aucun
# Accès aucun
# 07 aucun
# L’ aucun
# entrée geogName
# du aucun
# port geogName
# est aucun
# marquée aucun
# par aucun
# une aucun
# balise geogName
# latérale geogName
# tribord geogName
# à geogName
# panneaux geogName
# réfléchissants aucun
# . aucun
# La aucun
# rive geogName
# Sud geogName
# est aucun
# débordée aucun
# par aucun
# des aucun
# hauts-fonds geogName
# , aucun
# il aucun
# faut aucun
# se aucun
# rapprocher aucun
# de aucun
# la aucun
# rive geogName
# Nord geogName
# en aucun
# restant aucun
# bien aucun
# sur aucun
# l’ aucun
# axe geogName
# du aucun
# chenal geogName
# . aucun
# 01 aucun
# 4.3 aucun
# . aucun
# Îles geogName
# Sous-le-Vent geogName
# 01 aucun
# 5.4.7.3 aucun
# . aucun
# Données aucun
# portuaires aucun
# 07 aucun
# Caractéristiques aucun
# nautiques aucun
# Hydrographie aucun
# locale aucun
# Appontements aucun
# immergés aucun
# à aucun
# PMVE aucun
# dans aucun
# l’ aucun
# étier geogName
# de geogName
# la geogName
# Louippe geogName
# . aucun
# Installations geogName
# portuaires geogName
# Navires aucun
# admis aucun
# Infrastructures geogName
# Navires aucun
# ostréicoles aucun
# et aucun
# de aucun
# plaisance aucun
# jusqu’ aucun
# à aucun
# 11 aucun
# m aucun
# de aucun
# longueur aucun
# , aucun
# 4 aucun
# m aucun
# de aucun
# largeur aucun
# , aucun
# 3 aucun
# m aucun
# de aucun
# TE aucun
# en aucun
# VE aucun
# et aucun
# 1 aucun
# m aucun
# de aucun
# TE aucun
# en aucun
# ME aucun
# . aucun
# 89 aucun
# appontements aucun
# de aucun
# bois aucun
# privés aucun
# le aucun
# long aucun
# des aucun
# perrés geogName
# du aucun
# canal aucun
# , aucun
# pas aucun
# de aucun
# place aucun
# pour aucun
# les aucun
# navires aucun
# de aucun
# passage aucun
# . aucun
# Outillage aucun
# 2 aucun
# cales aucun
# réservées aucun
# aux aucun
# professionnels aucun
# . aucun
# Organisation aucun
# Administration aucun
# Port geogName
# concédé aucun
# par aucun
# le aucun
# conseil aucun
# départemental aucun
# à aucun
# la aucun
# CCI geogName
# Vendée geogName
# , aucun
# tél aucun
# : aucun
# 02 aucun
# 51 aucun
# 45 aucun
# 32 aucun
# 32 aucun
# . aucun
# Surveillant aucun
# de aucun
# port geogName
# : aucun
# 06 aucun
# 07 aucun
# 74 aucun
# 84 aucun
# 65 aucun
# , aucun
# astreinte aucun
# : aucun
# 06 aucun
# 81 aucun
# 53 aucun
# 71 aucun
# 20 aucun
# . aucun
# Services aucun
# DDTM aucun
# à aucun
# Nantes geogName
# , aucun
# 10 aucun
# boulevard geogName
# Gaston geogName
# Serpette geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 02.40.67.26.26 aucun
# ; aucun
# télécopie aucun
# : aucun
# 02.40.67.25.52 aucun
# ; aucun
# mél aucun
# : aucun
# ddtm@loire aucun
# - aucun
# atlantique.gouv.fr aucun
# DML aucun
# à aucun
# Nantes geogName
# , aucun
# 9 aucun
# boulevard geogName
# de geogName
# Verdun geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 02.40.11.77.50 aucun
# ; aucun
# télécopie aucun
# : aucun
# 02.40.11.77.91 aucun
# ; aucun
# ddtm-dml@loire-atlantique.gouv.fr aucun
# Communications aucun
# Liaisons aucun
# routières aucun
# vers aucun
# Nantes geogName
# ( aucun
# 53 aucun
# km aucun
# ) aucun
# , aucun
# pont geogName
# de geogName
# Saint-Nazaire geogName
# à aucun
# 40 aucun
# km aucun
# , aucun
# La aucun
# Roche-sur-Yon aucun
# à aucun
# 67 aucun
# km aucun
# . aucun
# Ville geogName
# Bouin geogName
# , geogName
# commune geogName
# de geogName
# Vendée geogName
# , aucun
# 2 aucun
# 152 aucun
# habitants aucun
# ( aucun
# 2015 aucun
# ) aucun
# 5.4.7.3 aucun
# . aucun
# — aucun
# Port geogName
# des geogName
# Brochets geogName
# ( aucun
# 46 aucun
# ° aucun
# 59,96 aucun
# ' aucun
# N aucun
# — aucun
# 2 aucun
# ° aucun
# 02,14 aucun
# ' aucun
# W aucun
# ) aucun
# . aucun
# 2126 aucun
# 01 aucun
# 4.3.3.6 aucun
# . aucun
# Uturoa aucun
# 07 aucun
# Uturoa geogName
# ( aucun
# 16 aucun
# ° aucun
# 44 aucun
# ' aucun
# S aucun
# — aucun
# 151 aucun
# ° aucun
# 26 aucun
# ' aucun
# W aucun
# ) aucun
# est aucun
# le aucun
# mouillage aucun
# le aucun
# plus aucun
# fréquenté aucun
# des aucun
# Îles geogName
# Sous-le-Vent geogName
# . aucun
# 13 aucun
# La aucun
# ville geogName
# , aucun
# 3 aucun
# 736 aucun
# habitants aucun
# ( aucun
# 2017 aucun
# ) aucun
# , aucun
# s’ aucun
# étend aucun
# le aucun
# long aucun
# du aucun
# rivage geogName
# depuis aucun
# la aucun
# pointe geogName
# Tonoi geogName
# jusqu’ aucun
# à aucun
# la aucun
# pointe geogName
# Faretara geogName
# à aucun
# 1,3 aucun
# M aucun
# au aucun
# NW aucun
# . aucun
# Le aucun
# temple aucun
# , aucun
# grande aucun
# maison geogName
# blanche aucun
# au aucun
# milieu aucun
# de aucun
# la aucun
# ville geogName
# porte aucun
# un aucun
# clocher geogName
# qui aucun
# est aucun
# un aucun
# amer geogName
# remarquable aucun
# pour aucun
# les aucun
# navires aucun
# venant aucun
# de aucun
# Tahaa geogName
# . aucun
# L’ aucun
# hôpital geogName
# , aucun
# grand aucun
# immeuble aucun
# jaune aucun
# en aucun
# béton aucun
# , aucun
# est aucun
# implanté aucun
# sur aucun
# la aucun
# pointe geogName
# du geogName
# Roi geogName
# Tamatoa geogName
# en aucun
# centre geogName
# - geogName
# ville geogName
# . aucun
# 19 aucun
# Le aucun
# port geogName
# est aucun
# constitué aucun
# par aucun
# le aucun
# plan aucun
# d’ aucun
# eau aucun
# large aucun
# de aucun
# 0,25 aucun
# M aucun
# environ aucun
# qui aucun
# s’ aucun
# étend aucun
# entre aucun
# la aucun
# pointe geogName
# Tonoi geogName
# et aucun
# la aucun
# pointe geogName
# du geogName
# Roi geogName
# Tamatoa geogName
# . aucun
# 25 aucun
# Mouillage aucun
# recommandé aucun
# pour aucun
# grands aucun
# navires aucun
# par aucun
# profondeur aucun
# de aucun
# 32 aucun
# m aucun
# , aucun
# à aucun
# 0,5 aucun
# M aucun
# au aucun
# NNW aucun
# de aucun
# l’ aucun
# extrémité aucun
# Ouest aucun
# de aucun
# la aucun
# piste aucun
# de aucun
# l’ aucun
# aérodrome geogName
# d’ geogName
# Uturoa geogName
# . aucun
# 31 aucun
# Trois aucun
# postes geogName
# de geogName
# mouillage geogName
# d’ geogName
# attente geogName
# se aucun
# trouvent aucun
# devant aucun
# le aucun
# port geogName
# de geogName
# Uturoa geogName
# ; aucun
# ils aucun
# sont aucun
# portés aucun
# sur aucun
# la aucun
# carte aucun
# . aucun
# Le aucun
# poste geogName
# le aucun
# plus aucun
# Sud aucun
# est aucun
# moins aucun
# recommandé aucun
# , aucun
# car aucun
# outre aucun
# son aucun
# failble aucun
# rayon aucun
# d’ aucun
# évitage aucun
# , aucun
# il aucun
# est aucun
# soumis aucun
# à aucun
# un aucun
# courant aucun
# plus aucun
# fort aucun
# portant aucun
# ...
# en aucun
# dur aucun
# assez aucun
# bonnes aucun
# dans aucun
# l’ aucun
# ensemble aucun
# vers aucun
# Dikhil geogName
# et geogName
# Ali geogName
# Sabieh geogName
# . aucun
# Liaison aucun
# par aucun
# route aucun
# avec aucun
# Arta aucun
# à aucun
# 40 aucun
# km aucun
# et aucun
# Addis geogName
# - geogName
# Abeba geogName
# . aucun
# Liaison aucun
# par aucun
# voie geogName
# ferrée geogName
# avec geogName
# Addis geogName
# - geogName
# Abeba geogName
# ( aucun
# 784 aucun
# km aucun
# de aucun
# voie geogName
# métrique geogName
# ) aucun
# . aucun
# Liaisons aucun
# maritimes aucun
# régulières aucun
# avec aucun
# le aucun
# monde aucun
# entier aucun
# . aucun
# Aéroport geogName
# international geogName
# à aucun
# 4 aucun
# km aucun
# au aucun
# Sud aucun
# de aucun
# la aucun
# ville geogName
# . aucun
# Vols aucun
# internationaux aucun
# tous aucun
# les aucun
# jours aucun
# de aucun
# la aucun
# semaine aucun
# . aucun
# Capitale geogName
# de aucun
# la aucun
# République geogName
# de geogName
# Djibouti geogName
# . aucun
# Ambassade aucun
# : aucun
# 45 aucun
# , aucun
# boulevard aucun
# du aucun
# Maréchal geogName
# Foch geogName
# . aucun
# B.P. aucun
# 2039 aucun
# . aucun
# Tél aucun
# . aucun
# : aucun
# +253 aucun
# 35 aucun
# 09 aucun
# 63 aucun
# . aucun
# Télécopie aucun
# : aucun
# + aucun
# 253 aucun
# 35 aucun
# 02 aucun
# 72 aucun
# . aucun
# Consulat geogName
# Général geogName
# : aucun
# Villa geogName
# Normandie geogName
# , aucun
# avenue geogName
# du geogName
# Maréchal geogName
# Lyautey geogName
# . aucun
# B.P. aucun
# 75 aucun
# . aucun
# Tél aucun
# . aucun
# : aucun
# +253 aucun
# 35 aucun
# 25 aucun
# 03 aucun
# . aucun
# Télécopie aucun
# : aucun
# +253 aucun
# 35 aucun
# 00 aucun
# 07 aucun
# . aucun
# Hôpital aucun
# civil aucun
# d’ aucun
# environ aucun
# 600 aucun
# lits aucun
# dans aucun
# la aucun
# partie aucun
# Nord aucun
# du aucun
# Plateau geogName
# du geogName
# Serpent geogName
# , aucun
# dispensaire aucun
# près aucun
# de aucun
# la aucun
# Capitainerie geogName
# du geogName
# port geogName
# , aucun
# clinique aucun
# privée aucun
# et aucun
# hôpital aucun
# militaire aucun
# . aucun
# La aucun
# poste geogName
# principale geogName
# est aucun
# située aucun
# à aucun
# environ aucun
# 300 aucun
# m aucun
# au aucun
# SSW aucun
# de aucun
# la aucun
# cathédrale geogName
# . aucun
# Population aucun
# estimée aucun
# à aucun
# 810 aucun
# 000 aucun
# habitants aucun
# ( aucun
# 2014 aucun
# ) aucun
# , aucun
# soit aucun
# plus aucun
# des aucun
# 2/3 aucun
# de aucun
# l’ aucun
# ensemble aucun
# de aucun
# la aucun
# population aucun
# du aucun
# pays geogName
# . aucun
# 8.3.2.8.A. aucun
# — aucun
# Djibouti geogName
# ( aucun
# 11 aucun
# ° aucun
# 36 aucun
# ' aucun
# N aucun
# — aucun
# 43 aucun
# ° aucun
# 08 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 13 aucun
# À aucun
# l’ aucun
# Ouest aucun
# du aucun
# Plateau geogName
# du geogName
# Marabout geogName
# , aucun
# la aucun
# jetée geogName
# du geogName
# Marabout geogName
# est aucun
# perpendiculaire aucun
# à aucun
# son aucun
# extrémité aucun
# , aucun
# à aucun
# la aucun
# jetée geogName
# du geogName
# Large geogName
# . aucun
# À aucun
# l’ aucun
# extrémité aucun
# SW aucun
# de aucun
# la aucun
# Jetée geogName
# du geogName
# Large geogName
# , aucun
# le aucun
# môle geogName
# du geogName
# Fontainebleau geogName
# a aucun
# été aucun
# construit aucun
# sur aucun
# l’ aucun
# épave geogName
# du aucun
# navire aucun
# du aucun
# même aucun
# nom aucun
# . aucun
# 19 aucun
# 25 aucun
# À aucun
# 0,1 aucun
# M aucun
# au aucun
# Sud aucun
# du aucun
# Môle geogName
# Sud geogName
# , aucun
# se aucun
# situe aucun
# la aucun
# jetée geogName
# du geogName
# Gouvernement geogName
# . aucun
# 8.3.2.8.B. aucun
# — aucun
# Môle geogName
# du geogName
# Fontainebleau geogName
# au aucun
# Nord aucun
# ( aucun
# Origine geogName
# Marine aucun
# nationale aucun
# ) aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 13 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 277 aucun
# / aucun
# 0 aucun
# 277 aucun
# CÔTE geogName
# SUD geogName
# DU aucun
# GOLFE geogName
# D' geogName
# ADEN geogName
# ET aucun
# CÔTE geogName
# AFRICAINE geogName
# DE aucun
# LA aucun
# MER geogName
# D' geogName
# ARABIE geogName
# ( aucun
# RÉPUBLIQUE geogName
# DE geogName
# DJIBOUTI geogName
# , aucun
# SOMALIE geogName
# ) aucun
# 31 aucun
# 37 aucun
# À aucun
# 1,8 aucun
# M aucun
# au aucun
# SW aucun
# du aucun
# port geogName
# du geogName
# Héron geogName
# , aucun
# le aucun
# site geogName
# de geogName
# Doraleh geogName
# accueille aucun
# le aucun
# terminal geogName
# pétrolier geogName
# et aucun
# le aucun
# terminal geogName
# à geogName
# conteneurs geogName
# . aucun
# 8.3.2.8.C. aucun
# — aucun
# Jetée geogName
# du geogName
# Gouvernement geogName
# - aucun
# 2001 aucun
# . aucun
# 43 aucun
# 8.3.2.8.D. aucun
# — aucun
# Terminal geogName
# pétrolier geogName
# de geogName
# Doraleh geogName
# - aucun
# 2015 aucun
# ( aucun
# Origine geogName
# Frégate geogName
# Guépratte geogName
# ) aucun
# . aucun
# 278 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 13 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 278 aucun
# / aucun
# 0 aucun
# ENTRE aucun
# DJIBOUTI geogName
# ET aucun
# BERBERA geogName
# 49 aucun
# 8.3.2.8.E. aucun
# — aucun
# Terminal geogName
# à geogName
# conteneurs geogName
# de geogName
# Doraleh geogName
# - aucun
# 2015 aucun
# ( aucun
# Origine geogName
# Frégate geogName
# Guépratte geogName
# ) aucun
# . aucun
# 01 aucun
# 5.4.6 aucun
# . aucun
# Port geogName
# du geogName
# Collet geogName
# 07 aucun
# 5.4.6 aucun
# . aucun
# — aucun
# Port geogName
# du geogName
# Collet geogName
# ( aucun
# 2018 aucun
# ) aucun
# . aucun
# 01 aucun
# 5.4.5 aucun
# . aucun
# La geogName
# Bernerie-en-Retz geogName
# 07 aucun
# 5.4.5 aucun
# . aucun
# — aucun
# La geogName
# Bernerie-en-Retz geogName
# ( aucun
# 2018 aucun
# ) aucun
# . aucun
# 01 aucun
# 2.1.4.7 aucun
# . aucun
# Zone geogName
# de geogName
# câbles geogName
# 07 aucun
# Arrêté aucun
# 1987 aucun
# - aucun
# 089 aucun
# du aucun
# 29 aucun
# décembre aucun
# 1987 aucun
# du aucun
# préfet aucun
# maritime aucun
# de aucun
# la aucun
# Troisième geogName
# Région geogName
# ( aucun
# www.premar-mediterranee.gouv.fr/arretes.html aucun
# ) aucun
# . aucun
# 90 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 05 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 90 aucun
# / aucun
# 0 aucun
# GÉNÉRALITÉS aucun
# 13 aucun
# – aucun
# Situation aucun
# : aucun
# zone aucun
# large aucun
# d’ aucun
# environ aucun
# 3 aucun
# M aucun
# , aucun
# portée aucun
# sur aucun
# les aucun
# cartes aucun
# , aucun
# entre aucun
# Canet geogName
# - geogName
# Plage geogName
# et aucun
# le aucun
# cap geogName
# Cerbère geogName
# . aucun
# 19 aucun
# – aucun
# Réglementation aucun
# : aucun
# mouillage aucun
# , aucun
# dragage aucun
# et aucun
# chalutage aucun
# interdits aucun
# . aucun
# Mouillage aucun
# autorisé aucun
# pour aucun
# les aucun
# navires aucun
# de aucun
# pêche aucun
# ou aucun
# de aucun
# plaisance aucun
# , aucun
# d’ aucun
# une aucun
# jauge aucun
# brute aucun
# inférieure aucun
# ou aucun
# égale aucun
# à aucun
# 10 aucun
# , aucun
# aux aucun
# risques aucun
# du aucun
# propriétaire aucun
# . aucun
# 01 aucun
# 3.3.3.4 aucun
# . aucun
# Données aucun
# portuaires aucun
# 07 aucun
# Caractéristiques aucun
# nautiques aucun
# Balisage geogName
# Chenal geogName
# d’ geogName
# accès geogName
# balisé aucun
# par aucun
# 4 aucun
# paires aucun
# de aucun
# bouées geogName
# latérales geogName
# . aucun
# Sémaphore geogName
# Pertusato geogName
# ( aucun
# 41 aucun
# ° aucun
# 22,44 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 10,69 aucun
# ' aucun
# E aucun
# ) aucun
# Stations geogName
# de geogName
# sauvetage geogName
# Propriano geogName
# ( aucun
# 41 aucun
# ° aucun
# 40,56 aucun
# ' aucun
# N aucun
# — aucun
# 8 aucun
# ° aucun
# 54,09 aucun
# ' aucun
# E aucun
# ) aucun
# Bonifacio geogName
# ( aucun
# 41 aucun
# ° aucun
# 23,31 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 09,73 aucun
# ' aucun
# E aucun
# ) aucun
# Porto geogName
# - geogName
# Vecchio geogName
# ( aucun
# 41 aucun
# ° aucun
# 35,46 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 17,16 aucun
# ' aucun
# E aucun
# ) aucun
# Navires aucun
# admis aucun
# Navires aucun
# jusqu’ aucun
# à aucun
# 35 aucun
# m aucun
# de aucun
# longueur aucun
# . aucun
# Infrastructures geogName
# 200 aucun
# places aucun
# par aucun
# 3 aucun
# m aucun
# d’ aucun
# eau aucun
# dans aucun
# 2 aucun
# bassins geogName
# . aucun
# Installations geogName
# portuaires geogName
# 186 aucun
# ÎLES geogName
# LAVEZZI geogName
# Amarrage geogName
# perpendiculairement aucun
# aux aucun
# ouvrages aucun
# . aucun
# Bassin geogName
# Nord geogName
# . aucun
# Limité aucun
# au aucun
# Sud aucun
# par aucun
# un aucun
# 2ème aucun
# appontement geogName
# ( aucun
# G aucun
# ) aucun
# parallèle aucun
# au aucun
# 1er aucun
# ; aucun
# à aucun
# l’ aucun
# Est aucun
# et aucun
# au aucun
# Nord aucun
# par aucun
# les aucun
# rives geogName
# des aucun
# quais geogName
# ( aucun
# H aucun
# ) aucun
# ; aucun
# à aucun
# l’ aucun
# Ouest aucun
# par aucun
# une aucun
# petite aucun
# jetée geogName
# ( aucun
# I aucun
# ) aucun
# . aucun
# Bateaux aucun
# de aucun
# 6 aucun
# m aucun
# à aucun
# 10 aucun
# m aucun
# par aucun
# 2,5 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Bassin geogName
# Sud geogName
# . aucun
# Limité aucun
# au aucun
# Sud aucun
# et aucun
# à aucun
# l’ aucun
# Est aucun
# par aucun
# la aucun
# jetée geogName
# et aucun
# au aucun
# Nord aucun
# par aucun
# un aucun
# appontement geogName
# central geogName
# ( aucun
# F aucun
# ) aucun
# . aucun
# 2 aucun
# pontons geogName
# ( aucun
# A aucun
# et aucun
# B aucun
# ) aucun
# établis aucun
# le aucun
# long aucun
# de aucun
# la aucun
# jetée geogName
# et geogName
# 3 geogName
# pontons geogName
# ( aucun
# C aucun
# , aucun
# D aucun
# et aucun
# E aucun
# ) aucun
# perpendiculairement aucun
# à aucun
# l’ aucun
# appontement geogName
# central aucun
# en aucun
# direction aucun
# du aucun
# Sud aucun
# . aucun
# Amarrage aucun
# des aucun
# bateaux aucun
# les aucun
# plus aucun
# importants aucun
# jusqu’ aucun
# à aucun
# 18 aucun
# m aucun
# sur aucun
# la aucun
# face geogName
# Ouest geogName
# du aucun
# ponton geogName
# C geogName
# et aucun
# la aucun
# face geogName
# extérieure geogName
# du aucun
# ponton geogName
# E. geogName
# Unités geogName
# de aucun
# 10 aucun
# m aucun
# à aucun
# 12 aucun
# m aucun
# amarrés aucun
# aux aucun
# autres aucun
# pontons geogName
# de aucun
# ce aucun
# bassin geogName
# . aucun
# Coffres aucun
# d’ aucun
# amarrage aucun
# pour aucun
# grosses aucun
# unités aucun
# mouillés aucun
# du aucun
# Nord aucun
# au aucun
# Sud aucun
# dans aucun
# l’ aucun
# Ouest aucun
# du aucun
# bassin geogName
# Sud geogName
# . aucun
# Outillage aucun
# Pas aucun
# de aucun
# moyen aucun
# de aucun
# levage aucun
# . aucun
# Ravitaillement aucun
# Shipchandler aucun
# ( aucun
# 08 aucun
# h aucun
# 30 aucun
# à aucun
# 13 aucun
# h aucun
# 00 aucun
# et aucun
# 14 aucun
# h aucun
# 30 aucun
# à aucun
# 19 aucun
# h aucun
# 30 aucun
# ) aucun
# ; aucun
# petit aucun
# supermarché aucun
# sur aucun
# l’ aucun
# île geogName
# . aucun
# Eau aucun
# et aucun
# électricité aucun
# aux aucun
# pontons geogName
# . aucun
# Sanitaires geogName
# et aucun
# douches aucun
# à aucun
# la aucun
# capitainerie geogName
# . aucun
# Météo aucun
# à aucun
# la aucun
# capitainerie geogName
# . aucun
# Pas geogName
# de geogName
# carburant geogName
# . aucun
# Administration aucun
# Île geogName
# de geogName
# Cavallo geogName
# située aucun
# sur aucun
# la aucun
# commune geogName
# de geogName
# Bonifacio geogName
# . aucun
# Gestion aucun
# par aucun
# société aucun
# privée aucun
# Web aucun
# : aucun
# www.portodicavallo.it aucun
# Organisation aucun
# Capitainerie aucun
# Tél aucun
# : aucun
# 04 aucun
# 95 aucun
# 25 aucun
# 80 aucun
# 11 aucun
# Portable geogName
# : aucun
# 06 aucun
# 72 aucun
# 36 aucun
# 33 aucun
# 70 aucun
# VHF aucun
# : aucun
# Canal geogName
# 9 aucun
# pour aucun
# instructions aucun
# Mél aucun
# : aucun
# info@portodicavallo.it aucun
# Ouverture aucun
# : aucun
# entre aucun
# 08 aucun
# h aucun
# 00 aucun
# et aucun
# 20 aucun
# h aucun
# 00 aucun
# Accueil aucun
# des aucun
# navires aucun
# Aide aucun
# à aucun
# l’ aucun
# amarrage aucun
# par aucun
# pneumatiques aucun
# du aucun
# port geogName
# . aucun
# Port geogName
# fermé aucun
# par aucun
# la aucun
# direction aucun
# en aucun
# cas aucun
# de aucun
# mauvais aucun
# temps aucun
# . aucun
# Services aucun
# Douanes aucun
# , aucun
# police aucun
# et aucun
# secours aucun
# à aucun
# la aucun
# capitainerie geogName
# . aucun
# Communications aucun
# Taxi aucun
# , aucun
# avion-taxi aucun
# et aucun
# bateau-taxi aucun
# ; aucun
# 1 aucun
# navette aucun
# maritime aucun
# 4 aucun
# fois aucun
# par aucun
# jour aucun
# entre aucun
# Cavallo geogName
# et aucun
# le aucun
# débarcadère geogName
# de geogName
# Piantarella geogName
# . aucun
# Location aucun
# de aucun
# vélos aucun
# tous aucun
# terrains aucun
# , aucun
# de aucun
# voiturettes aucun
# électriques aucun
# et aucun
# de aucun
# bateaux aucun
# ( aucun
# s’ aucun
# adresser aucun
# à aucun
# la aucun
# capitainerie geogName
# ) geogName
# . aucun
# 3.3.3.4 aucun
# . aucun
# — aucun
# Port geogName
# de geogName
# Cavallo geogName
# ( aucun
# 41 aucun
# ° aucun
# 21,67 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 15,83 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 187 aucun
# DU aucun
# CAP geogName
# DE geogName
# FENO geogName
# AU aucun
# GOLFE geogName
# DE geogName
# SANT’ geogName
# AMANZA geogName
# . aucun
# BOUCHES geogName
# DE geogName
# BONIFACIO geogName
# 01 aucun
# 9.2.3.7 aucun
# . aucun
# Réglementation aucun
# 07 aucun
# Voir aucun
# les aucun
# sous-paragraphes aucun
# 9.1.5.4 aucun
# . aucun
# et aucun
# 9.1.5.7 aucun
# . aucun
# 13 aucun
# La aucun
# zone geogName
# large aucun
# de aucun
# 100 aucun
# m aucun
# qui aucun
# borde aucun
# le aucun
# terre geogName
# - geogName
# plein geogName
# Nord-Est geogName
# et aucun
# la aucun
# jetée geogName
# Nord geogName
# est aucun
# interdite aucun
# à aucun
# la aucun
# navigation aucun
# . aucun
# 411 aucun
# DU aucun
# CAP geogName
# VERT geogName
# JUSQU’ aucun
# AU aucun
# CAP geogName
# VERGA geogName
# 01 aucun
# 4.6.1.1 aucun
# . aucun
# Présentation aucun
# 07 aucun
# La aucun
# chaîne aucun
# de aucun
# montagnes aucun
# qui aucun
# longe aucun
# la aucun
# côte geogName
# à aucun
# partir aucun
# de aucun
# Mostaganem geogName
# s’ aucun
# étend aucun
# jusqu’ aucun
# à aucun
# Ras geogName
# Ténès geogName
# à aucun
# environ aucun
# 60 aucun
# M aucun
# à aucun
# l’ aucun
# ENE aucun
# de aucun
# Ras geogName
# Ouillis geogName
# . aucun
# Plusieurs aucun
# sommets aucun
# dépassent aucun
# 800 aucun
# m aucun
# d’ aucun
# altitude aucun
# . aucun
# 13 aucun
# Les aucun
# mouillages geogName
# sont aucun
# rares aucun
# le aucun
# long aucun
# de aucun
# cette aucun
# partie aucun
# de aucun
# la aucun
# côte geogName
# . aucun
# Ils aucun
# ne aucun
# sont aucun
# en aucun
# général aucun
# fréquentés aucun
# que aucun
# par aucun
# les aucun
# petits aucun
# navires aucun
# ou aucun
# les aucun
# bateaux aucun
# de aucun
# pêche aucun
# connaissant aucun
# les aucun
# lieux aucun
# . aucun
# 19 aucun
# À aucun
# environ aucun
# 2 aucun
# M aucun
# au aucun
# SW aucun
# de aucun
# Ras geogName
# Ténès geogName
# , aucun
# le aucun
# port geogName
# de geogName
# Ténès geogName
# ( aucun
# § aucun
# 4.6.4 aucun
# . aucun
# ) aucun
# est aucun
# un aucun
# port geogName
# de geogName
# commerce geogName
# d’ aucun
# importance aucun
# secon aucun
# daire aucun
# et aucun
# un aucun
# port geogName
# de geogName
# pêche geogName
# . aucun
# 01 aucun
# 2.2.1.3 aucun
# . aucun
# Dangers geogName
# au aucun
# large aucun
# 07 aucun
# La aucun
# présence aucun
# de aucun
# bancs geogName
# du aucun
# large aucun
# , aucun
# qui aucun
# sont aucun
# présentés aucun
# dans aucun
# les aucun
# chapitres aucun
# descriptifs aucun
# correspondants aucun
# , aucun
# accroît aucun
# les aucun
# difficultés aucun
# de aucun
# navigation aucun
# dans aucun
# cette aucun
# zone geogName
# . aucun
# 01 aucun
# 2.3.3.3 aucun
# . aucun
# Mouillage aucun
# 07 aucun
# L’ aucun
# anse geogName
# de geogName
# Miquelon geogName
# est aucun
# très aucun
# saine aucun
# . aucun
# Il aucun
# est aucun
# possible aucun
# d’ aucun
# y aucun
# mouiller aucun
# par aucun
# 7 aucun
# à aucun
# 11 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Le aucun
# fond aucun
# est aucun
# de aucun
# bonne aucun
# tenue aucun
# , aucun
# sauf aucun
# par aucun
# fort aucun
# vent aucun
# d’ aucun
# Est aucun
# et aucun
# de aucun
# NE aucun
# où aucun
# il aucun
# faut aucun
# se aucun
# tenir aucun
# prêt aucun
# à aucun
# appareiller aucun
# à aucun
# tout aucun
# instant aucun
# . aucun
# 13 aucun
# On aucun
# évitera aucun
# de aucun
# mouiller aucun
# à aucun
# proximité aucun
# des aucun
# deux aucun
# câbles aucun
# sous-marins aucun
# de aucun
# fibre aucun
# optique aucun
# qui aucun
# traversent aucun
# l’ aucun
# anse geogName
# de geogName
# Mi geogName
# quelon geogName
# et aucun
# qui aucun
# atterrissent aucun
# au aucun
# Sud aucun
# de aucun
# l’ aucun
# appontement geogName
# pétrolier geogName
# . aucun
# 19 aucun
# Par aucun
# forts aucun
# vents aucun
# de aucun
# secteur aucun
# NNW aucun
# à aucun
# Est aucun
# , aucun
# le aucun
# seul aucun
# mouillage geogName
# conseillé aucun
# est aucun
# situé aucun
# au aucun
# SW aucun
# de aucun
# Langlade geogName
# , aucun
# dans aucun
# l’ aucun
# anse geogName
# du geogName
# Sud-Ouest geogName
# ( aucun
# voir aucun
# § aucun
# 2.3.5 aucun
# . aucun
# ) aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 21 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 103 aucun
# / aucun
# 0 aucun
# 103 aucun
# SAINT-PIERRE-ET-MIQUELON geogName

# %%
os.makedirs('../submissions', exist_ok=True)
submission = predictions[['Id', 'Label']]
submission.to_csv('../submissions/submission_knn_1.csv', index=False)

# %%
submission
# Out:
#           Id     Label
# 0          0     aucun
# 1          1     aucun
# 2          2     aucun
# 3          3     aucun
# 4          4     aucun
# ...      ...       ...
# 26168  26168     aucun
# 26169  26169     aucun
# 26170  26170     aucun
# 26171  26171     aucun
# 26172  26172  geogName
#
# [26173 rows x 2 columns]

# %% [markdown]
# # CRF + XGBoost Pipeline

# %%
xgb_pipeline = Model(extractor=crf, classifier=xgboost, embeddings=we, class_labels = class_labels)

# %%
predictions = xgb_pipeline.predict(df_test)
# Out:
# /var/folders/g9/npfr2mks4118dkv7g8ckgccr0000gn/T/ipykernel_6227/2184327442.py:99: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   vector = self.embeddings.word_vec(word)
# /var/folders/g9/npfr2mks4118dkv7g8ckgccr0000gn/T/ipykernel_6227/2184327442.py:102: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   vector = self.embeddings.word_vec(word.lower())

# %%
for tok, label in zip(predictions['Token'], predictions['Label']):
    print(tok, label)
# Out:
# 01 aucun
# 2.1.4.8 aucun
# . aucun
# Conduites aucun
# sous-marines aucun
# 07 aucun
# Arrêtés aucun
# 1974 aucun
# - aucun
# 961 aucun
# ADM aucun
# / aucun
# SA aucun
# du aucun
# 6 aucun
# décembre aucun
# 1974 aucun
# et aucun
# 1998 aucun
# - aucun
# 002 aucun
# du aucun
# 15 aucun
# janvier aucun
# 1998 aucun
# du aucun
# préfet aucun
# maritime aucun
# de aucun
# la aucun
# Méditerranée geogFeat geogName
# ( aucun
# www.premar-mediterranee.gouv.fr/arretes.html aucun
# ) aucun
# , aucun
# courrier aucun
# des aucun
# Phares geogFeat geogName
# et geogFeat geogName
# Balises geogFeat geogName
# du aucun
# 9 aucun
# septembre aucun
# 1968 aucun
# . aucun
# 2107 aucun
# 08 aucun
# Émissaires aucun
# de aucun
# rejet aucun
# protégés aucun
# par aucun
# des aucun
# zones geogFeat geogName
# réglementées geogFeat geogName
# . aucun
# 13 aucun
# Situation aucun
# : aucun
# zones geogFeat geogName
# portées geogFeat geogName
# sur aucun
# les aucun
# cartes aucun
# , aucun
# devant aucun
# les aucun
# ports geogFeat geogName
# de aucun
# : aucun
# – aucun
# Cerbère geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 26,52 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 10,26 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Banyuls-sur-Mer geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 29,00 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 08,53 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Port-Vendres geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 31,41 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 07,22 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Collioure geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 31,79 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 05,21 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Argelès-sur-Mer geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 32,80 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 03,45 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Grau geogFeat geogName
# - geogFeat geogName
# d’ geogFeat geogName
# Agde geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 15,92 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 27,45 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 19 aucun
# Réglementation aucun
# : aucun
# mouillage aucun
# et aucun
# dragage aucun
# interdits aucun
# . aucun
# 01 aucun
# 3.7.1 aucun
# . aucun
# Entre aucun
# le aucun
# port geogFeat geogName
# de geogFeat geogName
# Lomé geogFeat geogName
# et aucun
# le aucun
# port geogFeat geogName
# de geogFeat geogName
# Kpémé geogFeat geogName
# 07 aucun
# Le aucun
# phare geogFeat geogName
# de geogFeat geogName
# Baguida geogFeat geogName
# , aucun
# à aucun
# 2 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# de aucun
# la aucun
# contre-jetée aucun
# du aucun
# Port geogFeat geogName
# de geogFeat geogName
# Lomé geogFeat geogName
# , aucun
# est aucun
# un aucun
# pylône geogFeat geogName
# peint geogFeat geogName
# en aucun
# aluminium aucun
# , aucun
# haut aucun
# de aucun
# 34 aucun
# m aucun
# , aucun
# à aucun
# voyant aucun
# trapézoïdal aucun
# noir aucun
# . aucun
# 13 aucun
# Entre aucun
# le aucun
# Port geogFeat geogName
# de geogFeat geogName
# Lomé geogFeat geogName
# et aucun
# le aucun
# village geogFeat geogName
# de geogFeat geogName
# Kpémé geogFeat geogName
# à aucun
# 15 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# la aucun
# côte geogFeat geogName
# est aucun
# formée aucun
# d’ aucun
# une aucun
# plage geogFeat geogName
# de aucun
# sable aucun
# rectiligne aucun
# , aucun
# bordée aucun
# de aucun
# cocotiers aucun
# . aucun
# 19 aucun
# Au aucun
# Nord aucun
# de aucun
# Porto geogFeat geogName
# - geogFeat geogName
# Segouro geogFeat geogName
# ( aucun
# Porto geogFeat geogName
# - geogFeat geogName
# Seguro geogFeat geogName
# ) aucun
# [ aucun
# 6 aucun
# ° aucun
# 12 aucun
# ' aucun
# N aucun
# — aucun
# 1 aucun
# ° aucun
# 29 aucun
# ' aucun
# E aucun
# ] aucun
# , aucun
# ( aucun
# vue aucun
# 3.7.1 aucun
# . aucun
# ) aucun
# , aucun
# s’ aucun
# étend aucun
# le aucun
# Lac geogFeat geogName
# Togo geogFeat geogName
# , aucun
# vaste aucun
# étendue aucun
# d’ aucun
# eau aucun
# qui aucun
# se aucun
# prolonge aucun
# jusqu’ aucun
# au aucun
# village geogFeat geogName
# de geogFeat geogName
# Grand-Popo geogFeat geogName
# , aucun
# à aucun
# 20 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# par aucun
# une aucun
# lagune geogFeat geogName
# étroite aucun
# en aucun
# forme aucun
# de aucun
# canal aucun
# . aucun
# 25 aucun
# Le aucun
# village geogFeat geogName
# de geogFeat geogName
# Kpémé geogFeat geogName
# est aucun
# situé aucun
# à aucun
# 2 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# de aucun
# Porto geogFeat geogName
# - geogFeat geogName
# Segouro geogFeat geogName
# . aucun
# 31 aucun
# 3.7.1 aucun
# . aucun
# — aucun
# Vue aucun
# générale aucun
# de aucun
# Porto geogFeat geogName
# - geogFeat geogName
# Ségouro geogFeat geogName
# . aucun
# 01 aucun
# 6.2.1.7 aucun
# . aucun
# Règlementation aucun
# 07 aucun
# VOIE geogFeat geogName
# D’ geogFeat geogName
# ACCÈS geogFeat geogName
# OBLIGATOIRE geogFeat geogName
# . aucun
# — aucun
# Une aucun
# voie geogFeat geogName
# d’ geogFeat geogName
# accès geogFeat geogName
# est aucun
# obligatoire aucun
# pour aucun
# les aucun
# navires aucun
# dont aucun
# la aucun
# jauge aucun
# brute aucun
# est aucun
# supérieure aucun
# à aucun
# 3 aucun
# 000 aucun
# , aucun
# transportant aucun
# des aucun
# hydrocarbures aucun
# ou aucun
# des aucun
# substances aucun
# dangereuses aucun
# ( aucun
# arrêté aucun
# 2006/069 aucun
# du aucun
# 30 aucun
# août aucun
# 2006 aucun
# [ aucun
# modifié aucun
# ] aucun
# du aucun
# préfet aucun
# maritime aucun
# de aucun
# l’ aucun
# Atlantique geogFeat geogName
# ) aucun
# . aucun
# 13 aucun
# Le aucun
# chenal geogFeat geogName
# d’ geogFeat geogName
# approche geogFeat geogName
# est aucun
# limité aucun
# : aucun
# – aucun
# au aucun
# Nord aucun
# et aucun
# au aucun
# Sud aucun
# , aucun
# par aucun
# des aucun
# lignes aucun
# orientées aucun
# à aucun
# 328,4 aucun
# ° aucun
# et aucun
# 270 aucun
# ° aucun
# à aucun
# partir aucun
# du aucun
# feu geogFeat geogName
# de aucun
# la aucun
# digue geogFeat geogName
# Nord geogFeat geogName
# ; aucun
# – aucun
# à aucun
# l’ aucun
# Ouest aucun
# , aucun
# le aucun
# chenal geogFeat geogName
# débute geogFeat geogName
# à aucun
# 7 aucun
# M aucun
# du aucun
# feu geogFeat geogName
# de aucun
# la aucun
# digue geogFeat geogName
# Nord geogFeat geogName
# , aucun
# et aucun
# se aucun
# prolonge aucun
# , aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# jusqu’ aucun
# à aucun
# 1 aucun
# M aucun
# de aucun
# ce aucun
# même aucun
# feu geogFeat geogName
# . aucun
# 19 aucun
# La aucun
# zone geogFeat geogName
# d’ geogFeat geogName
# attente geogFeat geogName
# est aucun
# limitée aucun
# : aucun
# – aucun
# au aucun
# Nord aucun
# par aucun
# la aucun
# ligne geogFeat geogName
# orientée aucun
# à aucun
# 300 aucun
# ° aucun
# à aucun
# partir aucun
# du aucun
# château geogFeat geogName
# d’ geogFeat geogName
# eau geogFeat geogName
# d’ geogFeat geogName
# Ondres geogFeat geogName
# ; aucun
# – aucun
# au aucun
# Sud aucun
# par aucun
# la aucun
# ligne geogFeat geogName
# orientée aucun
# à aucun
# 328,4 aucun
# ° aucun
# à aucun
# partir aucun
# du aucun
# feu geogFeat geogName
# de aucun
# la aucun
# digue geogFeat geogName
# Nord geogFeat geogName
# ; aucun
# – aucun
# à aucun
# l’ aucun
# Est aucun
# et aucun
# à aucun
# l’ aucun
# Ouest aucun
# par aucun
# les aucun
# distances aucun
# de aucun
# 2 aucun
# M aucun
# et aucun
# 4 aucun
# M aucun
# à aucun
# partir aucun
# du aucun
# trait aucun
# de aucun
# côte geogFeat geogName
# . aucun
# 25 aucun
# À aucun
# partir aucun
# de aucun
# l’ aucun
# extrémité aucun
# Est aucun
# du aucun
# chenal geogFeat geogName
# d’ geogFeat geogName
# approche geogFeat geogName
# , aucun
# les aucun
# navires aucun
# se aucun
# conforment aucun
# aux aucun
# instructions aucun
# du aucun
# pilote aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 281 aucun
# / aucun
# 0 aucun
# 281 aucun
# DE aucun
# L’ aucun
# ADOUR geogFeat geogName
# À aucun
# LA aucun
# FRONTIÈRE geogFeat geogName
# ESPAGNOLE geogFeat geogName
# 31 aucun
# CARACTÉRISTIQUES aucun
# DU aucun
# NAVIRE geogFeat geogName
# DE geogFeat geogName
# RÉFÉRENCE geogFeat geogName
# . aucun
# — aucun
# Les aucun
# caractéristiques aucun
# du aucun
# navire aucun
# de aucun
# référence aucun
# autorisé aucun
# à aucun
# accéder aucun
# au aucun
# port geogFeat geogName
# sont aucun
# les aucun
# suivantes aucun
# : aucun
# longueur aucun
# 160 aucun
# m aucun
# , aucun
# largeur aucun
# 25 aucun
# m aucun
# , aucun
# tirant aucun
# d’ aucun
# eau aucun
# à aucun
# l’ aucun
# entrée aucun
# 8,70 aucun
# m aucun
# , aucun
# tirant aucun
# d’ aucun
# eau aucun
# à aucun
# la aucun
# sortie aucun
# 9,60 aucun
# m. aucun
# 37 aucun
# L’ aucun
# accès geogFeat geogName
# d’ aucun
# un aucun
# navire aucun
# présentant aucun
# une aucun
# caractéristique aucun
# supérieure aucun
# à aucun
# celles aucun
# du aucun
# navire aucun
# de aucun
# référence aucun
# peut aucun
# être aucun
# autorisé aucun
# par aucun
# la aucun
# capitainerie geogFeat geogName
# , geogFeat geogName
# après aucun
# avis aucun
# du aucun
# pilotage aucun
# . aucun
# Dans aucun
# ce aucun
# cas aucun
# , aucun
# il aucun
# est aucun
# conseillé aucun
# aux aucun
# représentants aucun
# du aucun
# navire aucun
# de aucun
# déposer aucun
# à aucun
# la aucun
# capitainerie geogFeat geogName
# , aucun
# au aucun
# minimum aucun
# une aucun
# semaine aucun
# avant aucun
# le aucun
# mouvement aucun
# prévu aucun
# , aucun
# la aucun
# demande aucun
# d’ aucun
# escale aucun
# qui aucun
# doit aucun
# comporter aucun
# les aucun
# caractéristiques aucun
# détaillées aucun
# du aucun
# navire aucun
# . aucun
# 43 aucun
# Des aucun
# restrictions aucun
# peuvent aucun
# être aucun
# apportées aucun
# par aucun
# la aucun
# capitainerie geogFeat geogName
# , aucun
# pour aucun
# des aucun
# raisons aucun
# de aucun
# sécurité aucun
# , aucun
# de aucun
# profondeur aucun
# du aucun
# chenal geogFeat geogName
# ou aucun
# de aucun
# conditions aucun
# nautiques aucun
# et aucun
# météorologiques aucun
# . aucun
# 49 aucun
# De aucun
# nuit aucun
# , aucun
# seuls aucun
# sont aucun
# autorisés aucun
# à aucun
# faire aucun
# mouvement aucun
# les aucun
# navires aucun
# dont aucun
# les aucun
# dimensions aucun
# n’ aucun
# excèdent aucun
# pas aucun
# 130 aucun
# m aucun
# de aucun
# long aucun
# et aucun
# 7,00 aucun
# m aucun
# de aucun
# tirant aucun
# d’ aucun
# eau aucun
# . aucun
# 55 aucun
# L’ aucun
# entrée geogFeat geogName
# de aucun
# l’ aucun
# Adour geogFeat geogName
# peut aucun
# être aucun
# impraticable aucun
# par aucun
# gros aucun
# temps aucun
# en aucun
# mer aucun
# , aucun
# ou aucun
# forte aucun
# crue aucun
# en aucun
# rivière geogFeat geogName
# , aucun
# particulièrement aucun
# en aucun
# jusant aucun
# . aucun
# Les aucun
# navires aucun
# reçoivent aucun
# alors aucun
# des aucun
# instructions aucun
# de aucun
# la aucun
# capitainerie geogFeat geogName
# sur geogFeat geogName
# VHF geogFeat geogName
# , aucun
# canal aucun
# 12 aucun
# , aucun
# soit aucun
# pour aucun
# quitter aucun
# leur aucun
# mouillage aucun
# , aucun
# soit aucun
# pour aucun
# rester aucun
# en aucun
# attente aucun
# au aucun
# large aucun
# . aucun
# 61 aucun
# PROFONDEURS aucun
# , aucun
# TIRANTS geogFeat geogName
# D’ geogFeat geogName
# EAU geogFeat geogName
# ET geogFeat geogName
# TIRANTS geogFeat geogName
# D’ geogFeat geogName
# AIR geogFeat geogName
# ADMISSIBLES geogFeat geogName
# . aucun
# — aucun
# Les aucun
# profondeurs aucun
# à aucun
# l’ aucun
# embouchure geogFeat geogName
# sont aucun
# variables aucun
# suivant aucun
# les aucun
# saisons aucun
# ; aucun
# elles aucun
# sont aucun
# entretenues aucun
# par aucun
# dragage aucun
# . aucun
# Elles aucun
# ne aucun
# sont aucun
# pratiquement aucun
# pas aucun
# inférieures aucun
# à aucun
# 9,5 aucun
# m aucun
# en aucun
# été aucun
# , aucun
# mais aucun
# peuvent aucun
# être aucun
# réduites aucun
# en aucun
# hiver aucun
# à aucun
# la aucun
# suite aucun
# des aucun
# tempêtes aucun
# d’ aucun
# Ouest aucun
# à aucun
# SW aucun
# . aucun
# 67 aucun
# Le aucun
# tirant aucun
# d’ aucun
# eau aucun
# admissible aucun
# est aucun
# fonction aucun
# du aucun
# coefficient aucun
# de aucun
# la aucun
# marée aucun
# , aucun
# de aucun
# l’ aucun
# état aucun
# de aucun
# la aucun
# mer aucun
# , aucun
# des aucun
# vents aucun
# , aucun
# de aucun
# l’ aucun
# état aucun
# d’ aucun
# ensablement aucun
# à aucun
# l’ aucun
# embouchure geogFeat geogName
# de aucun
# l’ aucun
# Adour geogFeat geogName
# , aucun
# ainsi aucun
# que aucun
# de aucun
# la aucun
# hauteur aucun
# d’ aucun
# eau aucun
# au aucun
# poste geogFeat geogName
# d’ geogFeat geogName
# amarrage geogFeat geogName
# souhaité aucun
# . aucun
# Par aucun
# conditions aucun
# idéales aucun
# , aucun
# le aucun
# tirant aucun
# d’ aucun
# eau aucun
# maximal aucun
# admissible aucun
# est aucun
# : aucun
# de aucun
# jour aucun
# 8,70 aucun
# m aucun
# à aucun
# l’ aucun
# entrée geogFeat geogName
# et aucun
# 9,60 aucun
# m aucun
# à aucun
# la aucun
# sortie aucun
# ; aucun
# de aucun
# nuit aucun
# 7 aucun
# m. aucun
# 73 aucun
# Le aucun
# pont geogFeat geogName
# Henri geogFeat geogName
# Grenet geogFeat geogName
# , aucun
# situé aucun
# à aucun
# 3,1 aucun
# M aucun
# de aucun
# l’ aucun
# embouchure geogFeat geogName
# de aucun
# l’ aucun
# Adour geogFeat geogName
# , aucun
# autorise aucun
# un aucun
# tirant aucun
# d’ aucun
# air aucun
# de aucun
# 9,5 aucun
# m aucun
# par aucun
# rapport aucun
# au aucun
# zéro aucun
# des aucun
# cartes aucun
# . aucun
# 01 aucun
# 5.4.10.3 aucun
# . aucun
# Accès aucun
# 07 aucun
# À aucun
# l’ aucun
# angle aucun
# des aucun
# vestiges geogFeat geogName
# d’ aucun
# une aucun
# ancienne geogFeat geogName
# digue geogFeat geogName
# , aucun
# une aucun
# balise geogFeat geogName
# latérale geogFeat geogName
# bâbord geogFeat geogName
# , aucun
# avec aucun
# panneaux aucun
# réfléchissants aucun
# , aucun
# signale aucun
# l’ aucun
# entrée geogFeat geogName
# du aucun
# port geogFeat geogName
# . aucun
# 01 aucun
# 2.4.5 aucun
# . aucun
# Chenalage aucun
# 07 aucun
# Les aucun
# voies geogFeat geogName
# recommandées aucun
# permettant aucun
# l’ aucun
# accès geogFeat geogName
# à aucun
# Nouméa geogFeat geogName
# sont aucun
# portées aucun
# sur aucun
# les aucun
# cartes aucun
# ( aucun
# § aucun
# 2.1.1.3 aucun
# . aucun
# ) aucun
# . aucun
# Leurs aucun
# limites aucun
# sont aucun
# précisées aucun
# en aucun
# annexe aucun
# ( aucun
# § aucun
# 7.4 aucun
# . aucun
# ) aucun
# . aucun
# 13 aucun
# Corne aucun
# SE aucun
# : aucun
# – aucun
# du aucun
# canal aucun
# de aucun
# la aucun
# Havannah geogFeat geogName
# ( aucun
# § aucun
# 2.2.1.1 aucun
# . aucun
# ) aucun
# à aucun
# Nouméa geogFeat geogName
# ( aucun
# § aucun
# 2.4 aucun
# . aucun
# ) aucun
# par aucun
# le aucun
# canal geogFeat geogName
# Woodin geogFeat geogName
# ( aucun
# § aucun
# 2.2.3 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# menant aucun
# à aucun
# la aucun
# passe geogFeat geogName
# de geogFeat geogName
# la geogFeat geogName
# Sarcelle geogFeat geogName
# ( aucun
# § aucun
# 2.2.1.6 aucun
# . aucun
# ) aucun
# et aucun
# à aucun
# l’ aucun
# île geogFeat geogName
# des geogFeat geogName
# Pins geogFeat geogName
# ( aucun
# § aucun
# 2.2.2 aucun
# . aucun
# ) aucun
# . aucun
# 19 aucun
# Côte geogFeat geogName
# SW geogFeat geogName
# : aucun
# – aucun
# de aucun
# la aucun
# passe geogFeat geogName
# de geogFeat geogName
# Uatio geogFeat geogName
# jusqu’ aucun
# au aucun
# mouillage aucun
# de aucun
# l’ aucun
# îlot geogFeat geogName
# Kouaré geogFeat geogName
# ( aucun
# § aucun
# 2.2.5 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# de aucun
# la aucun
# passe geogFeat geogName
# Nord aucun
# des aucun
# passes geogFeat geogName
# de geogFeat geogName
# Boulari geogFeat geogName
# ( aucun
# § aucun
# 2.3.1 aucun
# . aucun
# ) aucun
# à aucun
# la aucun
# Petite geogFeat geogName
# rade geogFeat geogName
# ( aucun
# § aucun
# 2.4.6.1 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# reliant aucun
# les aucun
# passes geogFeat geogName
# de geogFeat geogName
# Boulari geogFeat geogName
# au aucun
# canal geogFeat geogName
# Woodin geogFeat geogName
# ( aucun
# § aucun
# 2.2.3 aucun
# . aucun
# ) aucun
# ou aucun
# au aucun
# canal aucun
# de aucun
# la aucun
# Havannah geogFeat geogName
# ( aucun
# § aucun
# 2.2.1.1 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# de aucun
# la aucun
# passe geogFeat geogName
# de geogFeat geogName
# Dumbéa geogFeat geogName
# ( aucun
# § aucun
# 2.3.2.1 aucun
# . aucun
# ) aucun
# et aucun
# celles aucun
# menant aucun
# de aucun
# cette aucun
# passe geogFeat geogName
# à geogFeat geogName
# Nouméa geogFeat geogName
# ; aucun
# – aucun
# de aucun
# la aucun
# passe geogFeat geogName
# de geogFeat geogName
# Uitoé geogFeat geogName
# ( aucun
# § aucun
# 2.5.2.1 aucun
# . aucun
# ) aucun
# à aucun
# Nouméa geogFeat geogName
# . aucun
# 25 aucun
# Les aucun
# points aucun
# d’ aucun
# embarquement aucun
# des aucun
# pilotes aucun
# sont aucun
# précisés aucun
# au aucun
# § aucun
# 2.4.4 aucun
# . aucun
# 01 aucun
# 4.5.5.4 aucun
# . aucun
# Données aucun
# portuaires aucun
# 07 aucun
# Caractéristiques aucun
# nautiques aucun
# Météorologie aucun
# locale aucun
# Vents aucun
# tourbillonnants aucun
# dans aucun
# la aucun
# baie geogFeat geogName
# par aucun
# temps aucun
# de aucun
# mistral aucun
# . aucun
# Navires aucun
# admis aucun
# PORT geogFeat geogName
# PUBLIC geogFeat geogName
# : aucun
# unités aucun
# de aucun
# plaisance aucun
# de aucun
# 4 aucun
# à aucun
# 30 aucun
# m. aucun
# Installations geogFeat geogName
# portuaires geogFeat geogName
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 21 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 205 aucun
# / aucun
# 0 aucun
# 205 aucun
# DE aucun
# LA aucun
# PRESQU’ geogFeat geogName
# ÎLE geogFeat geogName
# DE geogFeat geogName
# GIENS geogFeat geogName
# AU aucun
# CAP geogFeat geogName
# CAMARAT geogFeat geogName
# – aucun
# ÎLES geogFeat geogName
# D’ geogFeat geogName
# HYÈRES geogFeat geogName
# PORT geogFeat geogName
# PRIVÉ geogFeat geogName
# : aucun
# unités aucun
# de aucun
# plaisance aucun
# de aucun
# 7 aucun
# à aucun
# 16 aucun
# m. aucun
# Infrastructures geogFeat geogName
# 1 aucun
# port geogFeat geogName
# à aucun
# gestion aucun
# privée aucun
# ou aucun
# nouveau aucun
# port geogFeat geogName
# dans aucun
# la aucun
# partie aucun
# Est aucun
# et aucun
# 1 aucun
# port geogFeat geogName
# public geogFeat geogName
# à aucun
# l’ aucun
# Ouest aucun
# . aucun
# 1 aucun
# 251 aucun
# places geogFeat geogName
# dont aucun
# 100 aucun
# pour aucun
# bateaux aucun
# de aucun
# passage aucun
# sur aucun
# l’ aucun
# ensemble aucun
# des aucun
# deux aucun
# ports geogFeat geogName
# . aucun
# PORT geogFeat geogName
# PUBLIC geogFeat geogName
# : aucun
# 621 aucun
# places geogFeat geogName
# . aucun
# PORT geogFeat geogName
# PRIVÉ geogFeat geogName
# : aucun
# 545 aucun
# places geogFeat geogName
# . aucun
# Zone geogFeat geogName
# de geogFeat geogName
# mouillage geogFeat geogName
# organisé geogFeat geogName
# ( aucun
# en aucun
# saison aucun
# ) aucun
# : aucun
# 85 aucun
# places geogFeat geogName
# supplémentaires geogFeat geogName
# pour aucun
# bateaux aucun
# de aucun
# 7 aucun
# à aucun
# 16 aucun
# m. aucun
# Outillage aucun
# 1 aucun
# cale geogFeat geogName
# de geogFeat geogName
# halage geogFeat geogName
# + aucun
# 1 aucun
# élévateur aucun
# à aucun
# bateaux aucun
# de aucun
# 35 aucun
# t. aucun
# Ravitaillement aucun
# Eau aucun
# aux aucun
# appontements geogFeat geogName
# . aucun
# Poste geogFeat geogName
# de geogFeat geogName
# carburants geogFeat geogName
# à aucun
# l’ aucun
# épi geogFeat geogName
# entre aucun
# les aucun
# deux aucun
# ports geogFeat geogName
# ( aucun
# longueur aucun
# 20 aucun
# m aucun
# par aucun
# 1,8 aucun
# à aucun
# 3 aucun
# m aucun
# d’ aucun
# eau aucun
# ) aucun
# . aucun
# Administration aucun
# Organisation aucun
# PORT geogFeat geogName
# PUBLIC geogFeat geogName
# : aucun
# gestion aucun
# concédée aucun
# à aucun
# la aucun
# commune geogFeat geogName
# de geogFeat geogName
# Cavalaire-sur-Mer geogFeat geogName
# . aucun
# Bureau geogFeat geogName
# du geogFeat geogName
# port geogFeat geogName
# public geogFeat geogName
# : aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.17.81 aucun
# ; aucun
# télécopie aucun
# : aucun
# 04.64.64.67.06 aucun
# ; aucun
# mél aucun
# : aucun
# port@cavalaire.fr aucun
# . aucun
# Veille aucun
# VHF aucun
# en aucun
# saison aucun
# . aucun
# Site aucun
# web aucun
# : aucun
# www.cavalaire.fr aucun
# . aucun
# PORT geogFeat geogName
# PRIVÉ geogFeat geogName
# : aucun
# gestion aucun
# par aucun
# société aucun
# anonyme aucun
# ( aucun
# SACNPPC geogFeat geogName
# ) aucun
# . aucun
# Bureau geogFeat geogName
# du geogFeat geogName
# port geogFeat geogName
# privé geogFeat geogName
# : aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.16.01 aucun
# ; aucun
# télécopie aucun
# : aucun
# 04.94.64.36.06 aucun
# ; aucun
# mél aucun
# : aucun
# info@port- aucun
# cavalaire.com aucun
# . aucun
# Veille aucun
# VHF aucun
# en aucun
# saison aucun
# . aucun
# Site aucun
# web aucun
# : aucun
# www.port-cavalaire.com aucun
# . aucun
# Accueil aucun
# des aucun
# navires aucun
# Au aucun
# quai geogFeat geogName
# d’ geogFeat geogName
# attente geogFeat geogName
# , aucun
# devant aucun
# le aucun
# bureau geogFeat geogName
# du geogFeat geogName
# port geogFeat geogName
# public geogFeat geogName
# . aucun
# Services aucun
# Affaires aucun
# maritimes aucun
# : aucun
# à aucun
# Toulon geogFeat geogName
# . aucun
# Douanes aucun
# : aucun
# à aucun
# Toulon geogFeat geogName
# . aucun
# Poste geogFeat geogName
# de geogFeat geogName
# secours geogFeat geogName
# du geogFeat geogName
# Parc geogFeat geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.11.54 aucun
# ( aucun
# du aucun
# 1er aucun
# juin aucun
# au aucun
# 30 aucun
# septembre aucun
# ) aucun
# . aucun
# Poste geogFeat geogName
# de geogFeat geogName
# secours geogFeat geogName
# de geogFeat geogName
# Pardigon geogFeat geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.43.49 aucun
# ( aucun
# du aucun
# 15 aucun
# juin aucun
# au aucun
# 15 aucun
# septembre aucun
# ) aucun
# . aucun
# Gendarmerie geogFeat geogName
# : aucun
# Rue geogFeat geogName
# A. geogFeat geogName
# Daudet geogFeat geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.04.17 aucun
# . aucun
# Communications aucun
# Lignes aucun
# d’ aucun
# autocars aucun
# . aucun
# Gare geogFeat geogName
# SNCF geogFeat geogName
# à aucun
# Hyères geogFeat geogName
# et aucun
# Toulon geogFeat geogName
# . aucun
# Aéroport geogFeat geogName
# de geogFeat geogName
# Hyères geogFeat geogName
# - geogFeat geogName
# Le geogFeat geogName
# Palyvestre geogFeat geogName
# . aucun
# Ville geogFeat geogName
# Mairie geogFeat geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.04.26 aucun
# . aucun
# 4.5.5.4 aucun
# . aucun
# — aucun
# Port geogFeat geogName
# de geogFeat geogName
# Cavalaire geogFeat geogName
# ( aucun
# 43 aucun
# ° aucun
# 10,3 aucun
# ' aucun
# N aucun
# — aucun
# 6 aucun
# ° aucun
# 32,2 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 206 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 21 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 206 aucun
# / aucun
# 0 aucun
# DU aucun
# CAP geogFeat geogName
# BÉNAT geogFeat geogName
# AU aucun
# CAP geogFeat geogName
# CAMARAT geogFeat geogName
# . aucun
# 01 aucun
# 5.4.8.1 aucun
# . aucun
# Généralités aucun
# 07 aucun
# L’ aucun
# étier geogFeat geogName
# de geogFeat geogName
# Port geogFeat geogName
# des geogFeat geogName
# Champs geogFeat geogName
# est aucun
# situé aucun
# à aucun
# 1,5 aucun
# M aucun
# au aucun
# Sud aucun
# de aucun
# l’ aucun
# étier geogFeat geogName
# de geogFeat geogName
# la geogFeat geogName
# Louippe geogFeat geogName
# et aucun
# débouche aucun
# lui aucun
# aussi aucun
# dans aucun
# une aucun
# ouverture aucun
# de aucun
# la aucun
# digue geogFeat geogName
# du geogFeat geogName
# littoral geogFeat geogName
# . aucun
# 01 aucun
# 9.2 aucun
# . aucun
# Du aucun
# cap geogFeat geogName
# Vert geogFeat geogName
# à aucun
# la aucun
# pointe geogFeat geogName
# Rouge geogFeat geogName
# . aucun
# Baie geogFeat geogName
# de geogFeat geogName
# Gorée geogFeat geogName
# 07 aucun
# La aucun
# presqu’ geogFeat geogName
# île geogFeat geogName
# du aucun
# cap geogFeat geogName
# Vert geogFeat geogName
# comprend aucun
# deux aucun
# pointes geogFeat geogName
# saillantes aucun
# orientées aucun
# , aucun
# l’ aucun
# une aucun
# vers aucun
# l’ aucun
# Ouest aucun
# et aucun
# l’ aucun
# autre aucun
# vers aucun
# le aucun
# Sud aucun
# . aucun
# 13 aucun
# Le aucun
# cap geogFeat geogName
# Vert geogFeat geogName
# , aucun
# terminé aucun
# par aucun
# la aucun
# pointe geogFeat geogName
# des geogFeat geogName
# Almadies geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 44,47′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 31,95 aucun
# ' aucun
# W aucun
# ) aucun
# est aucun
# le aucun
# point aucun
# le aucun
# plus aucun
# occidental aucun
# de aucun
# la aucun
# côte geogFeat geogName
# Ouest geogFeat geogName
# du aucun
# continent geogFeat geogName
# africain geogFeat geogName
# . aucun
# Le aucun
# cap geogFeat geogName
# Manuel geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 38,77′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 25,98′ aucun
# W aucun
# ) aucun
# , aucun
# orienté aucun
# au aucun
# Sud aucun
# , aucun
# délimite aucun
# la aucun
# partie aucun
# Ouest aucun
# de aucun
# la aucun
# baie geogFeat geogName
# de geogFeat geogName
# Gorée geogFeat geogName
# . aucun
# 19 aucun
# La aucun
# baie geogFeat geogName
# de geogFeat geogName
# Gorée geogFeat geogName
# s’ aucun
# ouvre aucun
# entre aucun
# le aucun
# Cap geogFeat geogName
# Manuel geogFeat geogName
# et aucun
# la aucun
# pointe geogFeat geogName
# Rouge geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 38,11′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 10,42′ aucun
# W aucun
# ) aucun
# distante aucun
# de aucun
# 15 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# . aucun
# Bien aucun
# qu’ aucun
# ouverte aucun
# aux aucun
# vents aucun
# de aucun
# Sud aucun
# , aucun
# cette aucun
# vaste aucun
# baie geogFeat geogName
# est aucun
# réputée aucun
# être aucun
# sûre aucun
# . aucun
# L’ aucun
# île geogFeat geogName
# de geogFeat geogName
# Gorée geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 39,98′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 23,89′ aucun
# W aucun
# ) aucun
# se aucun
# trouve aucun
# dans aucun
# l’ aucun
# entrée geogFeat geogName
# de aucun
# la aucun
# baie geogFeat geogName
# . aucun
# 25 aucun
# Le aucun
# port geogFeat geogName
# de geogFeat geogName
# Dakar geogFeat geogName
# , aucun
# décrit aucun
# dans aucun
# le aucun
# paragraphe aucun
# 9.2.3 aucun
# . aucun
# , aucun
# est aucun
# établi aucun
# dans aucun
# l’ aucun
# anse geogFeat geogName
# qui aucun
# s’ aucun
# étend aucun
# entre aucun
# la aucun
# pointe geogFeat geogName
# de geogFeat geogName
# Dakar geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 40,19′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 25,30′ aucun
# W aucun
# ) aucun
# , aucun
# au aucun
# Sud aucun
# et aucun
# la aucun
# pointe geogFeat geogName
# de geogFeat geogName
# Bel geogFeat geogName
# - geogFeat geogName
# Air geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 42,08′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 25,03′ aucun
# W aucun
# ) aucun
# , aucun
# au aucun
# Nord aucun
# . aucun
# 31 aucun
# Outre aucun
# la aucun
# ville geogFeat geogName
# de geogFeat geogName
# Dakar geogFeat geogName
# qui aucun
# occupe aucun
# la aucun
# majeure aucun
# partie aucun
# de aucun
# la aucun
# presqu’ geogFeat geogName
# île geogFeat geogName
# du aucun
# cap geogFeat geogName
# Vert geogFeat geogName
# , aucun
# la aucun
# côte geogFeat geogName
# Nord geogFeat geogName
# de aucun
# la aucun
# baie geogFeat geogName
# de geogFeat geogName
# Gorée geogFeat geogName
# est aucun
# urbanisée aucun
# de aucun
# façon aucun
# presque aucun
# continue aucun
# depuis aucun
# la aucun
# pointe geogFeat geogName
# de geogFeat geogName
# Bel geogFeat geogName
# - geogFeat geogName
# Air geogFeat geogName
# jusqu’ aucun
# à aucun
# Rufisque geogFeat geogName
# . aucun
# 01 aucun
# 4.3.4.4 aucun
# . aucun
# Maupihaa aucun
# ( aucun
# Mopelia geogFeat geogName
# ) aucun
# 07 aucun
# À aucun
# 100 aucun
# M aucun
# à aucun
# l’ aucun
# WSW aucun
# de aucun
# Maupiti geogFeat geogName
# , aucun
# Maupihaa geogFeat geogName
# ( aucun
# Mopelia geogFeat geogName
# ) aucun
# [ aucun
# 16 aucun
# ° aucun
# 48 aucun
# ' aucun
# S aucun
# — aucun
# 153 aucun
# ° aucun
# 58 aucun
# ' aucun
# W aucun
# ] aucun
# est aucun
# un aucun
# atoll geogFeat geogName
# de aucun
# 4,5 aucun
# M aucun
# de aucun
# diamètre aucun
# , aucun
# avec aucun
# une aucun
# longue aucun
# île geogFeat geogName
# étroite geogFeat geogName
# , geogFeat geogName
# Motu geogFeat geogName
# Maupihaa geogFeat geogName
# , aucun
# couverte aucun
# de aucun
# cocotiers aucun
# , aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# un aucun
# motu aucun
# isolé aucun
# au aucun
# NW aucun
# et aucun
# un aucun
# récif- aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 221 aucun
# / aucun
# 0 aucun
# 221 aucun
# ÎLES geogFeat geogName
# DU aucun
# VENT aucun
# – aucun
# ÎLES geogFeat geogName
# SOUS-LE-VENT geogFeat geogName
# – aucun
# ÎLES geogFeat geogName
# AUSTRALES geogFeat geogName
# barrière aucun
# juste aucun
# affleurant aucun
# au aucun
# SW aucun
# . aucun
# Sa aucun
# population aucun
# est aucun
# réduite aucun
# à aucun
# 3 aucun
# habitants aucun
# sédentaires aucun
# ( aucun
# 2012 aucun
# ) aucun
# , aucun
# vivant aucun
# de aucun
# la aucun
# pêche aucun
# et aucun
# de aucun
# la aucun
# récolte aucun
# du aucun
# coprah aucun
# . aucun
# Les aucun
# exploitations aucun
# de aucun
# fermes aucun
# perlières aucun
# et aucun
# de aucun
# nacres aucun
# sont aucun
# abandonnées aucun
# . aucun
# 13 aucun
# L’ aucun
# unique aucun
# passe geogFeat geogName
# Taihaaru geogFeat geogName
# Vahine geogFeat geogName
# , aucun
# au aucun
# NW aucun
# de aucun
# l’ aucun
# atoll geogFeat geogName
# , aucun
# est aucun
# étroite aucun
# ( aucun
# 35 aucun
# m aucun
# ) aucun
# mais aucun
# profonde aucun
# ( aucun
# 12 aucun
# m aucun
# ) aucun
# . aucun
# Son aucun
# balisage geogFeat geogName
# , aucun
# détruit aucun
# par aucun
# les aucun
# intempéries geogFeat geogName
# n’ aucun
# a aucun
# pas aucun
# été aucun
# restauré aucun
# ( aucun
# 2014 aucun
# ) aucun
# . aucun
# À aucun
# l’ aucun
# entrée geogFeat geogName
# du aucun
# lagon geogFeat geogName
# , aucun
# la aucun
# passe geogFeat geogName
# se aucun
# divise aucun
# en aucun
# deux aucun
# chenaux geogFeat geogName
# ; aucun
# celui aucun
# du aucun
# NE aucun
# , aucun
# non aucun
# balisé aucun
# , aucun
# n’ aucun
# est aucun
# praticable aucun
# que aucun
# par aucun
# de aucun
# petites aucun
# embarcations aucun
# ; aucun
# celui aucun
# du aucun
# SW aucun
# franchit aucun
# un aucun
# seuil aucun
# couvert aucun
# de aucun
# 3,7 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Il aucun
# doit aucun
# être aucun
# emprunté aucun
# avec aucun
# précaution aucun
# , aucun
# par aucun
# temps aucun
# clair aucun
# quand aucun
# les aucun
# têtes geogFeat geogName
# de geogFeat geogName
# corail geogFeat geogName
# sont aucun
# bien aucun
# visibles aucun
# , aucun
# de aucun
# préférence aucun
# en aucun
# début aucun
# de aucun
# matinée aucun
# quand aucun
# le aucun
# courant aucun
# est aucun
# le aucun
# plus aucun
# faible aucun
# . aucun
# Le aucun
# courant aucun
# , aucun
# toujours aucun
# sortant aucun
# , aucun
# peut aucun
# atteindre aucun
# 9 aucun
# nœuds aucun
# par aucun
# forte aucun
# houle aucun
# de aucun
# SW aucun
# ( aucun
# ensachage aucun
# ) aucun
# et aucun
# provoque aucun
# des aucun
# tourbillons aucun
# près aucun
# du aucun
# plateau geogFeat geogName
# de aucun
# corail aucun
# central aucun
# . aucun
# 19 aucun
# Le aucun
# lagon geogFeat geogName
# est aucun
# très aucun
# vaste aucun
# et aucun
# profond aucun
# avec aucun
# de aucun
# nombreux aucun
# bancs geogFeat geogName
# de geogFeat geogName
# corail geogFeat geogName
# bien aucun
# visibles aucun
# . aucun
# 25 aucun
# MOUILLAGE aucun
# . aucun
# — aucun
# Faire geogFeat geogName
# route geogFeat geogName
# à aucun
# 065 aucun
# ° aucun
# , aucun
# en aucun
# relevant aucun
# par aucun
# l’ aucun
# arrière aucun
# à aucun
# 245 aucun
# ° aucun
# l’ aucun
# extrémité aucun
# Sud aucun
# de aucun
# l’ aucun
# îlot geogFeat geogName
# à aucun
# l’ aucun
# WSW aucun
# du aucun
# Motu geogFeat geogName
# Manu geogFeat geogName
# ; aucun
# mouiller aucun
# par aucun
# profondeur aucun
# de aucun
# 16 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# sable aucun
# avec aucun
# de aucun
# nombreuses aucun
# patates aucun
# de aucun
# corail aucun
# , aucun
# en aucun
# relevant aucun
# à aucun
# 312 aucun
# ° aucun
# la aucun
# pointe geogFeat geogName
# SW geogFeat geogName
# de aucun
# la aucun
# partie aucun
# Nord aucun
# du aucun
# Motu geogFeat geogName
# Maupihaa geogFeat geogName
# , aucun
# et aucun
# à aucun
# 0,3 aucun
# M aucun
# de aucun
# la aucun
# côte geogFeat geogName
# . aucun
# Ne aucun
# pas aucun
# s’ aucun
# approcher aucun
# à aucun
# moins aucun
# de aucun
# 0,3 aucun
# M aucun
# de aucun
# la aucun
# côte geogFeat geogName
# car aucun
# les aucun
# profondeurs aucun
# y aucun
# sont aucun
# moindres aucun
# que aucun
# celles aucun
# figurant aucun
# sur aucun
# la aucun
# carte aucun
# . aucun
# 31 aucun
# DÉBARQUEMENT aucun
# . aucun
# — aucun
# Les aucun
# embarcations aucun
# accostent aucun
# sur aucun
# la aucun
# plage geogFeat geogName
# devant aucun
# les aucun
# rares geogFeat geogName
# constructions geogFeat geogName
# entretenues geogFeat geogName
# . aucun
# 01 aucun
# 2.3 aucun
# . aucun
# Île geogFeat geogName
# Miquelon geogFeat geogName
# 01 aucun
# 4.3.4.6 aucun
# . aucun
# Manuae geogFeat geogName
# ( aucun
# Scilly geogFeat geogName
# ) aucun
# [ aucun
# Fanua geogFeat geogName
# Ura geogFeat geogName
# ] aucun
# 07 aucun
# Manuae geogFeat geogName
# ( aucun
# Scilly geogFeat geogName
# ) aucun
# [ aucun
# Fanua geogFeat geogName
# Ura geogFeat geogName
# ] aucun
# ( aucun
# 16 aucun
# ° aucun
# 30 aucun
# ' aucun
# S aucun
# — aucun
# 154 aucun
# ° aucun
# 40 aucun
# ' aucun
# W aucun
# ) aucun
# , aucun
# atoll geogFeat geogName
# de aucun
# 6 aucun
# M aucun
# de aucun
# diamètre aucun
# , aucun
# est aucun
# le aucun
# plus aucun
# Ouest aucun
# des aucun
# Îles geogFeat geogName
# Sous-le-Vent geogFeat geogName
# . aucun
# Le aucun
# lagon geogFeat geogName
# n’ aucun
# est aucun
# accessible aucun
# qu’ aucun
# aux aucun
# embarcations aucun
# par aucun
# une aucun
# échancrure aucun
# dans aucun
# le aucun
# récif geogFeat geogName
# à aucun
# 0,4 aucun
# M aucun
# à aucun
# l’ aucun
# WSW aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Nord geogFeat geogName
# . aucun
# Une aucun
# autre aucun
# anfractuosité aucun
# dans aucun
# la aucun
# barrière geogFeat geogName
# permet aucun
# le aucun
# débarquement aucun
# par aucun
# baleinière aucun
# sur aucun
# la aucun
# côte geogFeat geogName
# Est geogFeat geogName
# près aucun
# du aucun
# village geogFeat geogName
# ; aucun
# l’ aucun
# embarcation aucun
# doit aucun
# être aucun
# hissée aucun
# sur aucun
# le aucun
# platier aucun
# . aucun
# Ce aucun
# débarquement aucun
# de aucun
# même aucun
# que aucun
# le aucun
# franchissement aucun
# de aucun
# la aucun
# passe geogFeat geogName
# ne aucun
# peuvent aucun
# être aucun
# envisagés aucun
# que aucun
# par aucun
# temps aucun
# calme aucun
# . aucun
# 13 aucun
# Des aucun
# îlots geogFeat geogName
# boisés geogFeat geogName
# se aucun
# voient aucun
# dans aucun
# la aucun
# partie aucun
# Est aucun
# du aucun
# récif geogFeat geogName
# dont aucun
# les aucun
# côtes geogFeat geogName
# Ouest geogFeat geogName
# et aucun
# Sud aucun
# sont aucun
# à aucun
# fleur aucun
# d’ aucun
# eau aucun
# . aucun
# L’ aucun
# atoll geogFeat geogName
# présente aucun
# à aucun
# l’ aucun
# Ouest aucun
# un aucun
# banc geogFeat geogName
# de aucun
# sable aucun
# de aucun
# plus aucun
# de aucun
# 10 aucun
# km aucun
# , aucun
# parfois aucun
# confondu aucun
# avec aucun
# la aucun
# limite aucun
# du aucun
# récif geogFeat geogName
# . aucun
# 25 aucun
# Cet aucun
# atoll geogFeat geogName
# est aucun
# inclus aucun
# dans aucun
# la aucun
# réserve geogFeat geogName
# territoriale geogFeat geogName
# de geogFeat geogName
# Scilly geogFeat geogName
# et aucun
# Bellingshausen aucun
# ; aucun
# il aucun
# est aucun
# soumis aucun
# à aucun
# la aucun
# même aucun
# réglemen aucun
# tation aucun
# que aucun
# l’ aucun
# atoll geogFeat geogName
# Motu geogFeat geogName
# One geogFeat geogName
# ( aucun
# § aucun
# 4.3.4.5 aucun
# . aucun
# ) aucun
# . aucun
# La aucun
# population aucun
# , aucun
# très aucun
# isolée aucun
# , aucun
# est aucun
# limitée aucun
# à aucun
# moins aucun
# de aucun
# 10 aucun
# personnes aucun
# . aucun
# 31 aucun
# Note aucun
# : aucun
# Il aucun
# existe aucun
# également aucun
# une aucun
# île geogFeat geogName
# du geogFeat geogName
# nom geogFeat geogName
# de geogFeat geogName
# Manuae geogFeat geogName
# dans aucun
# les aucun
# Southern geogFeat geogName
# Cook geogFeat geogName
# Islands geogFeat geogName
# . aucun
# 222 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 222 aucun
# / aucun
# 0 aucun
# ÎLES geogFeat geogName
# AUSTRALES geogFeat geogName
# 01 aucun
# 4.3.3.3 aucun
# . aucun
# Côte geogFeat geogName
# de geogFeat geogName
# Tahaa geogFeat geogName
# 05 aucun
# Sur aucun
# la aucun
# côte geogFeat geogName
# SW geogFeat geogName
# de geogFeat geogName
# Tahaa geogFeat geogName
# , aucun
# la aucun
# passe geogFeat geogName
# Paipai geogFeat geogName
# , aucun
# large aucun
# de aucun
# 200 aucun
# m aucun
# et aucun
# profonde aucun
# , aucun
# est aucun
# bien aucun
# balisée aucun
# . aucun
# Son aucun
# axe geogFeat geogName
# ( aucun
# 009 aucun
# ° aucun
# ) aucun
# est aucun
# marqué aucun
# par aucun
# l’ aucun
# alignement geogFeat geogName
# de aucun
# deux aucun
# colonnes geogFeat geogName
# lumineuses geogFeat geogName
# à aucun
# bandes aucun
# horizontales aucun
# rouges aucun
# et aucun
# blanches aucun
# , aucun
# implantées aucun
# à aucun
# la aucun
# pointe geogFeat geogName
# Tepari geogFeat geogName
# , aucun
# au aucun
# Nord aucun
# de aucun
# la aucun
# passe geogFeat geogName
# . aucun
# 09 aucun
# 4.3.3.3.A. aucun
# — aucun
# Tahaa geogFeat geogName
# – aucun
# Passe geogFeat geogName
# Paipai geogFeat geogName
# – aucun
# Alignement geogFeat geogName
# à aucun
# 009 aucun
# ° aucun
# . aucun
# 13 aucun
# La aucun
# passe geogFeat geogName
# Paipai geogFeat geogName
# débouche aucun
# sur aucun
# la aucun
# baie geogFeat geogName
# Hurepiti geogFeat geogName
# qui aucun
# offre aucun
# un aucun
# excellent aucun
# abri aucun
# par aucun
# tous aucun
# les aucun
# temps aucun
# . aucun
# De aucun
# nombreuses aucun
# bouées geogFeat geogName
# sont aucun
# mouillées aucun
# dans aucun
# sa aucun
# partie aucun
# NW aucun
# . aucun
# Mouillage aucun
# , aucun
# par aucun
# profondeur aucun
# de aucun
# 25 aucun
# à aucun
# 30 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# sable aucun
# d’ aucun
# excellente aucun
# tenue aucun
# , aucun
# en aucun
# relevant aucun
# la aucun
# pointe geogFeat geogName
# Tepari geogFeat geogName
# à aucun
# 280 aucun
# ° aucun
# et aucun
# 0,3 aucun
# M. aucun
# Pour aucun
# se aucun
# rapprocher aucun
# de aucun
# Tiva geogFeat geogName
# , aucun
# mouillage aucun
# par aucun
# profondeur aucun
# de aucun
# 30 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# de aucun
# bonne aucun
# tenue aucun
# , aucun
# en aucun
# relevant aucun
# à aucun
# 320 aucun
# ° aucun
# et aucun
# 0,6 aucun
# M aucun
# le aucun
# clocher geogFeat geogName
# , aucun
# à aucun
# l’ aucun
# Ouest aucun
# de aucun
# la aucun
# baie geogFeat geogName
# . aucun
# Il aucun
# y aucun
# a aucun
# un aucun
# appontement geogFeat geogName
# devant aucun
# l’ aucun
# église geogFeat geogName
# et aucun
# un aucun
# autre aucun
# à aucun
# 0,2 aucun
# M aucun
# au aucun
# NW aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Tepari geogFeat geogName
# . aucun
# 17 aucun
# Le aucun
# chenal geogFeat geogName
# intérieur aucun
# autour aucun
# de aucun
# l’ aucun
# île geogFeat geogName
# est aucun
# marqué aucun
# par aucun
# un aucun
# balisage geogFeat geogName
# , aucun
# en aucun
# partie aucun
# lumineux aucun
# . aucun
# Les aucun
# balises geogFeat geogName
# sont aucun
# pour aucun
# la aucun
# plupart aucun
# implantées aucun
# sur aucun
# le aucun
# récif geogFeat geogName
# côtier geogFeat geogName
# de aucun
# l’ aucun
# île geogFeat geogName
# ; aucun
# il aucun
# ne aucun
# faut aucun
# pas aucun
# les aucun
# serrer aucun
# de aucun
# trop aucun
# près aucun
# , aucun
# car aucun
# elles aucun
# ne aucun
# sont aucun
# pas aucun
# toujours aucun
# au aucun
# bord aucun
# du aucun
# récif geogFeat geogName
# . aucun
# 21 aucun
# À aucun
# 2,7 aucun
# M aucun
# au aucun
# SE aucun
# de aucun
# la aucun
# passe geogFeat geogName
# Paipai geogFeat geogName
# , aucun
# la aucun
# baie geogFeat geogName
# Apu geogFeat geogName
# , aucun
# offre aucun
# d’ aucun
# excellents aucun
# mouillages aucun
# pour aucun
# petits aucun
# navires aucun
# notamment aucun
# à aucun
# 0,3 aucun
# M aucun
# dans aucun
# le aucun
# NNE aucun
# de aucun
# l aucun
# ’ aucun
# île geogFeat geogName
# Toapuhi geogFeat geogName
# par aucun
# 33 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# 25 aucun
# Les aucun
# grands aucun
# navires aucun
# peuvent aucun
# mouiller aucun
# par aucun
# profondeur aucun
# de aucun
# 43 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# sable aucun
# , aucun
# à aucun
# 0,6 aucun
# M aucun
# au aucun
# Sud aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Toamaro geogFeat geogName
# , aucun
# pointe geogFeat geogName
# SE geogFeat geogName
# de aucun
# la aucun
# baie geogFeat geogName
# Apu geogFeat geogName
# . aucun
# 29 aucun
# Un aucun
# appontement geogFeat geogName
# de aucun
# 15 aucun
# m aucun
# de aucun
# long aucun
# et aucun
# 5 aucun
# m aucun
# d’ aucun
# eau aucun
# se aucun
# trouve aucun
# sur aucun
# le aucun
# côté aucun
# Ouest aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Toamaro geogFeat geogName
# ; aucun
# c’ aucun
# est aucun
# tout aucun
# ce aucun
# qui aucun
# reste aucun
# de aucun
# la aucun
# marina geogFeat geogName
# Iti geogFeat geogName
# après aucun
# la aucun
# fermeture aucun
# du aucun
# yacht geogFeat geogName
# club geogFeat geogName
# « geogFeat geogName
# Taravana geogFeat geogName
# » aucun
# en aucun
# 2013 aucun
# . aucun
# 33 aucun
# À aucun
# 1,8 aucun
# M aucun
# plus aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# on aucun
# peut aucun
# mouiller aucun
# devant aucun
# le aucun
# village geogFeat geogName
# de geogFeat geogName
# Vaitoare geogFeat geogName
# , aucun
# par aucun
# profondeur aucun
# de aucun
# 30 aucun
# à aucun
# 40 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# d’ aucun
# excellente aucun
# tenue aucun
# en aucun
# relevant aucun
# à aucun
# 255 aucun
# ° aucun
# la aucun
# pointe geogFeat geogName
# SE geogFeat geogName
# de aucun
# l’ aucun
# îlot geogFeat geogName
# Fatufatu geogFeat geogName
# et aucun
# à aucun
# 341 aucun
# ° aucun
# la aucun
# pointe geogFeat geogName
# Sud geogFeat geogName
# de aucun
# l’ aucun
# appontement geogFeat geogName
# . aucun
# 37 aucun
# Sur aucun
# la aucun
# côte geogFeat geogName
# Est geogFeat geogName
# de aucun
# l’ aucun
# île geogFeat geogName
# , aucun
# la aucun
# passe geogFeat geogName
# Toahotu geogFeat geogName
# , aucun
# bien aucun
# balisée aucun
# , aucun
# large aucun
# de aucun
# 150 aucun
# m aucun
# et aucun
# profonde aucun
# , aucun
# se aucun
# franchit aucun
# sur aucun
# l’ aucun
# alignement geogFeat geogName
# ( aucun
# 293 aucun
# ° aucun
# ) aucun
# d’ aucun
# une aucun
# échancrure geogFeat geogName
# remarquable aucun
# , aucun
# légèrement aucun
# au aucun
# Sud aucun
# du aucun
# mont geogFeat geogName
# Puurauti geogFeat geogName
# , aucun
# par aucun
# une aucun
# balise geogFeat geogName
# , aucun
# peu aucun
# visible aucun
# , aucun
# implantée aucun
# au aucun
# pied aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Pataaia geogFeat geogName
# , aucun
# et aucun
# par aucun
# le aucun
# milieu aucun
# du aucun
# passage geogFeat geogName
# entre aucun
# l’ aucun
# îlot geogFeat geogName
# Mahaea geogFeat geogName
# et aucun
# l’ aucun
# îlot geogFeat geogName
# Toahotu geogFeat geogName
# ; aucun
# dès aucun
# que aucun
# ce aucun
# dernier aucun
# est aucun
# paré aucun
# , aucun
# venir aucun
# rondement aucun
# par aucun
# la aucun
# gauche aucun
# en aucun
# route geogFeat geogName
# à aucun
# 255 aucun
# ° aucun
# pour aucun
# laisser aucun
# au aucun
# Nord aucun
# un aucun
# haut-fond geogFeat geogName
# couvert aucun
# de aucun
# 5,2 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# non aucun
# balisé aucun
# , aucun
# marqué aucun
# par aucun
# une aucun
# décoloration aucun
# de aucun
# l’ aucun
# eau aucun
# , aucun
# parfois aucun
# peu aucun
# visible aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 209 aucun
# / aucun
# 0 aucun
# 209 aucun
# ÎLES geogFeat geogName
# DU aucun
# VENT aucun
# – aucun
# ÎLES geogFeat geogName
# SOUS-LE-VENT geogFeat geogName
# – aucun
# ÎLES geogFeat geogName
# AUSTRALES geogFeat geogName
# 41 aucun
# 4.3.3.3.B. aucun
# — aucun
# Tahaa geogFeat geogName
# – aucun
# Passe geogFeat geogName
# de geogFeat geogName
# Toahotu geogFeat geogName
# – aucun
# Alignement geogFeat geogName
# à aucun
# 293 aucun
# ° aucun
# . aucun
# 45 aucun
# Un aucun
# chenal geogFeat geogName
# secondaire geogFeat geogName
# marqué aucun
# par aucun
# des aucun
# espars geogFeat geogName
# noir aucun
# et aucun
# blanc aucun
# permet aucun
# aux aucun
# petites aucun
# embarcations aucun
# de aucun
# passer aucun
# sur aucun
# le aucun
# récif geogFeat geogName
# - aucun
# barrière aucun
# au aucun
# Sud aucun
# de aucun
# la aucun
# passe geogFeat geogName
# de geogFeat geogName
# Toahotu geogFeat geogName
# , aucun
# dans aucun
# la aucun
# partie aucun
# submergée aucun
# de aucun
# 0,5 aucun
# à aucun
# 1,5 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# et aucun
# d’ aucun
# accéder aucun
# au aucun
# mouillage geogFeat geogName
# d’ geogFeat geogName
# Uturoa geogFeat geogName
# en aucun
# longeant aucun
# le aucun
# côté aucun
# Est aucun
# du aucun
# récif geogFeat geogName
# . aucun
# 49 aucun
# La aucun
# baie geogFeat geogName
# Haamene geogFeat geogName
# constitue aucun
# une aucun
# brèche geogFeat geogName
# profonde aucun
# de aucun
# 2,4 aucun
# M aucun
# à aucun
# l’ aucun
# intérieur aucun
# de aucun
# l’ aucun
# île geogFeat geogName
# à aucun
# partir aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Para geogFeat geogName
# . aucun
# On aucun
# peut aucun
# mouiller aucun
# dans aucun
# la aucun
# partie aucun
# Est aucun
# de aucun
# la aucun
# baie geogFeat geogName
# par aucun
# profondeur aucun
# de aucun
# 30 aucun
# à aucun
# 40 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# . aucun
# Appontement aucun
# au aucun
# NE aucun
# de aucun
# la aucun
# baie geogFeat geogName
# de geogFeat geogName
# 18 aucun
# m aucun
# de aucun
# long aucun
# par aucun
# 2 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# 53 aucun
# À aucun
# 0,5 aucun
# M aucun
# au aucun
# Nord aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Pataaia geogFeat geogName
# , aucun
# la aucun
# baie geogFeat geogName
# Faaha geogFeat geogName
# , aucun
# longue aucun
# de aucun
# 1,1 aucun
# M aucun
# , aucun
# permet aucun
# de aucun
# mouiller aucun
# par aucun
# profondeur aucun
# de aucun
# 32 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# . aucun
# Le aucun
# village geogFeat geogName
# de geogFeat geogName
# Faaha geogFeat geogName
# , aucun
# en aucun
# fond aucun
# de aucun
# baie geogFeat geogName
# , aucun
# dispose aucun
# d’ aucun
# un aucun
# quai geogFeat geogName
# . aucun
# 57 aucun
# Le aucun
# chenal geogFeat geogName
# se aucun
# rétrécit aucun
# ( aucun
# 0,15 aucun
# M aucun
# ) aucun
# à aucun
# la aucun
# pointe geogFeat geogName
# Matahira geogFeat geogName
# , aucun
# pointe geogFeat geogName
# Ouest geogFeat geogName
# de aucun
# l’ aucun
# île geogFeat geogName
# , aucun
# puis aucun
# s’ aucun
# élargit aucun
# au aucun
# NE aucun
# de aucun
# l’ aucun
# île geogFeat geogName
# . aucun
# 61 aucun
# Il aucun
# est aucun
# conseillé aucun
# de aucun
# suivre aucun
# le aucun
# chenal geogFeat geogName
# en aucun
# serrant aucun
# le aucun
# récif geogFeat geogName
# côtier geogFeat geogName
# de geogFeat geogName
# Tahaa geogFeat geogName
# , aucun
# plus aucun
# accore aucun
# et aucun
# plus aucun
# visible aucun
# que aucun
# le aucun
# bord aucun
# intérieur aucun
# du aucun
# récif geogFeat geogName
# - aucun
# barrière aucun
# . aucun
# Le aucun
# seul aucun
# passage aucun
# délicat aucun
# est aucun
# au aucun
# Nord aucun
# de aucun
# la aucun
# baie geogFeat geogName
# Pahure geogFeat geogName
# ( aucun
# 16 aucun
# ° aucun
# 35 aucun
# ' aucun
# S aucun
# — aucun
# 151 aucun
# ° aucun
# 29 aucun
# ' aucun
# W aucun
# ) aucun
# , aucun
# où aucun
# le aucun
# chenal geogFeat geogName
# est aucun
# rétréci aucun
# par aucun
# plusieurs aucun
# dangers geogFeat geogName
# , aucun
# que aucun
# l’ aucun
# on aucun
# peut aucun
# contourner aucun
# par aucun
# le aucun
# Nord aucun
# en aucun
# arrondissant aucun
# à aucun
# plus aucun
# de aucun
# 0,15 aucun
# M aucun
# le aucun
# récif geogFeat geogName
# Moora geogFeat geogName
# , aucun
# balisé aucun
# mais aucun
# débordé aucun
# de aucun
# 0,1 aucun
# M aucun
# par aucun
# un aucun
# haut-fond geogFeat geogName
# recouvert aucun
# de aucun
# 4,1 aucun
# m aucun
# d’ aucun
# eau aucun
# puis aucun
# en aucun
# passant aucun
# au aucun
# Sud aucun
# du aucun
# récif geogFeat geogName
# Faremao geogFeat geogName
# , aucun
# marqué aucun
# par aucun
# une aucun
# balise geogFeat geogName
# latérale geogFeat geogName
# tribord geogFeat geogName
# . aucun
# 65 aucun
# À aucun
# l’ aucun
# embouchure geogFeat geogName
# de aucun
# la aucun
# rivière geogFeat geogName
# Iripau geogFeat geogName
# , aucun
# le aucun
# village geogFeat geogName
# de geogFeat geogName
# Patio geogFeat geogName
# , aucun
# centre aucun
# administratif aucun
# de aucun
# l’ aucun
# île geogFeat geogName
# , aucun
# offre aucun
# une aucun
# darse aucun
# et aucun
# des aucun
# quais geogFeat geogName
# par aucun
# 1,5 aucun
# m aucun
# d’ aucun
# eau aucun
# ; aucun
# il aucun
# possède aucun
# une aucun
# infirmerie aucun
# . aucun
# 69 aucun
# Vers aucun
# l’ aucun
# Ouest aucun
# , aucun
# le aucun
# chenal geogFeat geogName
# mène geogFeat geogName
# sans aucun
# difficulté aucun
# jusqu’ aucun
# à aucun
# la aucun
# baie geogFeat geogName
# Tapuamu geogFeat geogName
# offrant aucun
# dans aucun
# sa aucun
# partie aucun
# Sud aucun
# , aucun
# un aucun
# quai geogFeat geogName
# , aucun
# orienté aucun
# Est-Ouest aucun
# , aucun
# de aucun
# 74 aucun
# m aucun
# de aucun
# long aucun
# par aucun
# 6 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# avec aucun
# un aucun
# slip geogFeat geogName
# de aucun
# 14 aucun
# m aucun
# de aucun
# large aucun
# à aucun
# son aucun
# extrémité aucun
# Ouest aucun
# , aucun
# et aucun
# une aucun
# darse aucun
# pour aucun
# bonitiers aucun
# et aucun
# navires aucun
# de aucun
# plaisance aucun
# par aucun
# 1,7 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Alimentation aucun
# en aucun
# eau aucun
# possible aucun
# . aucun
# Il aucun
# est aucun
# interdit aucun
# de aucun
# mouiller aucun
# à aucun
# l’ aucun
# ouvert geogFeat geogName
# de aucun
# cette aucun
# baie geogFeat geogName
# sur aucun
# une aucun
# bande geogFeat geogName
# de aucun
# 0,3 aucun
# M aucun
# , aucun
# axée aucun
# à aucun
# 302 aucun
# ° aucun
# entre aucun
# le aucun
# quai geogFeat geogName
# et aucun
# l’ aucun
# îlot geogFeat geogName
# Tautau geogFeat geogName
# ( aucun
# canalisation aucun
# eau aucun
# et aucun
# gaz aucun
# ) aucun
# . aucun
# 210 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 210 aucun
# / aucun
# 0 aucun
# ÎLES geogFeat geogName
# SOUS-LE-VENT geogFeat geogName
# 73 aucun
# 4.3.3.3.C. aucun
# — aucun
# Tahaa geogFeat geogName
# – aucun
# Quai geogFeat geogName
# de geogFeat geogName
# la aucun
# baie geogFeat geogName
# de geogFeat geogName
# Tapuamu geogFeat geogName
# . aucun
# 77 aucun
# Le aucun
# village geogFeat geogName
# de geogFeat geogName
# Tiva geogFeat geogName
# , aucun
# à aucun
# 1,5 aucun
# M aucun
# au aucun
# Sud aucun
# de aucun
# Tapuamu geogFeat geogName
# , aucun
# possède aucun
# un aucun
# appontement geogFeat geogName
# de geogFeat geogName
# 9 aucun
# m aucun
# de aucun
# long aucun
# par aucun
# 2,7 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# accessible aucun
# aux aucun
# petits aucun
# caboteurs aucun
# . aucun
# 81 aucun
# L’ aucun
# accès geogFeat geogName
# à aucun
# Uturoa geogFeat geogName
# par aucun
# la aucun
# passe geogFeat geogName
# Toahotu geogFeat geogName
# est aucun
# ...
# à aucun
# 810 aucun
# 000 aucun
# habitants aucun
# ( aucun
# 2014 aucun
# ) aucun
# , aucun
# soit aucun
# plus aucun
# des aucun
# 2/3 aucun
# de aucun
# l’ aucun
# ensemble aucun
# de aucun
# la aucun
# population aucun
# du aucun
# pays geogFeat geogName
# . aucun
# 8.3.2.8.A. aucun
# — aucun
# Djibouti geogFeat geogName
# ( aucun
# 11 aucun
# ° aucun
# 36 aucun
# ' aucun
# N aucun
# — aucun
# 43 aucun
# ° aucun
# 08 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 13 aucun
# À aucun
# l’ aucun
# Ouest aucun
# du aucun
# Plateau geogFeat geogName
# du geogFeat geogName
# Marabout geogFeat geogName
# , aucun
# la aucun
# jetée geogFeat geogName
# du geogFeat geogName
# Marabout geogFeat geogName
# est aucun
# perpendiculaire aucun
# à aucun
# son aucun
# extrémité aucun
# , aucun
# à aucun
# la aucun
# jetée geogFeat geogName
# du geogFeat geogName
# Large geogFeat geogName
# . aucun
# À aucun
# l’ aucun
# extrémité aucun
# SW aucun
# de aucun
# la aucun
# Jetée geogFeat geogName
# du geogFeat geogName
# Large geogFeat geogName
# , aucun
# le aucun
# môle geogFeat geogName
# du geogFeat geogName
# Fontainebleau geogFeat geogName
# a aucun
# été aucun
# construit aucun
# sur aucun
# l’ aucun
# épave geogFeat geogName
# du aucun
# navire aucun
# du aucun
# même aucun
# nom aucun
# . aucun
# 19 aucun
# 25 aucun
# À aucun
# 0,1 aucun
# M aucun
# au aucun
# Sud aucun
# du aucun
# Môle geogFeat geogName
# Sud geogFeat geogName
# , aucun
# se aucun
# situe aucun
# la aucun
# jetée geogFeat geogName
# du geogFeat geogName
# Gouvernement geogFeat geogName
# . aucun
# 8.3.2.8.B. aucun
# — aucun
# Môle geogFeat geogName
# du geogFeat geogName
# Fontainebleau geogFeat geogName
# au aucun
# Nord aucun
# ( aucun
# Origine geogFeat geogName
# Marine aucun
# nationale aucun
# ) aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 13 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 277 aucun
# / aucun
# 0 aucun
# 277 aucun
# CÔTE geogFeat geogName
# SUD geogFeat geogName
# DU aucun
# GOLFE geogFeat geogName
# D' geogFeat geogName
# ADEN geogFeat geogName
# ET aucun
# CÔTE geogFeat geogName
# AFRICAINE geogFeat geogName
# DE aucun
# LA aucun
# MER geogFeat geogName
# D' geogFeat geogName
# ARABIE geogFeat geogName
# ( aucun
# RÉPUBLIQUE geogFeat geogName
# DE geogFeat geogName
# DJIBOUTI geogFeat geogName
# , aucun
# SOMALIE geogFeat geogName
# ) aucun
# 31 aucun
# 37 aucun
# À aucun
# 1,8 aucun
# M aucun
# au aucun
# SW aucun
# du aucun
# port geogFeat geogName
# du geogFeat geogName
# Héron geogFeat geogName
# , aucun
# le aucun
# site geogFeat geogName
# de geogFeat geogName
# Doraleh geogFeat geogName
# accueille aucun
# le aucun
# terminal geogFeat geogName
# pétrolier geogFeat geogName
# et aucun
# le aucun
# terminal geogFeat geogName
# à geogFeat geogName
# conteneurs geogFeat geogName
# . aucun
# 8.3.2.8.C. aucun
# — aucun
# Jetée geogFeat geogName
# du geogFeat geogName
# Gouvernement geogFeat geogName
# - aucun
# 2001 aucun
# . aucun
# 43 aucun
# 8.3.2.8.D. aucun
# — aucun
# Terminal geogFeat geogName
# pétrolier geogFeat geogName
# de geogFeat geogName
# Doraleh geogFeat geogName
# - aucun
# 2015 aucun
# ( aucun
# Origine geogFeat geogName
# Frégate geogFeat geogName
# Guépratte geogFeat geogName
# ) aucun
# . aucun
# 278 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 13 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 278 aucun
# / aucun
# 0 aucun
# ENTRE aucun
# DJIBOUTI geogFeat geogName
# ET aucun
# BERBERA geogFeat geogName
# 49 aucun
# 8.3.2.8.E. aucun
# — aucun
# Terminal geogFeat geogName
# à geogFeat geogName
# conteneurs geogFeat geogName
# de geogFeat geogName
# Doraleh geogFeat geogName
# - aucun
# 2015 aucun
# ( aucun
# Origine geogFeat geogName
# Frégate geogFeat geogName
# Guépratte geogFeat geogName
# ) aucun
# . aucun
# 01 aucun
# 5.4.6 aucun
# . aucun
# Port geogFeat geogName
# du geogFeat geogName
# Collet geogFeat geogName
# 07 aucun
# 5.4.6 aucun
# . aucun
# — aucun
# Port geogFeat geogName
# du geogFeat geogName
# Collet geogFeat geogName
# ( aucun
# 2018 aucun
# ) aucun
# . aucun
# 01 aucun
# 5.4.5 aucun
# . aucun
# La geogFeat geogName
# Bernerie-en-Retz geogFeat geogName
# 07 aucun
# 5.4.5 aucun
# . aucun
# — aucun
# La geogFeat geogName
# Bernerie-en-Retz geogFeat geogName
# ( aucun
# 2018 aucun
# ) aucun
# . aucun
# 01 aucun
# 2.1.4.7 aucun
# . aucun
# Zone geogFeat geogName
# de geogFeat geogName
# câbles geogFeat geogName
# 07 aucun
# Arrêté aucun
# 1987 aucun
# - aucun
# 089 aucun
# du aucun
# 29 aucun
# décembre aucun
# 1987 aucun
# du aucun
# préfet aucun
# maritime aucun
# de aucun
# la aucun
# Troisième geogFeat geogName
# Région geogFeat geogName
# ( aucun
# www.premar-mediterranee.gouv.fr/arretes.html aucun
# ) aucun
# . aucun
# 90 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 05 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 90 aucun
# / aucun
# 0 aucun
# GÉNÉRALITÉS aucun
# 13 aucun
# – aucun
# Situation aucun
# : aucun
# zone aucun
# large aucun
# d’ aucun
# environ aucun
# 3 aucun
# M aucun
# , aucun
# portée aucun
# sur aucun
# les aucun
# cartes aucun
# , aucun
# entre aucun
# Canet geogFeat geogName
# - geogFeat geogName
# Plage geogFeat geogName
# et aucun
# le aucun
# cap geogFeat geogName
# Cerbère geogFeat geogName
# . aucun
# 19 aucun
# – aucun
# Réglementation aucun
# : aucun
# mouillage aucun
# , aucun
# dragage aucun
# et aucun
# chalutage aucun
# interdits aucun
# . aucun
# Mouillage aucun
# autorisé aucun
# pour aucun
# les aucun
# navires aucun
# de aucun
# pêche aucun
# ou aucun
# de aucun
# plaisance aucun
# , aucun
# d’ aucun
# une aucun
# jauge aucun
# brute aucun
# inférieure aucun
# ou aucun
# égale aucun
# à aucun
# 10 aucun
# , aucun
# aux aucun
# risques aucun
# du aucun
# propriétaire aucun
# . aucun
# 01 aucun
# 3.3.3.4 aucun
# . aucun
# Données aucun
# portuaires aucun
# 07 aucun
# Caractéristiques aucun
# nautiques aucun
# Balisage geogFeat geogName
# Chenal geogFeat geogName
# d’ geogFeat geogName
# accès geogFeat geogName
# balisé aucun
# par aucun
# 4 aucun
# paires aucun
# de aucun
# bouées geogFeat geogName
# latérales geogFeat geogName
# . aucun
# Sémaphore geogFeat geogName
# Pertusato geogFeat geogName
# ( aucun
# 41 aucun
# ° aucun
# 22,44 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 10,69 aucun
# ' aucun
# E aucun
# ) aucun
# Stations geogFeat geogName
# de geogFeat geogName
# sauvetage geogFeat geogName
# Propriano geogFeat geogName
# ( aucun
# 41 aucun
# ° aucun
# 40,56 aucun
# ' aucun
# N aucun
# — aucun
# 8 aucun
# ° aucun
# 54,09 aucun
# ' aucun
# E aucun
# ) aucun
# Bonifacio geogFeat geogName
# ( aucun
# 41 aucun
# ° aucun
# 23,31 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 09,73 aucun
# ' aucun
# E aucun
# ) aucun
# Porto geogFeat geogName
# - geogFeat geogName
# Vecchio geogFeat geogName
# ( aucun
# 41 aucun
# ° aucun
# 35,46 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 17,16 aucun
# ' aucun
# E aucun
# ) aucun
# Navires aucun
# admis aucun
# Navires aucun
# jusqu’ aucun
# à aucun
# 35 aucun
# m aucun
# de aucun
# longueur aucun
# . aucun
# Infrastructures geogFeat geogName
# 200 aucun
# places aucun
# par aucun
# 3 aucun
# m aucun
# d’ aucun
# eau aucun
# dans aucun
# 2 aucun
# bassins geogFeat geogName
# . aucun
# Installations geogFeat geogName
# portuaires geogFeat geogName
# 186 aucun
# ÎLES geogFeat geogName
# LAVEZZI geogFeat geogName
# Amarrage geogFeat geogName
# perpendiculairement aucun
# aux aucun
# ouvrages aucun
# . aucun
# Bassin geogFeat geogName
# Nord geogFeat geogName
# . aucun
# Limité aucun
# au aucun
# Sud aucun
# par aucun
# un aucun
# 2ème aucun
# appontement geogFeat geogName
# ( aucun
# G aucun
# ) aucun
# parallèle aucun
# au aucun
# 1er aucun
# ; aucun
# à aucun
# l’ aucun
# Est aucun
# et aucun
# au aucun
# Nord aucun
# par aucun
# les aucun
# rives geogFeat geogName
# des aucun
# quais geogFeat geogName
# ( aucun
# H aucun
# ) aucun
# ; aucun
# à aucun
# l’ aucun
# Ouest aucun
# par aucun
# une aucun
# petite aucun
# jetée geogFeat geogName
# ( aucun
# I aucun
# ) aucun
# . aucun
# Bateaux aucun
# de aucun
# 6 aucun
# m aucun
# à aucun
# 10 aucun
# m aucun
# par aucun
# 2,5 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Bassin geogFeat geogName
# Sud geogFeat geogName
# . aucun
# Limité aucun
# au aucun
# Sud aucun
# et aucun
# à aucun
# l’ aucun
# Est aucun
# par aucun
# la aucun
# jetée geogFeat geogName
# et aucun
# au aucun
# Nord aucun
# par aucun
# un aucun
# appontement geogFeat geogName
# central geogFeat geogName
# ( aucun
# F aucun
# ) aucun
# . aucun
# 2 aucun
# pontons geogFeat geogName
# ( aucun
# A aucun
# et aucun
# B aucun
# ) aucun
# établis aucun
# le aucun
# long aucun
# de aucun
# la aucun
# jetée geogFeat geogName
# et geogFeat geogName
# 3 geogFeat geogName
# pontons geogFeat geogName
# ( aucun
# C aucun
# , aucun
# D aucun
# et aucun
# E aucun
# ) aucun
# perpendiculairement aucun
# à aucun
# l’ aucun
# appontement geogFeat geogName
# central aucun
# en aucun
# direction aucun
# du aucun
# Sud aucun
# . aucun
# Amarrage aucun
# des aucun
# bateaux aucun
# les aucun
# plus aucun
# importants aucun
# jusqu’ aucun
# à aucun
# 18 aucun
# m aucun
# sur aucun
# la aucun
# face geogFeat geogName
# Ouest geogFeat geogName
# du aucun
# ponton geogFeat geogName
# C geogFeat geogName
# et aucun
# la aucun
# face geogFeat geogName
# extérieure geogFeat geogName
# du aucun
# ponton geogFeat geogName
# E. geogFeat geogName
# Unités geogFeat geogName
# de aucun
# 10 aucun
# m aucun
# à aucun
# 12 aucun
# m aucun
# amarrés aucun
# aux aucun
# autres aucun
# pontons geogFeat geogName
# de aucun
# ce aucun
# bassin geogFeat geogName
# . aucun
# Coffres aucun
# d’ aucun
# amarrage aucun
# pour aucun
# grosses aucun
# unités aucun
# mouillés aucun
# du aucun
# Nord aucun
# au aucun
# Sud aucun
# dans aucun
# l’ aucun
# Ouest aucun
# du aucun
# bassin geogFeat geogName
# Sud geogFeat geogName
# . aucun
# Outillage aucun
# Pas aucun
# de aucun
# moyen aucun
# de aucun
# levage aucun
# . aucun
# Ravitaillement aucun
# Shipchandler aucun
# ( aucun
# 08 aucun
# h aucun
# 30 aucun
# à aucun
# 13 aucun
# h aucun
# 00 aucun
# et aucun
# 14 aucun
# h aucun
# 30 aucun
# à aucun
# 19 aucun
# h aucun
# 30 aucun
# ) aucun
# ; aucun
# petit aucun
# supermarché aucun
# sur aucun
# l’ aucun
# île geogFeat geogName
# . aucun
# Eau aucun
# et aucun
# électricité aucun
# aux aucun
# pontons geogFeat geogName
# . aucun
# Sanitaires geogFeat geogName
# et aucun
# douches aucun
# à aucun
# la aucun
# capitainerie geogFeat geogName
# . aucun
# Météo aucun
# à aucun
# la aucun
# capitainerie geogFeat geogName
# . aucun
# Pas geogFeat geogName
# de geogFeat geogName
# carburant geogFeat geogName
# . aucun
# Administration aucun
# Île geogFeat geogName
# de geogFeat geogName
# Cavallo geogFeat geogName
# située aucun
# sur aucun
# la aucun
# commune geogFeat geogName
# de geogFeat geogName
# Bonifacio geogFeat geogName
# . aucun
# Gestion aucun
# par aucun
# société aucun
# privée aucun
# Web aucun
# : aucun
# www.portodicavallo.it aucun
# Organisation aucun
# Capitainerie aucun
# Tél aucun
# : aucun
# 04 aucun
# 95 aucun
# 25 aucun
# 80 aucun
# 11 aucun
# Portable geogFeat geogName
# : aucun
# 06 aucun
# 72 aucun
# 36 aucun
# 33 aucun
# 70 aucun
# VHF aucun
# : aucun
# Canal geogFeat geogName
# 9 aucun
# pour aucun
# instructions aucun
# Mél aucun
# : aucun
# info@portodicavallo.it aucun
# Ouverture aucun
# : aucun
# entre aucun
# 08 aucun
# h aucun
# 00 aucun
# et aucun
# 20 aucun
# h aucun
# 00 aucun
# Accueil aucun
# des aucun
# navires aucun
# Aide aucun
# à aucun
# l’ aucun
# amarrage aucun
# par aucun
# pneumatiques aucun
# du aucun
# port geogFeat geogName
# . aucun
# Port geogFeat geogName
# fermé aucun
# par aucun
# la aucun
# direction aucun
# en aucun
# cas aucun
# de aucun
# mauvais aucun
# temps aucun
# . aucun
# Services aucun
# Douanes aucun
# , aucun
# police aucun
# et aucun
# secours aucun
# à aucun
# la aucun
# capitainerie geogFeat geogName
# . aucun
# Communications aucun
# Taxi aucun
# , aucun
# avion-taxi aucun
# et aucun
# bateau-taxi aucun
# ; aucun
# 1 aucun
# navette aucun
# maritime aucun
# 4 aucun
# fois aucun
# par aucun
# jour aucun
# entre aucun
# Cavallo geogFeat geogName
# et aucun
# le aucun
# débarcadère geogFeat geogName
# de geogFeat geogName
# Piantarella geogFeat geogName
# . aucun
# Location aucun
# de aucun
# vélos aucun
# tous aucun
# terrains aucun
# , aucun
# de aucun
# voiturettes aucun
# électriques aucun
# et aucun
# de aucun
# bateaux aucun
# ( aucun
# s’ aucun
# adresser aucun
# à aucun
# la aucun
# capitainerie geogFeat geogName
# ) geogFeat geogName
# . aucun
# 3.3.3.4 aucun
# . aucun
# — aucun
# Port geogFeat geogName
# de geogFeat geogName
# Cavallo geogFeat geogName
# ( aucun
# 41 aucun
# ° aucun
# 21,67 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 15,83 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 187 aucun
# DU aucun
# CAP geogFeat geogName
# DE geogFeat geogName
# FENO geogFeat geogName
# AU aucun
# GOLFE geogFeat geogName
# DE geogFeat geogName
# SANT’ geogFeat geogName
# AMANZA geogFeat geogName
# . aucun
# BOUCHES geogFeat geogName
# DE geogFeat geogName
# BONIFACIO geogFeat geogName
# 01 aucun
# 9.2.3.7 aucun
# . aucun
# Réglementation aucun
# 07 aucun
# Voir aucun
# les aucun
# sous-paragraphes aucun
# 9.1.5.4 aucun
# . aucun
# et aucun
# 9.1.5.7 aucun
# . aucun
# 13 aucun
# La aucun
# zone geogFeat geogName
# large aucun
# de aucun
# 100 aucun
# m aucun
# qui aucun
# borde aucun
# le aucun
# terre geogFeat geogName
# - geogFeat geogName
# plein geogFeat geogName
# Nord-Est geogFeat geogName
# et aucun
# la aucun
# jetée geogFeat geogName
# Nord geogFeat geogName
# est aucun
# interdite aucun
# à aucun
# la aucun
# navigation aucun
# . aucun
# 411 aucun
# DU aucun
# CAP geogFeat geogName
# VERT geogFeat geogName
# JUSQU’ aucun
# AU aucun
# CAP geogFeat geogName
# VERGA geogFeat geogName
# 01 aucun
# 4.6.1.1 aucun
# . aucun
# Présentation aucun
# 07 aucun
# La aucun
# chaîne aucun
# de aucun
# montagnes aucun
# qui aucun
# longe aucun
# la aucun
# côte geogFeat geogName
# à aucun
# partir aucun
# de aucun
# Mostaganem geogFeat geogName
# s’ aucun
# étend aucun
# jusqu’ aucun
# à aucun
# Ras geogFeat geogName
# Ténès geogFeat geogName
# à aucun
# environ aucun
# 60 aucun
# M aucun
# à aucun
# l’ aucun
# ENE aucun
# de aucun
# Ras geogFeat geogName
# Ouillis geogFeat geogName
# . aucun
# Plusieurs aucun
# sommets aucun
# dépassent aucun
# 800 aucun
# m aucun
# d’ aucun
# altitude aucun
# . aucun
# 13 aucun
# Les aucun
# mouillages geogFeat geogName
# sont aucun
# rares aucun
# le aucun
# long aucun
# de aucun
# cette aucun
# partie aucun
# de aucun
# la aucun
# côte geogFeat geogName
# . aucun
# Ils aucun
# ne aucun
# sont aucun
# en aucun
# général aucun
# fréquentés aucun
# que aucun
# par aucun
# les aucun
# petits aucun
# navires aucun
# ou aucun
# les aucun
# bateaux aucun
# de aucun
# pêche aucun
# connaissant aucun
# les aucun
# lieux aucun
# . aucun
# 19 aucun
# À aucun
# environ aucun
# 2 aucun
# M aucun
# au aucun
# SW aucun
# de aucun
# Ras geogFeat geogName
# Ténès geogFeat geogName
# , aucun
# le aucun
# port geogFeat geogName
# de geogFeat geogName
# Ténès geogFeat geogName
# ( aucun
# § aucun
# 4.6.4 aucun
# . aucun
# ) aucun
# est aucun
# un aucun
# port geogFeat geogName
# de geogFeat geogName
# commerce geogFeat geogName
# d’ aucun
# importance aucun
# secon aucun
# daire aucun
# et aucun
# un aucun
# port geogFeat geogName
# de geogFeat geogName
# pêche geogFeat geogName
# . aucun
# 01 aucun
# 2.2.1.3 aucun
# . aucun
# Dangers geogFeat geogName
# au aucun
# large aucun
# 07 aucun
# La aucun
# présence aucun
# de aucun
# bancs geogFeat geogName
# du aucun
# large aucun
# , aucun
# qui aucun
# sont aucun
# présentés aucun
# dans aucun
# les aucun
# chapitres aucun
# descriptifs aucun
# correspondants aucun
# , aucun
# accroît aucun
# les aucun
# difficultés aucun
# de aucun
# navigation aucun
# dans aucun
# cette aucun
# zone geogFeat geogName
# . aucun
# 01 aucun
# 2.3.3.3 aucun
# . aucun
# Mouillage aucun
# 07 aucun
# L’ aucun
# anse geogFeat geogName
# de geogFeat geogName
# Miquelon geogFeat geogName
# est aucun
# très aucun
# saine aucun
# . aucun
# Il aucun
# est aucun
# possible aucun
# d’ aucun
# y aucun
# mouiller aucun
# par aucun
# 7 aucun
# à aucun
# 11 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Le aucun
# fond aucun
# est aucun
# de aucun
# bonne aucun
# tenue aucun
# , aucun
# sauf aucun
# par aucun
# fort aucun
# vent aucun
# d’ aucun
# Est aucun
# et aucun
# de aucun
# NE aucun
# où aucun
# il aucun
# faut aucun
# se aucun
# tenir aucun
# prêt aucun
# à aucun
# appareiller aucun
# à aucun
# tout aucun
# instant aucun
# . aucun
# 13 aucun
# On aucun
# évitera aucun
# de aucun
# mouiller aucun
# à aucun
# proximité aucun
# des aucun
# deux aucun
# câbles aucun
# sous-marins aucun
# de aucun
# fibre aucun
# optique aucun
# qui aucun
# traversent aucun
# l’ aucun
# anse geogFeat geogName
# de geogFeat geogName
# Mi geogFeat geogName
# quelon geogFeat geogName
# et aucun
# qui aucun
# atterrissent aucun
# au aucun
# Sud aucun
# de aucun
# l’ aucun
# appontement geogFeat geogName
# pétrolier geogFeat geogName
# . aucun
# 19 aucun
# Par aucun
# forts aucun
# vents aucun
# de aucun
# secteur aucun
# NNW aucun
# à aucun
# Est aucun
# , aucun
# le aucun
# seul aucun
# mouillage geogFeat geogName
# conseillé aucun
# est aucun
# situé aucun
# au aucun
# SW aucun
# de aucun
# Langlade geogFeat geogName
# , aucun
# dans aucun
# l’ aucun
# anse geogFeat geogName
# du geogFeat geogName
# Sud-Ouest geogFeat geogName
# ( aucun
# voir aucun
# § aucun
# 2.3.5 aucun
# . aucun
# ) aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 21 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 103 aucun
# / aucun
# 0 aucun
# 103 aucun
# SAINT-PIERRE-ET-MIQUELON geogFeat geogName

# %%
os.makedirs('../submissions', exist_ok=True)
submission = predictions[['Id', 'Label']]
submission.to_csv('../submissions/submission_xgb_1.csv', index=False)

# %%
submission
# Out:
#           Id              Label
# 0          0              aucun
# 1          1              aucun
# 2          2              aucun
# 3          3              aucun
# 4          4              aucun
# ...      ...                ...
# 26168  26168              aucun
# 26169  26169              aucun
# 26170  26170              aucun
# 26171  26171              aucun
# 26172  26172  geogFeat geogName
#
# [26173 rows x 2 columns]

# %% [markdown]
# ### Load model

# %%
copy_test = final_model.extractCandidates(df_test)

# %%
copy_test = final_model.classifyCandidates(copy_test)
# Out:
# /var/folders/g9/npfr2mks4118dkv7g8ckgccr0000gn/T/ipykernel_10940/72374964.py:54: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   vector = self.embeddings.word_vec(word)
# /var/folders/g9/npfr2mks4118dkv7g8ckgccr0000gn/T/ipykernel_10940/72374964.py:57: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   vector = self.embeddings.word_vec(word.lower())

# %%
copy_test = final_model.getPrediction(copy_test)

# %%
copy_test
# Out:
#           Id                     Token                     lower  isdigit  \
# 0          0                        01                        01     True
# 1          1                   2.1.4.8                   2.1.4.8    False
# 2          2                         .                         .    False
# 3          3                 Conduites                 conduites    False
# 4          4              sous-marines              sous-marines    False
# ...      ...                       ...                       ...      ...
# 26168  26168                       103                       103     True
# 26169  26169                         /                         /    False
# 26170  26170                         0                         0     True
# 26171  26171                       103                       103     True
# 26172  26172  SAINT-PIERRE-ET-MIQUELON  saint-pierre-et-miquelon    False
#
#        isupper  ispunct  isstop  len                     shape crf_pred  \
# 0        False    False   False    2                        xx    aucun
# 1        False    False   False    7                   xxxxxxx    aucun
# 2        False     True   False    1                         x    aucun
# 3        False    False   False    9                 Xxxxxxxxx    aucun
# 4        False    False   False   12              xxxxxxxxxxxx    aucun
# ...        ...      ...     ...  ...                       ...      ...
# 26168    False    False   False    3                       xxx    aucun
# 26169    False     True   False    1                         x    aucun
# 26170    False    False   False    1                         x    aucun
# 26171    False    False   False    3                       xxx    aucun
# 26172     True    False   False   24  XXXXXxXXXXXXxXXxXXXXXXXX      NER
#
#        geogFeat  geogName  name              Label
# 0           0.0       0.0   0.0              aucun
# 1           0.0       0.0   0.0              aucun
# 2           0.0       0.0   0.0              aucun
# 3           0.0       0.0   0.0              aucun
# 4           0.0       0.0   0.0              aucun
# ...         ...       ...   ...                ...
# 26168       0.0       0.0   0.0              aucun
# 26169       0.0       0.0   0.0              aucun
# 26170       0.0       0.0   0.0              aucun
# 26171       0.0       0.0   0.0              aucun
# 26172       1.0       1.0   0.0  geogFeat geogName
#
# [26173 rows x 14 columns]

# %%
copy_test = final_model.predict(df_test)
# Out:
# /var/folders/g9/npfr2mks4118dkv7g8ckgccr0000gn/T/ipykernel_10940/72374964.py:54: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   vector = self.embeddings.word_vec(word)
# /var/folders/g9/npfr2mks4118dkv7g8ckgccr0000gn/T/ipykernel_10940/72374964.py:57: DeprecationWarning: Call to deprecated `word_vec` (Use get_vector instead).
#   vector = self.embeddings.word_vec(word.lower())
#           Id              Label
# 0          0              aucun
# 1          1              aucun
# 2          2              aucun
# 3          3              aucun
# 4          4              aucun
# ...      ...                ...
# 26168  26168              aucun
# 26169  26169              aucun
# 26170  26170              aucun
# 26171  26171              aucun
# 26172  26172  geogFeat geogName
#
# [26173 rows x 2 columns]

# %%
for tok, label in zip(copy_test['Token'], copy_test['Label']):
    print(tok, label)
# Out:
# 01 aucun
# 2.1.4.8 aucun
# . aucun
# Conduites aucun
# sous-marines aucun
# 07 aucun
# Arrêtés aucun
# 1974 aucun
# - aucun
# 961 aucun
# ADM aucun
# / aucun
# SA aucun
# du aucun
# 6 aucun
# décembre aucun
# 1974 aucun
# et aucun
# 1998 aucun
# - aucun
# 002 aucun
# du aucun
# 15 aucun
# janvier aucun
# 1998 aucun
# du aucun
# préfet aucun
# maritime aucun
# de aucun
# la aucun
# Méditerranée geogFeat geogName
# ( aucun
# www.premar-mediterranee.gouv.fr/arretes.html aucun
# ) aucun
# , aucun
# courrier aucun
# des aucun
# Phares geogFeat geogName
# et geogFeat geogName
# Balises geogFeat geogName
# du aucun
# 9 aucun
# septembre aucun
# 1968 aucun
# . aucun
# 2107 aucun
# 08 aucun
# Émissaires aucun
# de aucun
# rejet aucun
# protégés aucun
# par aucun
# des aucun
# zones geogFeat geogName
# réglementées geogFeat geogName
# . aucun
# 13 aucun
# Situation aucun
# : aucun
# zones geogFeat geogName
# portées geogFeat geogName
# sur aucun
# les aucun
# cartes aucun
# , aucun
# devant aucun
# les aucun
# ports geogFeat geogName
# de aucun
# : aucun
# – aucun
# Cerbère geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 26,52 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 10,26 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Banyuls-sur-Mer geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 29,00 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 08,53 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Port-Vendres geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 31,41 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 07,22 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Collioure geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 31,79 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 05,21 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Argelès-sur-Mer geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 32,80 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 03,45 aucun
# ' aucun
# E aucun
# ) aucun
# ; aucun
# – aucun
# Grau geogFeat geogName
# - geogFeat geogName
# d’ geogFeat geogName
# Agde geogFeat geogName
# ( aucun
# 42 aucun
# ° aucun
# 15,92 aucun
# ' aucun
# N aucun
# — aucun
# 3 aucun
# ° aucun
# 27,45 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 19 aucun
# Réglementation aucun
# : aucun
# mouillage aucun
# et aucun
# dragage aucun
# interdits aucun
# . aucun
# 01 aucun
# 3.7.1 aucun
# . aucun
# Entre aucun
# le aucun
# port geogFeat geogName
# de geogFeat geogName
# Lomé geogFeat geogName
# et aucun
# le aucun
# port geogFeat geogName
# de geogFeat geogName
# Kpémé geogFeat geogName
# 07 aucun
# Le aucun
# phare geogFeat geogName
# de geogFeat geogName
# Baguida geogFeat geogName
# , aucun
# à aucun
# 2 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# de aucun
# la aucun
# contre-jetée aucun
# du aucun
# Port geogFeat geogName
# de geogFeat geogName
# Lomé geogFeat geogName
# , aucun
# est aucun
# un aucun
# pylône geogFeat geogName
# peint geogFeat geogName
# en aucun
# aluminium aucun
# , aucun
# haut aucun
# de aucun
# 34 aucun
# m aucun
# , aucun
# à aucun
# voyant aucun
# trapézoïdal aucun
# noir aucun
# . aucun
# 13 aucun
# Entre aucun
# le aucun
# Port geogFeat geogName
# de geogFeat geogName
# Lomé geogFeat geogName
# et aucun
# le aucun
# village geogFeat geogName
# de geogFeat geogName
# Kpémé geogFeat geogName
# à aucun
# 15 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# la aucun
# côte geogFeat geogName
# est aucun
# formée aucun
# d’ aucun
# une aucun
# plage geogFeat geogName
# de aucun
# sable aucun
# rectiligne aucun
# , aucun
# bordée aucun
# de aucun
# cocotiers aucun
# . aucun
# 19 aucun
# Au aucun
# Nord aucun
# de aucun
# Porto geogFeat geogName
# - geogFeat geogName
# Segouro geogFeat geogName
# ( aucun
# Porto geogFeat geogName
# - geogFeat geogName
# Seguro geogFeat geogName
# ) aucun
# [ aucun
# 6 aucun
# ° aucun
# 12 aucun
# ' aucun
# N aucun
# — aucun
# 1 aucun
# ° aucun
# 29 aucun
# ' aucun
# E aucun
# ] aucun
# , aucun
# ( aucun
# vue aucun
# 3.7.1 aucun
# . aucun
# ) aucun
# , aucun
# s’ aucun
# étend aucun
# le aucun
# Lac geogFeat geogName
# Togo geogFeat geogName
# , aucun
# vaste aucun
# étendue aucun
# d’ aucun
# eau aucun
# qui aucun
# se aucun
# prolonge aucun
# jusqu’ aucun
# au aucun
# village geogFeat geogName
# de geogFeat geogName
# Grand-Popo geogFeat geogName
# , aucun
# à aucun
# 20 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# par aucun
# une aucun
# lagune geogFeat geogName
# étroite aucun
# en aucun
# forme aucun
# de aucun
# canal aucun
# . aucun
# 25 aucun
# Le aucun
# village geogFeat geogName
# de geogFeat geogName
# Kpémé geogFeat geogName
# est aucun
# situé aucun
# à aucun
# 2 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# de aucun
# Porto geogFeat geogName
# - geogFeat geogName
# Segouro geogFeat geogName
# . aucun
# 31 aucun
# 3.7.1 aucun
# . aucun
# — aucun
# Vue aucun
# générale aucun
# de aucun
# Porto geogFeat geogName
# - geogFeat geogName
# Ségouro geogFeat geogName
# . aucun
# 01 aucun
# 6.2.1.7 aucun
# . aucun
# Règlementation aucun
# 07 aucun
# VOIE geogFeat geogName
# D’ geogFeat geogName
# ACCÈS geogFeat geogName
# OBLIGATOIRE geogFeat geogName
# . aucun
# — aucun
# Une aucun
# voie geogFeat geogName
# d’ geogFeat geogName
# accès geogFeat geogName
# est aucun
# obligatoire aucun
# pour aucun
# les aucun
# navires aucun
# dont aucun
# la aucun
# jauge aucun
# brute aucun
# est aucun
# supérieure aucun
# à aucun
# 3 aucun
# 000 aucun
# , aucun
# transportant aucun
# des aucun
# hydrocarbures aucun
# ou aucun
# des aucun
# substances aucun
# dangereuses aucun
# ( aucun
# arrêté aucun
# 2006/069 aucun
# du aucun
# 30 aucun
# août aucun
# 2006 aucun
# [ aucun
# modifié aucun
# ] aucun
# du aucun
# préfet aucun
# maritime aucun
# de aucun
# l’ aucun
# Atlantique geogFeat geogName
# ) aucun
# . aucun
# 13 aucun
# Le aucun
# chenal geogFeat geogName
# d’ geogFeat geogName
# approche geogFeat geogName
# est aucun
# limité aucun
# : aucun
# – aucun
# au aucun
# Nord aucun
# et aucun
# au aucun
# Sud aucun
# , aucun
# par aucun
# des aucun
# lignes aucun
# orientées aucun
# à aucun
# 328,4 aucun
# ° aucun
# et aucun
# 270 aucun
# ° aucun
# à aucun
# partir aucun
# du aucun
# feu geogFeat geogName
# de aucun
# la aucun
# digue geogFeat geogName
# Nord geogFeat geogName
# ; aucun
# – aucun
# à aucun
# l’ aucun
# Ouest aucun
# , aucun
# le aucun
# chenal geogFeat geogName
# débute geogFeat geogName
# à aucun
# 7 aucun
# M aucun
# du aucun
# feu geogFeat geogName
# de aucun
# la aucun
# digue geogFeat geogName
# Nord geogFeat geogName
# , aucun
# et aucun
# se aucun
# prolonge aucun
# , aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# jusqu’ aucun
# à aucun
# 1 aucun
# M aucun
# de aucun
# ce aucun
# même aucun
# feu geogFeat geogName
# . aucun
# 19 aucun
# La aucun
# zone geogFeat geogName
# d’ geogFeat geogName
# attente geogFeat geogName
# est aucun
# limitée aucun
# : aucun
# – aucun
# au aucun
# Nord aucun
# par aucun
# la aucun
# ligne geogFeat geogName
# orientée aucun
# à aucun
# 300 aucun
# ° aucun
# à aucun
# partir aucun
# du aucun
# château geogFeat geogName
# d’ geogFeat geogName
# eau geogFeat geogName
# d’ geogFeat geogName
# Ondres geogFeat geogName
# ; aucun
# – aucun
# au aucun
# Sud aucun
# par aucun
# la aucun
# ligne geogFeat geogName
# orientée aucun
# à aucun
# 328,4 aucun
# ° aucun
# à aucun
# partir aucun
# du aucun
# feu geogFeat geogName
# de aucun
# la aucun
# digue geogFeat geogName
# Nord geogFeat geogName
# ; aucun
# – aucun
# à aucun
# l’ aucun
# Est aucun
# et aucun
# à aucun
# l’ aucun
# Ouest aucun
# par aucun
# les aucun
# distances aucun
# de aucun
# 2 aucun
# M aucun
# et aucun
# 4 aucun
# M aucun
# à aucun
# partir aucun
# du aucun
# trait aucun
# de aucun
# côte geogFeat geogName
# . aucun
# 25 aucun
# À aucun
# partir aucun
# de aucun
# l’ aucun
# extrémité aucun
# Est aucun
# du aucun
# chenal geogFeat geogName
# d’ geogFeat geogName
# approche geogFeat geogName
# , aucun
# les aucun
# navires aucun
# se aucun
# conforment aucun
# aux aucun
# instructions aucun
# du aucun
# pilote aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 281 aucun
# / aucun
# 0 aucun
# 281 aucun
# DE aucun
# L’ aucun
# ADOUR geogFeat geogName
# À aucun
# LA aucun
# FRONTIÈRE geogFeat geogName
# ESPAGNOLE geogFeat geogName
# 31 aucun
# CARACTÉRISTIQUES aucun
# DU aucun
# NAVIRE geogFeat geogName
# DE geogFeat geogName
# RÉFÉRENCE geogFeat geogName
# . aucun
# — aucun
# Les aucun
# caractéristiques aucun
# du aucun
# navire aucun
# de aucun
# référence aucun
# autorisé aucun
# à aucun
# accéder aucun
# au aucun
# port geogFeat geogName
# sont aucun
# les aucun
# suivantes aucun
# : aucun
# longueur aucun
# 160 aucun
# m aucun
# , aucun
# largeur aucun
# 25 aucun
# m aucun
# , aucun
# tirant aucun
# d’ aucun
# eau aucun
# à aucun
# l’ aucun
# entrée aucun
# 8,70 aucun
# m aucun
# , aucun
# tirant aucun
# d’ aucun
# eau aucun
# à aucun
# la aucun
# sortie aucun
# 9,60 aucun
# m. aucun
# 37 aucun
# L’ aucun
# accès geogFeat geogName
# d’ aucun
# un aucun
# navire aucun
# présentant aucun
# une aucun
# caractéristique aucun
# supérieure aucun
# à aucun
# celles aucun
# du aucun
# navire aucun
# de aucun
# référence aucun
# peut aucun
# être aucun
# autorisé aucun
# par aucun
# la aucun
# capitainerie geogFeat geogName
# , geogFeat geogName
# après aucun
# avis aucun
# du aucun
# pilotage aucun
# . aucun
# Dans aucun
# ce aucun
# cas aucun
# , aucun
# il aucun
# est aucun
# conseillé aucun
# aux aucun
# représentants aucun
# du aucun
# navire aucun
# de aucun
# déposer aucun
# à aucun
# la aucun
# capitainerie geogFeat geogName
# , aucun
# au aucun
# minimum aucun
# une aucun
# semaine aucun
# avant aucun
# le aucun
# mouvement aucun
# prévu aucun
# , aucun
# la aucun
# demande aucun
# d’ aucun
# escale aucun
# qui aucun
# doit aucun
# comporter aucun
# les aucun
# caractéristiques aucun
# détaillées aucun
# du aucun
# navire aucun
# . aucun
# 43 aucun
# Des aucun
# restrictions aucun
# peuvent aucun
# être aucun
# apportées aucun
# par aucun
# la aucun
# capitainerie geogFeat geogName
# , aucun
# pour aucun
# des aucun
# raisons aucun
# de aucun
# sécurité aucun
# , aucun
# de aucun
# profondeur aucun
# du aucun
# chenal geogFeat geogName
# ou aucun
# de aucun
# conditions aucun
# nautiques aucun
# et aucun
# météorologiques aucun
# . aucun
# 49 aucun
# De aucun
# nuit aucun
# , aucun
# seuls aucun
# sont aucun
# autorisés aucun
# à aucun
# faire aucun
# mouvement aucun
# les aucun
# navires aucun
# dont aucun
# les aucun
# dimensions aucun
# n’ aucun
# excèdent aucun
# pas aucun
# 130 aucun
# m aucun
# de aucun
# long aucun
# et aucun
# 7,00 aucun
# m aucun
# de aucun
# tirant aucun
# d’ aucun
# eau aucun
# . aucun
# 55 aucun
# L’ aucun
# entrée geogFeat geogName
# de aucun
# l’ aucun
# Adour geogFeat geogName
# peut aucun
# être aucun
# impraticable aucun
# par aucun
# gros aucun
# temps aucun
# en aucun
# mer aucun
# , aucun
# ou aucun
# forte aucun
# crue aucun
# en aucun
# rivière geogFeat geogName
# , aucun
# particulièrement aucun
# en aucun
# jusant aucun
# . aucun
# Les aucun
# navires aucun
# reçoivent aucun
# alors aucun
# des aucun
# instructions aucun
# de aucun
# la aucun
# capitainerie geogFeat geogName
# sur geogFeat geogName
# VHF geogFeat geogName
# , aucun
# canal aucun
# 12 aucun
# , aucun
# soit aucun
# pour aucun
# quitter aucun
# leur aucun
# mouillage aucun
# , aucun
# soit aucun
# pour aucun
# rester aucun
# en aucun
# attente aucun
# au aucun
# large aucun
# . aucun
# 61 aucun
# PROFONDEURS aucun
# , aucun
# TIRANTS geogFeat geogName
# D’ geogFeat geogName
# EAU geogFeat geogName
# ET geogFeat geogName
# TIRANTS geogFeat geogName
# D’ geogFeat geogName
# AIR geogFeat geogName
# ADMISSIBLES geogFeat geogName
# . aucun
# — aucun
# Les aucun
# profondeurs aucun
# à aucun
# l’ aucun
# embouchure geogFeat geogName
# sont aucun
# variables aucun
# suivant aucun
# les aucun
# saisons aucun
# ; aucun
# elles aucun
# sont aucun
# entretenues aucun
# par aucun
# dragage aucun
# . aucun
# Elles aucun
# ne aucun
# sont aucun
# pratiquement aucun
# pas aucun
# inférieures aucun
# à aucun
# 9,5 aucun
# m aucun
# en aucun
# été aucun
# , aucun
# mais aucun
# peuvent aucun
# être aucun
# réduites aucun
# en aucun
# hiver aucun
# à aucun
# la aucun
# suite aucun
# des aucun
# tempêtes aucun
# d’ aucun
# Ouest aucun
# à aucun
# SW aucun
# . aucun
# 67 aucun
# Le aucun
# tirant aucun
# d’ aucun
# eau aucun
# admissible aucun
# est aucun
# fonction aucun
# du aucun
# coefficient aucun
# de aucun
# la aucun
# marée aucun
# , aucun
# de aucun
# l’ aucun
# état aucun
# de aucun
# la aucun
# mer aucun
# , aucun
# des aucun
# vents aucun
# , aucun
# de aucun
# l’ aucun
# état aucun
# d’ aucun
# ensablement aucun
# à aucun
# l’ aucun
# embouchure geogFeat geogName
# de aucun
# l’ aucun
# Adour geogFeat geogName
# , aucun
# ainsi aucun
# que aucun
# de aucun
# la aucun
# hauteur aucun
# d’ aucun
# eau aucun
# au aucun
# poste geogFeat geogName
# d’ geogFeat geogName
# amarrage geogFeat geogName
# souhaité aucun
# . aucun
# Par aucun
# conditions aucun
# idéales aucun
# , aucun
# le aucun
# tirant aucun
# d’ aucun
# eau aucun
# maximal aucun
# admissible aucun
# est aucun
# : aucun
# de aucun
# jour aucun
# 8,70 aucun
# m aucun
# à aucun
# l’ aucun
# entrée geogFeat geogName
# et aucun
# 9,60 aucun
# m aucun
# à aucun
# la aucun
# sortie aucun
# ; aucun
# de aucun
# nuit aucun
# 7 aucun
# m. aucun
# 73 aucun
# Le aucun
# pont geogFeat geogName
# Henri geogFeat geogName
# Grenet geogFeat geogName
# , aucun
# situé aucun
# à aucun
# 3,1 aucun
# M aucun
# de aucun
# l’ aucun
# embouchure geogFeat geogName
# de aucun
# l’ aucun
# Adour geogFeat geogName
# , aucun
# autorise aucun
# un aucun
# tirant aucun
# d’ aucun
# air aucun
# de aucun
# 9,5 aucun
# m aucun
# par aucun
# rapport aucun
# au aucun
# zéro aucun
# des aucun
# cartes aucun
# . aucun
# 01 aucun
# 5.4.10.3 aucun
# . aucun
# Accès aucun
# 07 aucun
# À aucun
# l’ aucun
# angle aucun
# des aucun
# vestiges geogFeat geogName
# d’ aucun
# une aucun
# ancienne geogFeat geogName
# digue geogFeat geogName
# , aucun
# une aucun
# balise geogFeat geogName
# latérale geogFeat geogName
# bâbord geogFeat geogName
# , aucun
# avec aucun
# panneaux aucun
# réfléchissants aucun
# , aucun
# signale aucun
# l’ aucun
# entrée geogFeat geogName
# du aucun
# port geogFeat geogName
# . aucun
# 01 aucun
# 2.4.5 aucun
# . aucun
# Chenalage aucun
# 07 aucun
# Les aucun
# voies geogFeat geogName
# recommandées aucun
# permettant aucun
# l’ aucun
# accès geogFeat geogName
# à aucun
# Nouméa geogFeat geogName
# sont aucun
# portées aucun
# sur aucun
# les aucun
# cartes aucun
# ( aucun
# § aucun
# 2.1.1.3 aucun
# . aucun
# ) aucun
# . aucun
# Leurs aucun
# limites aucun
# sont aucun
# précisées aucun
# en aucun
# annexe aucun
# ( aucun
# § aucun
# 7.4 aucun
# . aucun
# ) aucun
# . aucun
# 13 aucun
# Corne aucun
# SE aucun
# : aucun
# – aucun
# du aucun
# canal aucun
# de aucun
# la aucun
# Havannah geogFeat geogName
# ( aucun
# § aucun
# 2.2.1.1 aucun
# . aucun
# ) aucun
# à aucun
# Nouméa geogFeat geogName
# ( aucun
# § aucun
# 2.4 aucun
# . aucun
# ) aucun
# par aucun
# le aucun
# canal geogFeat geogName
# Woodin geogFeat geogName
# ( aucun
# § aucun
# 2.2.3 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# menant aucun
# à aucun
# la aucun
# passe geogFeat geogName
# de geogFeat geogName
# la geogFeat geogName
# Sarcelle geogFeat geogName
# ( aucun
# § aucun
# 2.2.1.6 aucun
# . aucun
# ) aucun
# et aucun
# à aucun
# l’ aucun
# île geogFeat geogName
# des geogFeat geogName
# Pins geogFeat geogName
# ( aucun
# § aucun
# 2.2.2 aucun
# . aucun
# ) aucun
# . aucun
# 19 aucun
# Côte geogFeat geogName
# SW geogFeat geogName
# : aucun
# – aucun
# de aucun
# la aucun
# passe geogFeat geogName
# de geogFeat geogName
# Uatio geogFeat geogName
# jusqu’ aucun
# au aucun
# mouillage aucun
# de aucun
# l’ aucun
# îlot geogFeat geogName
# Kouaré geogFeat geogName
# ( aucun
# § aucun
# 2.2.5 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# de aucun
# la aucun
# passe geogFeat geogName
# Nord aucun
# des aucun
# passes geogFeat geogName
# de geogFeat geogName
# Boulari geogFeat geogName
# ( aucun
# § aucun
# 2.3.1 aucun
# . aucun
# ) aucun
# à aucun
# la aucun
# Petite geogFeat geogName
# rade geogFeat geogName
# ( aucun
# § aucun
# 2.4.6.1 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# reliant aucun
# les aucun
# passes geogFeat geogName
# de geogFeat geogName
# Boulari geogFeat geogName
# au aucun
# canal geogFeat geogName
# Woodin geogFeat geogName
# ( aucun
# § aucun
# 2.2.3 aucun
# . aucun
# ) aucun
# ou aucun
# au aucun
# canal aucun
# de aucun
# la aucun
# Havannah geogFeat geogName
# ( aucun
# § aucun
# 2.2.1.1 aucun
# . aucun
# ) aucun
# ; aucun
# – aucun
# de aucun
# la aucun
# passe geogFeat geogName
# de geogFeat geogName
# Dumbéa geogFeat geogName
# ( aucun
# § aucun
# 2.3.2.1 aucun
# . aucun
# ) aucun
# et aucun
# celles aucun
# menant aucun
# de aucun
# cette aucun
# passe geogFeat geogName
# à geogFeat geogName
# Nouméa geogFeat geogName
# ; aucun
# – aucun
# de aucun
# la aucun
# passe geogFeat geogName
# de geogFeat geogName
# Uitoé geogFeat geogName
# ( aucun
# § aucun
# 2.5.2.1 aucun
# . aucun
# ) aucun
# à aucun
# Nouméa geogFeat geogName
# . aucun
# 25 aucun
# Les aucun
# points aucun
# d’ aucun
# embarquement aucun
# des aucun
# pilotes aucun
# sont aucun
# précisés aucun
# au aucun
# § aucun
# 2.4.4 aucun
# . aucun
# 01 aucun
# 4.5.5.4 aucun
# . aucun
# Données aucun
# portuaires aucun
# 07 aucun
# Caractéristiques aucun
# nautiques aucun
# Météorologie aucun
# locale aucun
# Vents aucun
# tourbillonnants aucun
# dans aucun
# la aucun
# baie geogFeat geogName
# par aucun
# temps aucun
# de aucun
# mistral aucun
# . aucun
# Navires aucun
# admis aucun
# PORT geogFeat geogName
# PUBLIC geogFeat geogName
# : aucun
# unités aucun
# de aucun
# plaisance aucun
# de aucun
# 4 aucun
# à aucun
# 30 aucun
# m. aucun
# Installations geogFeat geogName
# portuaires geogFeat geogName
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 21 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 205 aucun
# / aucun
# 0 aucun
# 205 aucun
# DE aucun
# LA aucun
# PRESQU’ geogFeat geogName
# ÎLE geogFeat geogName
# DE geogFeat geogName
# GIENS geogFeat geogName
# AU aucun
# CAP geogFeat geogName
# CAMARAT geogFeat geogName
# – aucun
# ÎLES geogFeat geogName
# D’ geogFeat geogName
# HYÈRES geogFeat geogName
# PORT geogFeat geogName
# PRIVÉ geogFeat geogName
# : aucun
# unités aucun
# de aucun
# plaisance aucun
# de aucun
# 7 aucun
# à aucun
# 16 aucun
# m. aucun
# Infrastructures geogFeat geogName
# 1 aucun
# port geogFeat geogName
# à aucun
# gestion aucun
# privée aucun
# ou aucun
# nouveau aucun
# port geogFeat geogName
# dans aucun
# la aucun
# partie aucun
# Est aucun
# et aucun
# 1 aucun
# port geogFeat geogName
# public geogFeat geogName
# à aucun
# l’ aucun
# Ouest aucun
# . aucun
# 1 aucun
# 251 aucun
# places geogFeat geogName
# dont aucun
# 100 aucun
# pour aucun
# bateaux aucun
# de aucun
# passage aucun
# sur aucun
# l’ aucun
# ensemble aucun
# des aucun
# deux aucun
# ports geogFeat geogName
# . aucun
# PORT geogFeat geogName
# PUBLIC geogFeat geogName
# : aucun
# 621 aucun
# places geogFeat geogName
# . aucun
# PORT geogFeat geogName
# PRIVÉ geogFeat geogName
# : aucun
# 545 aucun
# places geogFeat geogName
# . aucun
# Zone geogFeat geogName
# de geogFeat geogName
# mouillage geogFeat geogName
# organisé geogFeat geogName
# ( aucun
# en aucun
# saison aucun
# ) aucun
# : aucun
# 85 aucun
# places geogFeat geogName
# supplémentaires geogFeat geogName
# pour aucun
# bateaux aucun
# de aucun
# 7 aucun
# à aucun
# 16 aucun
# m. aucun
# Outillage aucun
# 1 aucun
# cale geogFeat geogName
# de geogFeat geogName
# halage geogFeat geogName
# + aucun
# 1 aucun
# élévateur aucun
# à aucun
# bateaux aucun
# de aucun
# 35 aucun
# t. aucun
# Ravitaillement aucun
# Eau aucun
# aux aucun
# appontements geogFeat geogName
# . aucun
# Poste geogFeat geogName
# de geogFeat geogName
# carburants geogFeat geogName
# à aucun
# l’ aucun
# épi geogFeat geogName
# entre aucun
# les aucun
# deux aucun
# ports geogFeat geogName
# ( aucun
# longueur aucun
# 20 aucun
# m aucun
# par aucun
# 1,8 aucun
# à aucun
# 3 aucun
# m aucun
# d’ aucun
# eau aucun
# ) aucun
# . aucun
# Administration aucun
# Organisation aucun
# PORT geogFeat geogName
# PUBLIC geogFeat geogName
# : aucun
# gestion aucun
# concédée aucun
# à aucun
# la aucun
# commune geogFeat geogName
# de geogFeat geogName
# Cavalaire-sur-Mer geogFeat geogName
# . aucun
# Bureau geogFeat geogName
# du geogFeat geogName
# port geogFeat geogName
# public geogFeat geogName
# : aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.17.81 aucun
# ; aucun
# télécopie aucun
# : aucun
# 04.64.64.67.06 aucun
# ; aucun
# mél aucun
# : aucun
# port@cavalaire.fr aucun
# . aucun
# Veille aucun
# VHF aucun
# en aucun
# saison aucun
# . aucun
# Site aucun
# web aucun
# : aucun
# www.cavalaire.fr aucun
# . aucun
# PORT geogFeat geogName
# PRIVÉ geogFeat geogName
# : aucun
# gestion aucun
# par aucun
# société aucun
# anonyme aucun
# ( aucun
# SACNPPC geogFeat geogName
# ) aucun
# . aucun
# Bureau geogFeat geogName
# du geogFeat geogName
# port geogFeat geogName
# privé geogFeat geogName
# : aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.16.01 aucun
# ; aucun
# télécopie aucun
# : aucun
# 04.94.64.36.06 aucun
# ; aucun
# mél aucun
# : aucun
# info@port- aucun
# cavalaire.com aucun
# . aucun
# Veille aucun
# VHF aucun
# en aucun
# saison aucun
# . aucun
# Site aucun
# web aucun
# : aucun
# www.port-cavalaire.com aucun
# . aucun
# Accueil aucun
# des aucun
# navires aucun
# Au aucun
# quai geogFeat geogName
# d’ geogFeat geogName
# attente geogFeat geogName
# , aucun
# devant aucun
# le aucun
# bureau geogFeat geogName
# du geogFeat geogName
# port geogFeat geogName
# public geogFeat geogName
# . aucun
# Services aucun
# Affaires aucun
# maritimes aucun
# : aucun
# à aucun
# Toulon geogFeat geogName
# . aucun
# Douanes aucun
# : aucun
# à aucun
# Toulon geogFeat geogName
# . aucun
# Poste geogFeat geogName
# de geogFeat geogName
# secours geogFeat geogName
# du geogFeat geogName
# Parc geogFeat geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.11.54 aucun
# ( aucun
# du aucun
# 1er aucun
# juin aucun
# au aucun
# 30 aucun
# septembre aucun
# ) aucun
# . aucun
# Poste geogFeat geogName
# de geogFeat geogName
# secours geogFeat geogName
# de geogFeat geogName
# Pardigon geogFeat geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.43.49 aucun
# ( aucun
# du aucun
# 15 aucun
# juin aucun
# au aucun
# 15 aucun
# septembre aucun
# ) aucun
# . aucun
# Gendarmerie geogFeat geogName
# : aucun
# Rue geogFeat geogName
# A. geogFeat geogName
# Daudet geogFeat geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.04.17 aucun
# . aucun
# Communications aucun
# Lignes aucun
# d’ aucun
# autocars aucun
# . aucun
# Gare geogFeat geogName
# SNCF geogFeat geogName
# à aucun
# Hyères geogFeat geogName
# et aucun
# Toulon geogFeat geogName
# . aucun
# Aéroport geogFeat geogName
# de geogFeat geogName
# Hyères geogFeat geogName
# - geogFeat geogName
# Le geogFeat geogName
# Palyvestre geogFeat geogName
# . aucun
# Ville geogFeat geogName
# Mairie geogFeat geogName
# ; aucun
# tél aucun
# . aucun
# : aucun
# 04.94.64.04.26 aucun
# . aucun
# 4.5.5.4 aucun
# . aucun
# — aucun
# Port geogFeat geogName
# de geogFeat geogName
# Cavalaire geogFeat geogName
# ( aucun
# 43 aucun
# ° aucun
# 10,3 aucun
# ' aucun
# N aucun
# — aucun
# 6 aucun
# ° aucun
# 32,2 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 206 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 21 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 206 aucun
# / aucun
# 0 aucun
# DU aucun
# CAP geogFeat geogName
# BÉNAT geogFeat geogName
# AU aucun
# CAP geogFeat geogName
# CAMARAT geogFeat geogName
# . aucun
# 01 aucun
# 5.4.8.1 aucun
# . aucun
# Généralités aucun
# 07 aucun
# L’ aucun
# étier geogFeat geogName
# de geogFeat geogName
# Port geogFeat geogName
# des geogFeat geogName
# Champs geogFeat geogName
# est aucun
# situé aucun
# à aucun
# 1,5 aucun
# M aucun
# au aucun
# Sud aucun
# de aucun
# l’ aucun
# étier geogFeat geogName
# de geogFeat geogName
# la geogFeat geogName
# Louippe geogFeat geogName
# et aucun
# débouche aucun
# lui aucun
# aussi aucun
# dans aucun
# une aucun
# ouverture aucun
# de aucun
# la aucun
# digue geogFeat geogName
# du geogFeat geogName
# littoral geogFeat geogName
# . aucun
# 01 aucun
# 9.2 aucun
# . aucun
# Du aucun
# cap geogFeat geogName
# Vert geogFeat geogName
# à aucun
# la aucun
# pointe geogFeat geogName
# Rouge geogFeat geogName
# . aucun
# Baie geogFeat geogName
# de geogFeat geogName
# Gorée geogFeat geogName
# 07 aucun
# La aucun
# presqu’ geogFeat geogName
# île geogFeat geogName
# du aucun
# cap geogFeat geogName
# Vert geogFeat geogName
# comprend aucun
# deux aucun
# pointes geogFeat geogName
# saillantes aucun
# orientées aucun
# , aucun
# l’ aucun
# une aucun
# vers aucun
# l’ aucun
# Ouest aucun
# et aucun
# l’ aucun
# autre aucun
# vers aucun
# le aucun
# Sud aucun
# . aucun
# 13 aucun
# Le aucun
# cap geogFeat geogName
# Vert geogFeat geogName
# , aucun
# terminé aucun
# par aucun
# la aucun
# pointe geogFeat geogName
# des geogFeat geogName
# Almadies geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 44,47′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 31,95 aucun
# ' aucun
# W aucun
# ) aucun
# est aucun
# le aucun
# point aucun
# le aucun
# plus aucun
# occidental aucun
# de aucun
# la aucun
# côte geogFeat geogName
# Ouest geogFeat geogName
# du aucun
# continent geogFeat geogName
# africain geogFeat geogName
# . aucun
# Le aucun
# cap geogFeat geogName
# Manuel geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 38,77′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 25,98′ aucun
# W aucun
# ) aucun
# , aucun
# orienté aucun
# au aucun
# Sud aucun
# , aucun
# délimite aucun
# la aucun
# partie aucun
# Ouest aucun
# de aucun
# la aucun
# baie geogFeat geogName
# de geogFeat geogName
# Gorée geogFeat geogName
# . aucun
# 19 aucun
# La aucun
# baie geogFeat geogName
# de geogFeat geogName
# Gorée geogFeat geogName
# s’ aucun
# ouvre aucun
# entre aucun
# le aucun
# Cap geogFeat geogName
# Manuel geogFeat geogName
# et aucun
# la aucun
# pointe geogFeat geogName
# Rouge geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 38,11′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 10,42′ aucun
# W aucun
# ) aucun
# distante aucun
# de aucun
# 15 aucun
# M aucun
# à aucun
# l’ aucun
# Est aucun
# . aucun
# Bien aucun
# qu’ aucun
# ouverte aucun
# aux aucun
# vents aucun
# de aucun
# Sud aucun
# , aucun
# cette aucun
# vaste aucun
# baie geogFeat geogName
# est aucun
# réputée aucun
# être aucun
# sûre aucun
# . aucun
# L’ aucun
# île geogFeat geogName
# de geogFeat geogName
# Gorée geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 39,98′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 23,89′ aucun
# W aucun
# ) aucun
# se aucun
# trouve aucun
# dans aucun
# l’ aucun
# entrée geogFeat geogName
# de aucun
# la aucun
# baie geogFeat geogName
# . aucun
# 25 aucun
# Le aucun
# port geogFeat geogName
# de geogFeat geogName
# Dakar geogFeat geogName
# , aucun
# décrit aucun
# dans aucun
# le aucun
# paragraphe aucun
# 9.2.3 aucun
# . aucun
# , aucun
# est aucun
# établi aucun
# dans aucun
# l’ aucun
# anse geogFeat geogName
# qui aucun
# s’ aucun
# étend aucun
# entre aucun
# la aucun
# pointe geogFeat geogName
# de geogFeat geogName
# Dakar geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 40,19′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 25,30′ aucun
# W aucun
# ) aucun
# , aucun
# au aucun
# Sud aucun
# et aucun
# la aucun
# pointe geogFeat geogName
# de geogFeat geogName
# Bel geogFeat geogName
# - geogFeat geogName
# Air geogFeat geogName
# ( aucun
# 14 aucun
# ° aucun
# 42,08′ aucun
# N aucun
# — aucun
# 17 aucun
# ° aucun
# 25,03′ aucun
# W aucun
# ) aucun
# , aucun
# au aucun
# Nord aucun
# . aucun
# 31 aucun
# Outre aucun
# la aucun
# ville geogFeat geogName
# de geogFeat geogName
# Dakar geogFeat geogName
# qui aucun
# occupe aucun
# la aucun
# majeure aucun
# partie aucun
# de aucun
# la aucun
# presqu’ geogFeat geogName
# île geogFeat geogName
# du aucun
# cap geogFeat geogName
# Vert geogFeat geogName
# , aucun
# la aucun
# côte geogFeat geogName
# Nord geogFeat geogName
# de aucun
# la aucun
# baie geogFeat geogName
# de geogFeat geogName
# Gorée geogFeat geogName
# est aucun
# urbanisée aucun
# de aucun
# façon aucun
# presque aucun
# continue aucun
# depuis aucun
# la aucun
# pointe geogFeat geogName
# de geogFeat geogName
# Bel geogFeat geogName
# - geogFeat geogName
# Air geogFeat geogName
# jusqu’ aucun
# à aucun
# Rufisque geogFeat geogName
# . aucun
# 01 aucun
# 4.3.4.4 aucun
# . aucun
# Maupihaa aucun
# ( aucun
# Mopelia geogFeat geogName
# ) aucun
# 07 aucun
# À aucun
# 100 aucun
# M aucun
# à aucun
# l’ aucun
# WSW aucun
# de aucun
# Maupiti geogFeat geogName
# , aucun
# Maupihaa geogFeat geogName
# ( aucun
# Mopelia geogFeat geogName
# ) aucun
# [ aucun
# 16 aucun
# ° aucun
# 48 aucun
# ' aucun
# S aucun
# — aucun
# 153 aucun
# ° aucun
# 58 aucun
# ' aucun
# W aucun
# ] aucun
# est aucun
# un aucun
# atoll geogFeat geogName
# de aucun
# 4,5 aucun
# M aucun
# de aucun
# diamètre aucun
# , aucun
# avec aucun
# une aucun
# longue aucun
# île geogFeat geogName
# étroite geogFeat geogName
# , geogFeat geogName
# Motu geogFeat geogName
# Maupihaa geogFeat geogName
# , aucun
# couverte aucun
# de aucun
# cocotiers aucun
# , aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# un aucun
# motu aucun
# isolé aucun
# au aucun
# NW aucun
# et aucun
# un aucun
# récif- aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 221 aucun
# / aucun
# 0 aucun
# 221 aucun
# ÎLES geogFeat geogName
# DU aucun
# VENT aucun
# – aucun
# ÎLES geogFeat geogName
# SOUS-LE-VENT geogFeat geogName
# – aucun
# ÎLES geogFeat geogName
# AUSTRALES geogFeat geogName
# barrière aucun
# juste aucun
# affleurant aucun
# au aucun
# SW aucun
# . aucun
# Sa aucun
# population aucun
# est aucun
# réduite aucun
# à aucun
# 3 aucun
# habitants aucun
# sédentaires aucun
# ( aucun
# 2012 aucun
# ) aucun
# , aucun
# vivant aucun
# de aucun
# la aucun
# pêche aucun
# et aucun
# de aucun
# la aucun
# récolte aucun
# du aucun
# coprah aucun
# . aucun
# Les aucun
# exploitations aucun
# de aucun
# fermes aucun
# perlières aucun
# et aucun
# de aucun
# nacres aucun
# sont aucun
# abandonnées aucun
# . aucun
# 13 aucun
# L’ aucun
# unique aucun
# passe geogFeat geogName
# Taihaaru geogFeat geogName
# Vahine geogFeat geogName
# , aucun
# au aucun
# NW aucun
# de aucun
# l’ aucun
# atoll geogFeat geogName
# , aucun
# est aucun
# étroite aucun
# ( aucun
# 35 aucun
# m aucun
# ) aucun
# mais aucun
# profonde aucun
# ( aucun
# 12 aucun
# m aucun
# ) aucun
# . aucun
# Son aucun
# balisage geogFeat geogName
# , aucun
# détruit aucun
# par aucun
# les aucun
# intempéries geogFeat geogName
# n’ aucun
# a aucun
# pas aucun
# été aucun
# restauré aucun
# ( aucun
# 2014 aucun
# ) aucun
# . aucun
# À aucun
# l’ aucun
# entrée geogFeat geogName
# du aucun
# lagon geogFeat geogName
# , aucun
# la aucun
# passe geogFeat geogName
# se aucun
# divise aucun
# en aucun
# deux aucun
# chenaux geogFeat geogName
# ; aucun
# celui aucun
# du aucun
# NE aucun
# , aucun
# non aucun
# balisé aucun
# , aucun
# n’ aucun
# est aucun
# praticable aucun
# que aucun
# par aucun
# de aucun
# petites aucun
# embarcations aucun
# ; aucun
# celui aucun
# du aucun
# SW aucun
# franchit aucun
# un aucun
# seuil aucun
# couvert aucun
# de aucun
# 3,7 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Il aucun
# doit aucun
# être aucun
# emprunté aucun
# avec aucun
# précaution aucun
# , aucun
# par aucun
# temps aucun
# clair aucun
# quand aucun
# les aucun
# têtes geogFeat geogName
# de geogFeat geogName
# corail geogFeat geogName
# sont aucun
# bien aucun
# visibles aucun
# , aucun
# de aucun
# préférence aucun
# en aucun
# début aucun
# de aucun
# matinée aucun
# quand aucun
# le aucun
# courant aucun
# est aucun
# le aucun
# plus aucun
# faible aucun
# . aucun
# Le aucun
# courant aucun
# , aucun
# toujours aucun
# sortant aucun
# , aucun
# peut aucun
# atteindre aucun
# 9 aucun
# nœuds aucun
# par aucun
# forte aucun
# houle aucun
# de aucun
# SW aucun
# ( aucun
# ensachage aucun
# ) aucun
# et aucun
# provoque aucun
# des aucun
# tourbillons aucun
# près aucun
# du aucun
# plateau geogFeat geogName
# de aucun
# corail aucun
# central aucun
# . aucun
# 19 aucun
# Le aucun
# lagon geogFeat geogName
# est aucun
# très aucun
# vaste aucun
# et aucun
# profond aucun
# avec aucun
# de aucun
# nombreux aucun
# bancs geogFeat geogName
# de geogFeat geogName
# corail geogFeat geogName
# bien aucun
# visibles aucun
# . aucun
# 25 aucun
# MOUILLAGE aucun
# . aucun
# — aucun
# Faire geogFeat geogName
# route geogFeat geogName
# à aucun
# 065 aucun
# ° aucun
# , aucun
# en aucun
# relevant aucun
# par aucun
# l’ aucun
# arrière aucun
# à aucun
# 245 aucun
# ° aucun
# l’ aucun
# extrémité aucun
# Sud aucun
# de aucun
# l’ aucun
# îlot geogFeat geogName
# à aucun
# l’ aucun
# WSW aucun
# du aucun
# Motu geogFeat geogName
# Manu geogFeat geogName
# ; aucun
# mouiller aucun
# par aucun
# profondeur aucun
# de aucun
# 16 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# sable aucun
# avec aucun
# de aucun
# nombreuses aucun
# patates aucun
# de aucun
# corail aucun
# , aucun
# en aucun
# relevant aucun
# à aucun
# 312 aucun
# ° aucun
# la aucun
# pointe geogFeat geogName
# SW geogFeat geogName
# de aucun
# la aucun
# partie aucun
# Nord aucun
# du aucun
# Motu geogFeat geogName
# Maupihaa geogFeat geogName
# , aucun
# et aucun
# à aucun
# 0,3 aucun
# M aucun
# de aucun
# la aucun
# côte geogFeat geogName
# . aucun
# Ne aucun
# pas aucun
# s’ aucun
# approcher aucun
# à aucun
# moins aucun
# de aucun
# 0,3 aucun
# M aucun
# de aucun
# la aucun
# côte geogFeat geogName
# car aucun
# les aucun
# profondeurs aucun
# y aucun
# sont aucun
# moindres aucun
# que aucun
# celles aucun
# figurant aucun
# sur aucun
# la aucun
# carte aucun
# . aucun
# 31 aucun
# DÉBARQUEMENT aucun
# . aucun
# — aucun
# Les aucun
# embarcations aucun
# accostent aucun
# sur aucun
# la aucun
# plage geogFeat geogName
# devant aucun
# les aucun
# rares geogFeat geogName
# constructions geogFeat geogName
# entretenues geogFeat geogName
# . aucun
# 01 aucun
# 2.3 aucun
# . aucun
# Île geogFeat geogName
# Miquelon geogFeat geogName
# 01 aucun
# 4.3.4.6 aucun
# . aucun
# Manuae geogFeat geogName
# ( aucun
# Scilly geogFeat geogName
# ) aucun
# [ aucun
# Fanua geogFeat geogName
# Ura geogFeat geogName
# ] aucun
# 07 aucun
# Manuae geogFeat geogName
# ( aucun
# Scilly geogFeat geogName
# ) aucun
# [ aucun
# Fanua geogFeat geogName
# Ura geogFeat geogName
# ] aucun
# ( aucun
# 16 aucun
# ° aucun
# 30 aucun
# ' aucun
# S aucun
# — aucun
# 154 aucun
# ° aucun
# 40 aucun
# ' aucun
# W aucun
# ) aucun
# , aucun
# atoll geogFeat geogName
# de aucun
# 6 aucun
# M aucun
# de aucun
# diamètre aucun
# , aucun
# est aucun
# le aucun
# plus aucun
# Ouest aucun
# des aucun
# Îles geogFeat geogName
# Sous-le-Vent geogFeat geogName
# . aucun
# Le aucun
# lagon geogFeat geogName
# n’ aucun
# est aucun
# accessible aucun
# qu’ aucun
# aux aucun
# embarcations aucun
# par aucun
# une aucun
# échancrure aucun
# dans aucun
# le aucun
# récif geogFeat geogName
# à aucun
# 0,4 aucun
# M aucun
# à aucun
# l’ aucun
# WSW aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Nord geogFeat geogName
# . aucun
# Une aucun
# autre aucun
# anfractuosité aucun
# dans aucun
# la aucun
# barrière geogFeat geogName
# permet aucun
# le aucun
# débarquement aucun
# par aucun
# baleinière aucun
# sur aucun
# la aucun
# côte geogFeat geogName
# Est geogFeat geogName
# près aucun
# du aucun
# village geogFeat geogName
# ; aucun
# l’ aucun
# embarcation aucun
# doit aucun
# être aucun
# hissée aucun
# sur aucun
# le aucun
# platier aucun
# . aucun
# Ce aucun
# débarquement aucun
# de aucun
# même aucun
# que aucun
# le aucun
# franchissement aucun
# de aucun
# la aucun
# passe geogFeat geogName
# ne aucun
# peuvent aucun
# être aucun
# envisagés aucun
# que aucun
# par aucun
# temps aucun
# calme aucun
# . aucun
# 13 aucun
# Des aucun
# îlots geogFeat geogName
# boisés geogFeat geogName
# se aucun
# voient aucun
# dans aucun
# la aucun
# partie aucun
# Est aucun
# du aucun
# récif geogFeat geogName
# dont aucun
# les aucun
# côtes geogFeat geogName
# Ouest geogFeat geogName
# et aucun
# Sud aucun
# sont aucun
# à aucun
# fleur aucun
# d’ aucun
# eau aucun
# . aucun
# L’ aucun
# atoll geogFeat geogName
# présente aucun
# à aucun
# l’ aucun
# Ouest aucun
# un aucun
# banc geogFeat geogName
# de aucun
# sable aucun
# de aucun
# plus aucun
# de aucun
# 10 aucun
# km aucun
# , aucun
# parfois aucun
# confondu aucun
# avec aucun
# la aucun
# limite aucun
# du aucun
# récif geogFeat geogName
# . aucun
# 25 aucun
# Cet aucun
# atoll geogFeat geogName
# est aucun
# inclus aucun
# dans aucun
# la aucun
# réserve geogFeat geogName
# territoriale geogFeat geogName
# de geogFeat geogName
# Scilly geogFeat geogName
# et aucun
# Bellingshausen aucun
# ; aucun
# il aucun
# est aucun
# soumis aucun
# à aucun
# la aucun
# même aucun
# réglemen aucun
# tation aucun
# que aucun
# l’ aucun
# atoll geogFeat geogName
# Motu geogFeat geogName
# One geogFeat geogName
# ( aucun
# § aucun
# 4.3.4.5 aucun
# . aucun
# ) aucun
# . aucun
# La aucun
# population aucun
# , aucun
# très aucun
# isolée aucun
# , aucun
# est aucun
# limitée aucun
# à aucun
# moins aucun
# de aucun
# 10 aucun
# personnes aucun
# . aucun
# 31 aucun
# Note aucun
# : aucun
# Il aucun
# existe aucun
# également aucun
# une aucun
# île geogFeat geogName
# du geogFeat geogName
# nom geogFeat geogName
# de geogFeat geogName
# Manuae geogFeat geogName
# dans aucun
# les aucun
# Southern geogFeat geogName
# Cook geogFeat geogName
# Islands geogFeat geogName
# . aucun
# 222 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 222 aucun
# / aucun
# 0 aucun
# ÎLES geogFeat geogName
# AUSTRALES geogFeat geogName
# 01 aucun
# 4.3.3.3 aucun
# . aucun
# Côte geogFeat geogName
# de geogFeat geogName
# Tahaa geogFeat geogName
# 05 aucun
# Sur aucun
# la aucun
# côte geogFeat geogName
# SW geogFeat geogName
# de geogFeat geogName
# Tahaa geogFeat geogName
# , aucun
# la aucun
# passe geogFeat geogName
# Paipai geogFeat geogName
# , aucun
# large aucun
# de aucun
# 200 aucun
# m aucun
# et aucun
# profonde aucun
# , aucun
# est aucun
# bien aucun
# balisée aucun
# . aucun
# Son aucun
# axe geogFeat geogName
# ( aucun
# 009 aucun
# ° aucun
# ) aucun
# est aucun
# marqué aucun
# par aucun
# l’ aucun
# alignement geogFeat geogName
# de aucun
# deux aucun
# colonnes geogFeat geogName
# lumineuses geogFeat geogName
# à aucun
# bandes aucun
# horizontales aucun
# rouges aucun
# et aucun
# blanches aucun
# , aucun
# implantées aucun
# à aucun
# la aucun
# pointe geogFeat geogName
# Tepari geogFeat geogName
# , aucun
# au aucun
# Nord aucun
# de aucun
# la aucun
# passe geogFeat geogName
# . aucun
# 09 aucun
# 4.3.3.3.A. aucun
# — aucun
# Tahaa geogFeat geogName
# – aucun
# Passe geogFeat geogName
# Paipai geogFeat geogName
# – aucun
# Alignement geogFeat geogName
# à aucun
# 009 aucun
# ° aucun
# . aucun
# 13 aucun
# La aucun
# passe geogFeat geogName
# Paipai geogFeat geogName
# débouche aucun
# sur aucun
# la aucun
# baie geogFeat geogName
# Hurepiti geogFeat geogName
# qui aucun
# offre aucun
# un aucun
# excellent aucun
# abri aucun
# par aucun
# tous aucun
# les aucun
# temps aucun
# . aucun
# De aucun
# nombreuses aucun
# bouées geogFeat geogName
# sont aucun
# mouillées aucun
# dans aucun
# sa aucun
# partie aucun
# NW aucun
# . aucun
# Mouillage aucun
# , aucun
# par aucun
# profondeur aucun
# de aucun
# 25 aucun
# à aucun
# 30 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# sable aucun
# d’ aucun
# excellente aucun
# tenue aucun
# , aucun
# en aucun
# relevant aucun
# la aucun
# pointe geogFeat geogName
# Tepari geogFeat geogName
# à aucun
# 280 aucun
# ° aucun
# et aucun
# 0,3 aucun
# M. aucun
# Pour aucun
# se aucun
# rapprocher aucun
# de aucun
# Tiva geogFeat geogName
# , aucun
# mouillage aucun
# par aucun
# profondeur aucun
# de aucun
# 30 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# de aucun
# bonne aucun
# tenue aucun
# , aucun
# en aucun
# relevant aucun
# à aucun
# 320 aucun
# ° aucun
# et aucun
# 0,6 aucun
# M aucun
# le aucun
# clocher geogFeat geogName
# , aucun
# à aucun
# l’ aucun
# Ouest aucun
# de aucun
# la aucun
# baie geogFeat geogName
# . aucun
# Il aucun
# y aucun
# a aucun
# un aucun
# appontement geogFeat geogName
# devant aucun
# l’ aucun
# église geogFeat geogName
# et aucun
# un aucun
# autre aucun
# à aucun
# 0,2 aucun
# M aucun
# au aucun
# NW aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Tepari geogFeat geogName
# . aucun
# 17 aucun
# Le aucun
# chenal geogFeat geogName
# intérieur aucun
# autour aucun
# de aucun
# l’ aucun
# île geogFeat geogName
# est aucun
# marqué aucun
# par aucun
# un aucun
# balisage geogFeat geogName
# , aucun
# en aucun
# partie aucun
# lumineux aucun
# . aucun
# Les aucun
# balises geogFeat geogName
# sont aucun
# pour aucun
# la aucun
# plupart aucun
# implantées aucun
# sur aucun
# le aucun
# récif geogFeat geogName
# côtier geogFeat geogName
# de aucun
# l’ aucun
# île geogFeat geogName
# ; aucun
# il aucun
# ne aucun
# faut aucun
# pas aucun
# les aucun
# serrer aucun
# de aucun
# trop aucun
# près aucun
# , aucun
# car aucun
# elles aucun
# ne aucun
# sont aucun
# pas aucun
# toujours aucun
# au aucun
# bord aucun
# du aucun
# récif geogFeat geogName
# . aucun
# 21 aucun
# À aucun
# 2,7 aucun
# M aucun
# au aucun
# SE aucun
# de aucun
# la aucun
# passe geogFeat geogName
# Paipai geogFeat geogName
# , aucun
# la aucun
# baie geogFeat geogName
# Apu geogFeat geogName
# , aucun
# offre aucun
# d’ aucun
# excellents aucun
# mouillages aucun
# pour aucun
# petits aucun
# navires aucun
# notamment aucun
# à aucun
# 0,3 aucun
# M aucun
# dans aucun
# le aucun
# NNE aucun
# de aucun
# l aucun
# ’ aucun
# île geogFeat geogName
# Toapuhi geogFeat geogName
# par aucun
# 33 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# 25 aucun
# Les aucun
# grands aucun
# navires aucun
# peuvent aucun
# mouiller aucun
# par aucun
# profondeur aucun
# de aucun
# 43 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# sable aucun
# , aucun
# à aucun
# 0,6 aucun
# M aucun
# au aucun
# Sud aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Toamaro geogFeat geogName
# , aucun
# pointe geogFeat geogName
# SE geogFeat geogName
# de aucun
# la aucun
# baie geogFeat geogName
# Apu geogFeat geogName
# . aucun
# 29 aucun
# Un aucun
# appontement geogFeat geogName
# de aucun
# 15 aucun
# m aucun
# de aucun
# long aucun
# et aucun
# 5 aucun
# m aucun
# d’ aucun
# eau aucun
# se aucun
# trouve aucun
# sur aucun
# le aucun
# côté aucun
# Ouest aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Toamaro geogFeat geogName
# ; aucun
# c’ aucun
# est aucun
# tout aucun
# ce aucun
# qui aucun
# reste aucun
# de aucun
# la aucun
# marina geogFeat geogName
# Iti geogFeat geogName
# après aucun
# la aucun
# fermeture aucun
# du aucun
# yacht geogFeat geogName
# club geogFeat geogName
# « geogFeat geogName
# Taravana geogFeat geogName
# » aucun
# en aucun
# 2013 aucun
# . aucun
# 33 aucun
# À aucun
# 1,8 aucun
# M aucun
# plus aucun
# à aucun
# l’ aucun
# Est aucun
# , aucun
# on aucun
# peut aucun
# mouiller aucun
# devant aucun
# le aucun
# village geogFeat geogName
# de geogFeat geogName
# Vaitoare geogFeat geogName
# , aucun
# par aucun
# profondeur aucun
# de aucun
# 30 aucun
# à aucun
# 40 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# d’ aucun
# excellente aucun
# tenue aucun
# en aucun
# relevant aucun
# à aucun
# 255 aucun
# ° aucun
# la aucun
# pointe geogFeat geogName
# SE geogFeat geogName
# de aucun
# l’ aucun
# îlot geogFeat geogName
# Fatufatu geogFeat geogName
# et aucun
# à aucun
# 341 aucun
# ° aucun
# la aucun
# pointe geogFeat geogName
# Sud geogFeat geogName
# de aucun
# l’ aucun
# appontement geogFeat geogName
# . aucun
# 37 aucun
# Sur aucun
# la aucun
# côte geogFeat geogName
# Est geogFeat geogName
# de aucun
# l’ aucun
# île geogFeat geogName
# , aucun
# la aucun
# passe geogFeat geogName
# Toahotu geogFeat geogName
# , aucun
# bien aucun
# balisée aucun
# , aucun
# large aucun
# de aucun
# 150 aucun
# m aucun
# et aucun
# profonde aucun
# , aucun
# se aucun
# franchit aucun
# sur aucun
# l’ aucun
# alignement geogFeat geogName
# ( aucun
# 293 aucun
# ° aucun
# ) aucun
# d’ aucun
# une aucun
# échancrure geogFeat geogName
# remarquable aucun
# , aucun
# légèrement aucun
# au aucun
# Sud aucun
# du aucun
# mont geogFeat geogName
# Puurauti geogFeat geogName
# , aucun
# par aucun
# une aucun
# balise geogFeat geogName
# , aucun
# peu aucun
# visible aucun
# , aucun
# implantée aucun
# au aucun
# pied aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Pataaia geogFeat geogName
# , aucun
# et aucun
# par aucun
# le aucun
# milieu aucun
# du aucun
# passage geogFeat geogName
# entre aucun
# l’ aucun
# îlot geogFeat geogName
# Mahaea geogFeat geogName
# et aucun
# l’ aucun
# îlot geogFeat geogName
# Toahotu geogFeat geogName
# ; aucun
# dès aucun
# que aucun
# ce aucun
# dernier aucun
# est aucun
# paré aucun
# , aucun
# venir aucun
# rondement aucun
# par aucun
# la aucun
# gauche aucun
# en aucun
# route geogFeat geogName
# à aucun
# 255 aucun
# ° aucun
# pour aucun
# laisser aucun
# au aucun
# Nord aucun
# un aucun
# haut-fond geogFeat geogName
# couvert aucun
# de aucun
# 5,2 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# non aucun
# balisé aucun
# , aucun
# marqué aucun
# par aucun
# une aucun
# décoloration aucun
# de aucun
# l’ aucun
# eau aucun
# , aucun
# parfois aucun
# peu aucun
# visible aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 209 aucun
# / aucun
# 0 aucun
# 209 aucun
# ÎLES geogFeat geogName
# DU aucun
# VENT aucun
# – aucun
# ÎLES geogFeat geogName
# SOUS-LE-VENT geogFeat geogName
# – aucun
# ÎLES geogFeat geogName
# AUSTRALES geogFeat geogName
# 41 aucun
# 4.3.3.3.B. aucun
# — aucun
# Tahaa geogFeat geogName
# – aucun
# Passe geogFeat geogName
# de geogFeat geogName
# Toahotu geogFeat geogName
# – aucun
# Alignement geogFeat geogName
# à aucun
# 293 aucun
# ° aucun
# . aucun
# 45 aucun
# Un aucun
# chenal geogFeat geogName
# secondaire geogFeat geogName
# marqué aucun
# par aucun
# des aucun
# espars geogFeat geogName
# noir aucun
# et aucun
# blanc aucun
# permet aucun
# aux aucun
# petites aucun
# embarcations aucun
# de aucun
# passer aucun
# sur aucun
# le aucun
# récif geogFeat geogName
# - aucun
# barrière aucun
# au aucun
# Sud aucun
# de aucun
# la aucun
# passe geogFeat geogName
# de geogFeat geogName
# Toahotu geogFeat geogName
# , aucun
# dans aucun
# la aucun
# partie aucun
# submergée aucun
# de aucun
# 0,5 aucun
# à aucun
# 1,5 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# et aucun
# d’ aucun
# accéder aucun
# au aucun
# mouillage geogFeat geogName
# d’ geogFeat geogName
# Uturoa geogFeat geogName
# en aucun
# longeant aucun
# le aucun
# côté aucun
# Est aucun
# du aucun
# récif geogFeat geogName
# . aucun
# 49 aucun
# La aucun
# baie geogFeat geogName
# Haamene geogFeat geogName
# constitue aucun
# une aucun
# brèche geogFeat geogName
# profonde aucun
# de aucun
# 2,4 aucun
# M aucun
# à aucun
# l’ aucun
# intérieur aucun
# de aucun
# l’ aucun
# île geogFeat geogName
# à aucun
# partir aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Para geogFeat geogName
# . aucun
# On aucun
# peut aucun
# mouiller aucun
# dans aucun
# la aucun
# partie aucun
# Est aucun
# de aucun
# la aucun
# baie geogFeat geogName
# par aucun
# profondeur aucun
# de aucun
# 30 aucun
# à aucun
# 40 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# . aucun
# Appontement aucun
# au aucun
# NE aucun
# de aucun
# la aucun
# baie geogFeat geogName
# de geogFeat geogName
# 18 aucun
# m aucun
# de aucun
# long aucun
# par aucun
# 2 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# 53 aucun
# À aucun
# 0,5 aucun
# M aucun
# au aucun
# Nord aucun
# de aucun
# la aucun
# pointe geogFeat geogName
# Pataaia geogFeat geogName
# , aucun
# la aucun
# baie geogFeat geogName
# Faaha geogFeat geogName
# , aucun
# longue aucun
# de aucun
# 1,1 aucun
# M aucun
# , aucun
# permet aucun
# de aucun
# mouiller aucun
# par aucun
# profondeur aucun
# de aucun
# 32 aucun
# m aucun
# , aucun
# sur aucun
# un aucun
# fond aucun
# de aucun
# vase aucun
# . aucun
# Le aucun
# village geogFeat geogName
# de geogFeat geogName
# Faaha geogFeat geogName
# , aucun
# en aucun
# fond aucun
# de aucun
# baie geogFeat geogName
# , aucun
# dispose aucun
# d’ aucun
# un aucun
# quai geogFeat geogName
# . aucun
# 57 aucun
# Le aucun
# chenal geogFeat geogName
# se aucun
# rétrécit aucun
# ( aucun
# 0,15 aucun
# M aucun
# ) aucun
# à aucun
# la aucun
# pointe geogFeat geogName
# Matahira geogFeat geogName
# , aucun
# pointe geogFeat geogName
# Ouest geogFeat geogName
# de aucun
# l’ aucun
# île geogFeat geogName
# , aucun
# puis aucun
# s’ aucun
# élargit aucun
# au aucun
# NE aucun
# de aucun
# l’ aucun
# île geogFeat geogName
# . aucun
# 61 aucun
# Il aucun
# est aucun
# conseillé aucun
# de aucun
# suivre aucun
# le aucun
# chenal geogFeat geogName
# en aucun
# serrant aucun
# le aucun
# récif geogFeat geogName
# côtier geogFeat geogName
# de geogFeat geogName
# Tahaa geogFeat geogName
# , aucun
# plus aucun
# accore aucun
# et aucun
# plus aucun
# visible aucun
# que aucun
# le aucun
# bord aucun
# intérieur aucun
# du aucun
# récif geogFeat geogName
# - aucun
# barrière aucun
# . aucun
# Le aucun
# seul aucun
# passage aucun
# délicat aucun
# est aucun
# au aucun
# Nord aucun
# de aucun
# la aucun
# baie geogFeat geogName
# Pahure geogFeat geogName
# ( aucun
# 16 aucun
# ° aucun
# 35 aucun
# ' aucun
# S aucun
# — aucun
# 151 aucun
# ° aucun
# 29 aucun
# ' aucun
# W aucun
# ) aucun
# , aucun
# où aucun
# le aucun
# chenal geogFeat geogName
# est aucun
# rétréci aucun
# par aucun
# plusieurs aucun
# dangers geogFeat geogName
# , aucun
# que aucun
# l’ aucun
# on aucun
# peut aucun
# contourner aucun
# par aucun
# le aucun
# Nord aucun
# en aucun
# arrondissant aucun
# à aucun
# plus aucun
# de aucun
# 0,15 aucun
# M aucun
# le aucun
# récif geogFeat geogName
# Moora geogFeat geogName
# , aucun
# balisé aucun
# mais aucun
# débordé aucun
# de aucun
# 0,1 aucun
# M aucun
# par aucun
# un aucun
# haut-fond geogFeat geogName
# recouvert aucun
# de aucun
# 4,1 aucun
# m aucun
# d’ aucun
# eau aucun
# puis aucun
# en aucun
# passant aucun
# au aucun
# Sud aucun
# du aucun
# récif geogFeat geogName
# Faremao geogFeat geogName
# , aucun
# marqué aucun
# par aucun
# une aucun
# balise geogFeat geogName
# latérale geogFeat geogName
# tribord geogFeat geogName
# . aucun
# 65 aucun
# À aucun
# l’ aucun
# embouchure geogFeat geogName
# de aucun
# la aucun
# rivière geogFeat geogName
# Iripau geogFeat geogName
# , aucun
# le aucun
# village geogFeat geogName
# de geogFeat geogName
# Patio geogFeat geogName
# , aucun
# centre aucun
# administratif aucun
# de aucun
# l’ aucun
# île geogFeat geogName
# , aucun
# offre aucun
# une aucun
# darse aucun
# et aucun
# des aucun
# quais geogFeat geogName
# par aucun
# 1,5 aucun
# m aucun
# d’ aucun
# eau aucun
# ; aucun
# il aucun
# possède aucun
# une aucun
# infirmerie aucun
# . aucun
# 69 aucun
# Vers aucun
# l’ aucun
# Ouest aucun
# , aucun
# le aucun
# chenal geogFeat geogName
# mène geogFeat geogName
# sans aucun
# difficulté aucun
# jusqu’ aucun
# à aucun
# la aucun
# baie geogFeat geogName
# Tapuamu geogFeat geogName
# offrant aucun
# dans aucun
# sa aucun
# partie aucun
# Sud aucun
# , aucun
# un aucun
# quai geogFeat geogName
# , aucun
# orienté aucun
# Est-Ouest aucun
# , aucun
# de aucun
# 74 aucun
# m aucun
# de aucun
# long aucun
# par aucun
# 6 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# avec aucun
# un aucun
# slip geogFeat geogName
# de aucun
# 14 aucun
# m aucun
# de aucun
# large aucun
# à aucun
# son aucun
# extrémité aucun
# Ouest aucun
# , aucun
# et aucun
# une aucun
# darse aucun
# pour aucun
# bonitiers aucun
# et aucun
# navires aucun
# de aucun
# plaisance aucun
# par aucun
# 1,7 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Alimentation aucun
# en aucun
# eau aucun
# possible aucun
# . aucun
# Il aucun
# est aucun
# interdit aucun
# de aucun
# mouiller aucun
# à aucun
# l’ aucun
# ouvert geogFeat geogName
# de aucun
# cette aucun
# baie geogFeat geogName
# sur aucun
# une aucun
# bande geogFeat geogName
# de aucun
# 0,3 aucun
# M aucun
# , aucun
# axée aucun
# à aucun
# 302 aucun
# ° aucun
# entre aucun
# le aucun
# quai geogFeat geogName
# et aucun
# l’ aucun
# îlot geogFeat geogName
# Tautau geogFeat geogName
# ( aucun
# canalisation aucun
# eau aucun
# et aucun
# gaz aucun
# ) aucun
# . aucun
# 210 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 19 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 20 aucun
# – aucun
# page aucun
# 210 aucun
# / aucun
# 0 aucun
# ÎLES geogFeat geogName
# SOUS-LE-VENT geogFeat geogName
# 73 aucun
# 4.3.3.3.C. aucun
# — aucun
# Tahaa geogFeat geogName
# – aucun
# Quai geogFeat geogName
# de geogFeat geogName
# la aucun
# baie geogFeat geogName
# de geogFeat geogName
# Tapuamu geogFeat geogName
# . aucun
# 77 aucun
# Le aucun
# village geogFeat geogName
# de geogFeat geogName
# Tiva geogFeat geogName
# , aucun
# à aucun
# 1,5 aucun
# M aucun
# au aucun
# Sud aucun
# de aucun
# Tapuamu geogFeat geogName
# , aucun
# possède aucun
# un aucun
# appontement geogFeat geogName
# de geogFeat geogName
# 9 aucun
# m aucun
# de aucun
# long aucun
# par aucun
# 2,7 aucun
# m aucun
# d’ aucun
# eau aucun
# , aucun
# accessible aucun
# aux aucun
# petits aucun
# caboteurs aucun
# . aucun
# 81 aucun
# L’ aucun
# accès geogFeat geogName
# à aucun
# Uturoa geogFeat geogName
# par aucun
# la aucun
# passe geogFeat geogName
# Toahotu geogFeat geogName
# est aucun
# ...
# à aucun
# 810 aucun
# 000 aucun
# habitants aucun
# ( aucun
# 2014 aucun
# ) aucun
# , aucun
# soit aucun
# plus aucun
# des aucun
# 2/3 aucun
# de aucun
# l’ aucun
# ensemble aucun
# de aucun
# la aucun
# population aucun
# du aucun
# pays geogFeat geogName
# . aucun
# 8.3.2.8.A. aucun
# — aucun
# Djibouti geogFeat geogName
# ( aucun
# 11 aucun
# ° aucun
# 36 aucun
# ' aucun
# N aucun
# — aucun
# 43 aucun
# ° aucun
# 08 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 13 aucun
# À aucun
# l’ aucun
# Ouest aucun
# du aucun
# Plateau geogFeat geogName
# du geogFeat geogName
# Marabout geogFeat geogName
# , aucun
# la aucun
# jetée geogFeat geogName
# du geogFeat geogName
# Marabout geogFeat geogName
# est aucun
# perpendiculaire aucun
# à aucun
# son aucun
# extrémité aucun
# , aucun
# à aucun
# la aucun
# jetée geogFeat geogName
# du geogFeat geogName
# Large geogFeat geogName
# . aucun
# À aucun
# l’ aucun
# extrémité aucun
# SW aucun
# de aucun
# la aucun
# Jetée geogFeat geogName
# du geogFeat geogName
# Large geogFeat geogName
# , aucun
# le aucun
# môle geogFeat geogName
# du geogFeat geogName
# Fontainebleau geogFeat geogName
# a aucun
# été aucun
# construit aucun
# sur aucun
# l’ aucun
# épave geogFeat geogName
# du aucun
# navire aucun
# du aucun
# même aucun
# nom aucun
# . aucun
# 19 aucun
# 25 aucun
# À aucun
# 0,1 aucun
# M aucun
# au aucun
# Sud aucun
# du aucun
# Môle geogFeat geogName
# Sud geogFeat geogName
# , aucun
# se aucun
# situe aucun
# la aucun
# jetée geogFeat geogName
# du geogFeat geogName
# Gouvernement geogFeat geogName
# . aucun
# 8.3.2.8.B. aucun
# — aucun
# Môle geogFeat geogName
# du geogFeat geogName
# Fontainebleau geogFeat geogName
# au aucun
# Nord aucun
# ( aucun
# Origine geogFeat geogName
# Marine aucun
# nationale aucun
# ) aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 13 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 277 aucun
# / aucun
# 0 aucun
# 277 aucun
# CÔTE geogFeat geogName
# SUD geogFeat geogName
# DU aucun
# GOLFE geogFeat geogName
# D' geogFeat geogName
# ADEN geogFeat geogName
# ET aucun
# CÔTE geogFeat geogName
# AFRICAINE geogFeat geogName
# DE aucun
# LA aucun
# MER geogFeat geogName
# D' geogFeat geogName
# ARABIE geogFeat geogName
# ( aucun
# RÉPUBLIQUE geogFeat geogName
# DE geogFeat geogName
# DJIBOUTI geogFeat geogName
# , aucun
# SOMALIE geogFeat geogName
# ) aucun
# 31 aucun
# 37 aucun
# À aucun
# 1,8 aucun
# M aucun
# au aucun
# SW aucun
# du aucun
# port geogFeat geogName
# du geogFeat geogName
# Héron geogFeat geogName
# , aucun
# le aucun
# site geogFeat geogName
# de geogFeat geogName
# Doraleh geogFeat geogName
# accueille aucun
# le aucun
# terminal geogFeat geogName
# pétrolier geogFeat geogName
# et aucun
# le aucun
# terminal geogFeat geogName
# à geogFeat geogName
# conteneurs geogFeat geogName
# . aucun
# 8.3.2.8.C. aucun
# — aucun
# Jetée geogFeat geogName
# du geogFeat geogName
# Gouvernement geogFeat geogName
# - aucun
# 2001 aucun
# . aucun
# 43 aucun
# 8.3.2.8.D. aucun
# — aucun
# Terminal geogFeat geogName
# pétrolier geogFeat geogName
# de geogFeat geogName
# Doraleh geogFeat geogName
# - aucun
# 2015 aucun
# ( aucun
# Origine geogFeat geogName
# Frégate geogFeat geogName
# Guépratte geogFeat geogName
# ) aucun
# . aucun
# 278 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 13 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 278 aucun
# / aucun
# 0 aucun
# ENTRE aucun
# DJIBOUTI geogFeat geogName
# ET aucun
# BERBERA geogFeat geogName
# 49 aucun
# 8.3.2.8.E. aucun
# — aucun
# Terminal geogFeat geogName
# à geogFeat geogName
# conteneurs geogFeat geogName
# de geogFeat geogName
# Doraleh geogFeat geogName
# - aucun
# 2015 aucun
# ( aucun
# Origine geogFeat geogName
# Frégate geogFeat geogName
# Guépratte geogFeat geogName
# ) aucun
# . aucun
# 01 aucun
# 5.4.6 aucun
# . aucun
# Port geogFeat geogName
# du geogFeat geogName
# Collet geogFeat geogName
# 07 aucun
# 5.4.6 aucun
# . aucun
# — aucun
# Port geogFeat geogName
# du geogFeat geogName
# Collet geogFeat geogName
# ( aucun
# 2018 aucun
# ) aucun
# . aucun
# 01 aucun
# 5.4.5 aucun
# . aucun
# La geogFeat geogName
# Bernerie-en-Retz geogFeat geogName
# 07 aucun
# 5.4.5 aucun
# . aucun
# — aucun
# La geogFeat geogName
# Bernerie-en-Retz geogFeat geogName
# ( aucun
# 2018 aucun
# ) aucun
# . aucun
# 01 aucun
# 2.1.4.7 aucun
# . aucun
# Zone geogFeat geogName
# de geogFeat geogName
# câbles geogFeat geogName
# 07 aucun
# Arrêté aucun
# 1987 aucun
# - aucun
# 089 aucun
# du aucun
# 29 aucun
# décembre aucun
# 1987 aucun
# du aucun
# préfet aucun
# maritime aucun
# de aucun
# la aucun
# Troisième geogFeat geogName
# Région geogFeat geogName
# ( aucun
# www.premar-mediterranee.gouv.fr/arretes.html aucun
# ) aucun
# . aucun
# 90 aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 05 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 90 aucun
# / aucun
# 0 aucun
# GÉNÉRALITÉS aucun
# 13 aucun
# – aucun
# Situation aucun
# : aucun
# zone aucun
# large aucun
# d’ aucun
# environ aucun
# 3 aucun
# M aucun
# , aucun
# portée aucun
# sur aucun
# les aucun
# cartes aucun
# , aucun
# entre aucun
# Canet geogFeat geogName
# - geogFeat geogName
# Plage geogFeat geogName
# et aucun
# le aucun
# cap geogFeat geogName
# Cerbère geogFeat geogName
# . aucun
# 19 aucun
# – aucun
# Réglementation aucun
# : aucun
# mouillage aucun
# , aucun
# dragage aucun
# et aucun
# chalutage aucun
# interdits aucun
# . aucun
# Mouillage aucun
# autorisé aucun
# pour aucun
# les aucun
# navires aucun
# de aucun
# pêche aucun
# ou aucun
# de aucun
# plaisance aucun
# , aucun
# d’ aucun
# une aucun
# jauge aucun
# brute aucun
# inférieure aucun
# ou aucun
# égale aucun
# à aucun
# 10 aucun
# , aucun
# aux aucun
# risques aucun
# du aucun
# propriétaire aucun
# . aucun
# 01 aucun
# 3.3.3.4 aucun
# . aucun
# Données aucun
# portuaires aucun
# 07 aucun
# Caractéristiques aucun
# nautiques aucun
# Balisage geogFeat geogName
# Chenal geogFeat geogName
# d’ geogFeat geogName
# accès geogFeat geogName
# balisé aucun
# par aucun
# 4 aucun
# paires aucun
# de aucun
# bouées geogFeat geogName
# latérales geogFeat geogName
# . aucun
# Sémaphore geogFeat geogName
# Pertusato geogFeat geogName
# ( aucun
# 41 aucun
# ° aucun
# 22,44 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 10,69 aucun
# ' aucun
# E aucun
# ) aucun
# Stations geogFeat geogName
# de geogFeat geogName
# sauvetage geogFeat geogName
# Propriano geogFeat geogName
# ( aucun
# 41 aucun
# ° aucun
# 40,56 aucun
# ' aucun
# N aucun
# — aucun
# 8 aucun
# ° aucun
# 54,09 aucun
# ' aucun
# E aucun
# ) aucun
# Bonifacio geogFeat geogName
# ( aucun
# 41 aucun
# ° aucun
# 23,31 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 09,73 aucun
# ' aucun
# E aucun
# ) aucun
# Porto geogFeat geogName
# - geogFeat geogName
# Vecchio geogFeat geogName
# ( aucun
# 41 aucun
# ° aucun
# 35,46 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 17,16 aucun
# ' aucun
# E aucun
# ) aucun
# Navires aucun
# admis aucun
# Navires aucun
# jusqu’ aucun
# à aucun
# 35 aucun
# m aucun
# de aucun
# longueur aucun
# . aucun
# Infrastructures geogFeat geogName
# 200 aucun
# places aucun
# par aucun
# 3 aucun
# m aucun
# d’ aucun
# eau aucun
# dans aucun
# 2 aucun
# bassins geogFeat geogName
# . aucun
# Installations geogFeat geogName
# portuaires geogFeat geogName
# 186 aucun
# ÎLES geogFeat geogName
# LAVEZZI geogFeat geogName
# Amarrage geogFeat geogName
# perpendiculairement aucun
# aux aucun
# ouvrages aucun
# . aucun
# Bassin geogFeat geogName
# Nord geogFeat geogName
# . aucun
# Limité aucun
# au aucun
# Sud aucun
# par aucun
# un aucun
# 2ème aucun
# appontement geogFeat geogName
# ( aucun
# G aucun
# ) aucun
# parallèle aucun
# au aucun
# 1er aucun
# ; aucun
# à aucun
# l’ aucun
# Est aucun
# et aucun
# au aucun
# Nord aucun
# par aucun
# les aucun
# rives geogFeat geogName
# des aucun
# quais geogFeat geogName
# ( aucun
# H aucun
# ) aucun
# ; aucun
# à aucun
# l’ aucun
# Ouest aucun
# par aucun
# une aucun
# petite aucun
# jetée geogFeat geogName
# ( aucun
# I aucun
# ) aucun
# . aucun
# Bateaux aucun
# de aucun
# 6 aucun
# m aucun
# à aucun
# 10 aucun
# m aucun
# par aucun
# 2,5 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Bassin geogFeat geogName
# Sud geogFeat geogName
# . aucun
# Limité aucun
# au aucun
# Sud aucun
# et aucun
# à aucun
# l’ aucun
# Est aucun
# par aucun
# la aucun
# jetée geogFeat geogName
# et aucun
# au aucun
# Nord aucun
# par aucun
# un aucun
# appontement geogFeat geogName
# central geogFeat geogName
# ( aucun
# F aucun
# ) aucun
# . aucun
# 2 aucun
# pontons geogFeat geogName
# ( aucun
# A aucun
# et aucun
# B aucun
# ) aucun
# établis aucun
# le aucun
# long aucun
# de aucun
# la aucun
# jetée geogFeat geogName
# et geogFeat geogName
# 3 geogFeat geogName
# pontons geogFeat geogName
# ( aucun
# C aucun
# , aucun
# D aucun
# et aucun
# E aucun
# ) aucun
# perpendiculairement aucun
# à aucun
# l’ aucun
# appontement geogFeat geogName
# central aucun
# en aucun
# direction aucun
# du aucun
# Sud aucun
# . aucun
# Amarrage aucun
# des aucun
# bateaux aucun
# les aucun
# plus aucun
# importants aucun
# jusqu’ aucun
# à aucun
# 18 aucun
# m aucun
# sur aucun
# la aucun
# face geogFeat geogName
# Ouest geogFeat geogName
# du aucun
# ponton geogFeat geogName
# C geogFeat geogName
# et aucun
# la aucun
# face geogFeat geogName
# extérieure geogFeat geogName
# du aucun
# ponton geogFeat geogName
# E. geogFeat geogName
# Unités geogFeat geogName
# de aucun
# 10 aucun
# m aucun
# à aucun
# 12 aucun
# m aucun
# amarrés aucun
# aux aucun
# autres aucun
# pontons geogFeat geogName
# de aucun
# ce aucun
# bassin geogFeat geogName
# . aucun
# Coffres aucun
# d’ aucun
# amarrage aucun
# pour aucun
# grosses aucun
# unités aucun
# mouillés aucun
# du aucun
# Nord aucun
# au aucun
# Sud aucun
# dans aucun
# l’ aucun
# Ouest aucun
# du aucun
# bassin geogFeat geogName
# Sud geogFeat geogName
# . aucun
# Outillage aucun
# Pas aucun
# de aucun
# moyen aucun
# de aucun
# levage aucun
# . aucun
# Ravitaillement aucun
# Shipchandler aucun
# ( aucun
# 08 aucun
# h aucun
# 30 aucun
# à aucun
# 13 aucun
# h aucun
# 00 aucun
# et aucun
# 14 aucun
# h aucun
# 30 aucun
# à aucun
# 19 aucun
# h aucun
# 30 aucun
# ) aucun
# ; aucun
# petit aucun
# supermarché aucun
# sur aucun
# l’ aucun
# île geogFeat geogName
# . aucun
# Eau aucun
# et aucun
# électricité aucun
# aux aucun
# pontons geogFeat geogName
# . aucun
# Sanitaires geogFeat geogName
# et aucun
# douches aucun
# à aucun
# la aucun
# capitainerie geogFeat geogName
# . aucun
# Météo aucun
# à aucun
# la aucun
# capitainerie geogFeat geogName
# . aucun
# Pas geogFeat geogName
# de geogFeat geogName
# carburant geogFeat geogName
# . aucun
# Administration aucun
# Île geogFeat geogName
# de geogFeat geogName
# Cavallo geogFeat geogName
# située aucun
# sur aucun
# la aucun
# commune geogFeat geogName
# de geogFeat geogName
# Bonifacio geogFeat geogName
# . aucun
# Gestion aucun
# par aucun
# société aucun
# privée aucun
# Web aucun
# : aucun
# www.portodicavallo.it aucun
# Organisation aucun
# Capitainerie aucun
# Tél aucun
# : aucun
# 04 aucun
# 95 aucun
# 25 aucun
# 80 aucun
# 11 aucun
# Portable geogFeat geogName
# : aucun
# 06 aucun
# 72 aucun
# 36 aucun
# 33 aucun
# 70 aucun
# VHF aucun
# : aucun
# Canal geogFeat geogName
# 9 aucun
# pour aucun
# instructions aucun
# Mél aucun
# : aucun
# info@portodicavallo.it aucun
# Ouverture aucun
# : aucun
# entre aucun
# 08 aucun
# h aucun
# 00 aucun
# et aucun
# 20 aucun
# h aucun
# 00 aucun
# Accueil aucun
# des aucun
# navires aucun
# Aide aucun
# à aucun
# l’ aucun
# amarrage aucun
# par aucun
# pneumatiques aucun
# du aucun
# port geogFeat geogName
# . aucun
# Port geogFeat geogName
# fermé aucun
# par aucun
# la aucun
# direction aucun
# en aucun
# cas aucun
# de aucun
# mauvais aucun
# temps aucun
# . aucun
# Services aucun
# Douanes aucun
# , aucun
# police aucun
# et aucun
# secours aucun
# à aucun
# la aucun
# capitainerie geogFeat geogName
# . aucun
# Communications aucun
# Taxi aucun
# , aucun
# avion-taxi aucun
# et aucun
# bateau-taxi aucun
# ; aucun
# 1 aucun
# navette aucun
# maritime aucun
# 4 aucun
# fois aucun
# par aucun
# jour aucun
# entre aucun
# Cavallo geogFeat geogName
# et aucun
# le aucun
# débarcadère geogFeat geogName
# de geogFeat geogName
# Piantarella geogFeat geogName
# . aucun
# Location aucun
# de aucun
# vélos aucun
# tous aucun
# terrains aucun
# , aucun
# de aucun
# voiturettes aucun
# électriques aucun
# et aucun
# de aucun
# bateaux aucun
# ( aucun
# s’ aucun
# adresser aucun
# à aucun
# la aucun
# capitainerie geogFeat geogName
# ) geogFeat geogName
# . aucun
# 3.3.3.4 aucun
# . aucun
# — aucun
# Port geogFeat geogName
# de geogFeat geogName
# Cavallo geogFeat geogName
# ( aucun
# 41 aucun
# ° aucun
# 21,67 aucun
# ' aucun
# N aucun
# — aucun
# 9 aucun
# ° aucun
# 15,83 aucun
# ' aucun
# E aucun
# ) aucun
# . aucun
# 187 aucun
# DU aucun
# CAP geogFeat geogName
# DE geogFeat geogName
# FENO geogFeat geogName
# AU aucun
# GOLFE geogFeat geogName
# DE geogFeat geogName
# SANT’ geogFeat geogName
# AMANZA geogFeat geogName
# . aucun
# BOUCHES geogFeat geogName
# DE geogFeat geogName
# BONIFACIO geogFeat geogName
# 01 aucun
# 9.2.3.7 aucun
# . aucun
# Réglementation aucun
# 07 aucun
# Voir aucun
# les aucun
# sous-paragraphes aucun
# 9.1.5.4 aucun
# . aucun
# et aucun
# 9.1.5.7 aucun
# . aucun
# 13 aucun
# La aucun
# zone geogFeat geogName
# large aucun
# de aucun
# 100 aucun
# m aucun
# qui aucun
# borde aucun
# le aucun
# terre geogFeat geogName
# - geogFeat geogName
# plein geogFeat geogName
# Nord-Est geogFeat geogName
# et aucun
# la aucun
# jetée geogFeat geogName
# Nord geogFeat geogName
# est aucun
# interdite aucun
# à aucun
# la aucun
# navigation aucun
# . aucun
# 411 aucun
# DU aucun
# CAP geogFeat geogName
# VERT geogFeat geogName
# JUSQU’ aucun
# AU aucun
# CAP geogFeat geogName
# VERGA geogFeat geogName
# 01 aucun
# 4.6.1.1 aucun
# . aucun
# Présentation aucun
# 07 aucun
# La aucun
# chaîne aucun
# de aucun
# montagnes aucun
# qui aucun
# longe aucun
# la aucun
# côte geogFeat geogName
# à aucun
# partir aucun
# de aucun
# Mostaganem geogFeat geogName
# s’ aucun
# étend aucun
# jusqu’ aucun
# à aucun
# Ras geogFeat geogName
# Ténès geogFeat geogName
# à aucun
# environ aucun
# 60 aucun
# M aucun
# à aucun
# l’ aucun
# ENE aucun
# de aucun
# Ras geogFeat geogName
# Ouillis geogFeat geogName
# . aucun
# Plusieurs aucun
# sommets aucun
# dépassent aucun
# 800 aucun
# m aucun
# d’ aucun
# altitude aucun
# . aucun
# 13 aucun
# Les aucun
# mouillages geogFeat geogName
# sont aucun
# rares aucun
# le aucun
# long aucun
# de aucun
# cette aucun
# partie aucun
# de aucun
# la aucun
# côte geogFeat geogName
# . aucun
# Ils aucun
# ne aucun
# sont aucun
# en aucun
# général aucun
# fréquentés aucun
# que aucun
# par aucun
# les aucun
# petits aucun
# navires aucun
# ou aucun
# les aucun
# bateaux aucun
# de aucun
# pêche aucun
# connaissant aucun
# les aucun
# lieux aucun
# . aucun
# 19 aucun
# À aucun
# environ aucun
# 2 aucun
# M aucun
# au aucun
# SW aucun
# de aucun
# Ras geogFeat geogName
# Ténès geogFeat geogName
# , aucun
# le aucun
# port geogFeat geogName
# de geogFeat geogName
# Ténès geogFeat geogName
# ( aucun
# § aucun
# 4.6.4 aucun
# . aucun
# ) aucun
# est aucun
# un aucun
# port geogFeat geogName
# de geogFeat geogName
# commerce geogFeat geogName
# d’ aucun
# importance aucun
# secon aucun
# daire aucun
# et aucun
# un aucun
# port geogFeat geogName
# de geogFeat geogName
# pêche geogFeat geogName
# . aucun
# 01 aucun
# 2.2.1.3 aucun
# . aucun
# Dangers geogFeat geogName
# au aucun
# large aucun
# 07 aucun
# La aucun
# présence aucun
# de aucun
# bancs geogFeat geogName
# du aucun
# large aucun
# , aucun
# qui aucun
# sont aucun
# présentés aucun
# dans aucun
# les aucun
# chapitres aucun
# descriptifs aucun
# correspondants aucun
# , aucun
# accroît aucun
# les aucun
# difficultés aucun
# de aucun
# navigation aucun
# dans aucun
# cette aucun
# zone geogFeat geogName
# . aucun
# 01 aucun
# 2.3.3.3 aucun
# . aucun
# Mouillage aucun
# 07 aucun
# L’ aucun
# anse geogFeat geogName
# de geogFeat geogName
# Miquelon geogFeat geogName
# est aucun
# très aucun
# saine aucun
# . aucun
# Il aucun
# est aucun
# possible aucun
# d’ aucun
# y aucun
# mouiller aucun
# par aucun
# 7 aucun
# à aucun
# 11 aucun
# m aucun
# d’ aucun
# eau aucun
# . aucun
# Le aucun
# fond aucun
# est aucun
# de aucun
# bonne aucun
# tenue aucun
# , aucun
# sauf aucun
# par aucun
# fort aucun
# vent aucun
# d’ aucun
# Est aucun
# et aucun
# de aucun
# NE aucun
# où aucun
# il aucun
# faut aucun
# se aucun
# tenir aucun
# prêt aucun
# à aucun
# appareiller aucun
# à aucun
# tout aucun
# instant aucun
# . aucun
# 13 aucun
# On aucun
# évitera aucun
# de aucun
# mouiller aucun
# à aucun
# proximité aucun
# des aucun
# deux aucun
# câbles aucun
# sous-marins aucun
# de aucun
# fibre aucun
# optique aucun
# qui aucun
# traversent aucun
# l’ aucun
# anse geogFeat geogName
# de geogFeat geogName
# Mi geogFeat geogName
# quelon geogFeat geogName
# et aucun
# qui aucun
# atterrissent aucun
# au aucun
# Sud aucun
# de aucun
# l’ aucun
# appontement geogFeat geogName
# pétrolier geogFeat geogName
# . aucun
# 19 aucun
# Par aucun
# forts aucun
# vents aucun
# de aucun
# secteur aucun
# NNW aucun
# à aucun
# Est aucun
# , aucun
# le aucun
# seul aucun
# mouillage geogFeat geogName
# conseillé aucun
# est aucun
# situé aucun
# au aucun
# SW aucun
# de aucun
# Langlade geogFeat geogName
# , aucun
# dans aucun
# l’ aucun
# anse geogFeat geogName
# du geogFeat geogName
# Sud-Ouest geogFeat geogName
# ( aucun
# voir aucun
# § aucun
# 2.3.5 aucun
# . aucun
# ) aucun
# . aucun
# extrait aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 09 aucun
# - aucun
# 21 aucun
# — aucun
# généré aucun
# le aucun
# : aucun
# 2021 aucun
# - aucun
# 10 aucun
# - aucun
# 06 aucun
# – aucun
# page aucun
# 103 aucun
# / aucun
# 0 aucun
# 103 aucun
# SAINT-PIERRE-ET-MIQUELON geogFeat geogName

# %%
os.makedirs('submissions', exist_ok=True)
submission = copy_test[['Id', 'Label']]
submission.to_csv('submissions/submission1.csv', index=False)

# %%
submission
# Out:
#           Id              Label
# 0          0              aucun
# 1          1              aucun
# 2          2              aucun
# 3          3              aucun
# 4          4              aucun
# ...      ...                ...
# 26168  26168              aucun
# 26169  26169              aucun
# 26170  26170              aucun
# 26171  26171              aucun
# 26172  26172  geogFeat geogName
#
# [26173 rows x 2 columns]
